# %%
from sklearn.model_selection import train_test_split
import os
import shutil
import numpy as np
from collections import Counter

# Get class distribution from ../combined_hybrid_data/
data_dir = '../final_testset/2021'
class_dirs = [d for d in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, d))]

# Collect all file paths and labels
file_paths = []
labels = []

for class_name in class_dirs:
    class_path = os.path.join(data_dir, class_name)
    files = os.listdir(class_path)
    for file in files:
        file_paths.append(os.path.join(class_path, file))
        labels.append(class_name)

# Split data while preserving class ratios
X_train, X_val, y_train, y_val = train_test_split(
    file_paths, labels, test_size=0.15, random_state=42, stratify=labels
)

# Create train and val directories
train_dir = '../trainingDatav3/train'
val_dir = '../trainingDatav3/val'

os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)

# Create class subdirectories and copy files
for class_name in class_dirs:
    os.makedirs(os.path.join(train_dir, class_name), exist_ok=True)
    os.makedirs(os.path.join(val_dir, class_name), exist_ok=True)

# Copy training files
for file_path, label in zip(X_train, y_train):
    filename = os.path.basename(file_path)
    dst_path = os.path.join(train_dir, label, filename)
    shutil.copy2(file_path, dst_path)

# Copy validation files
for file_path, label in zip(X_val, y_val):
    filename = os.path.basename(file_path)
    dst_path = os.path.join(val_dir, label, filename)
    shutil.copy2(file_path, dst_path)

print(f"Train set: {len(X_train)} files")
print(f"Val set: {len(X_val)} files")
print("Class distribution in train:", Counter(y_train))
print("Class distribution in val:", Counter(y_val))

# %%
import os
data_dir = '../trainingDatav3'
class_dirs = ["var","yok"]
# Function to rename files in a directory based on their class
def rename_files_by_class(base_dir):
    for split in ['train','val']:
        split_dir = os.path.join(base_dir, split)
        
        for class_name in class_dirs:
            class_dir = os.path.join(split_dir, class_name)
            
            # print(class_dir)
            if os.path.exists(class_dir):
                files = os.listdir(class_dir)
                
                for filename in files:
                    if filename.endswith('.png'):
                        # Get the base name without extension
                        base_name = os.path.splitext(filename)[0]
                        if(base_name.split('_')[-1] == class_name):
                            print(f"Skipping {filename} as it already has the class suffix.")
                            continue
                        # Create new filename with class suffix
                        new_filename = f"{base_name}_{class_name}.png"
                        
                        # Get full paths
                        old_path = os.path.join(class_dir, filename)
                        new_path = os.path.join(class_dir, new_filename)
                        
                        # Rename the file
                        os.rename(old_path, new_path)
                        
                print(f"Renamed files in {class_dir}")

# Rename all files in the training data directory
rename_files_by_class(data_dir)
print("All files have been renamed with their class suffixes.")
# Out:
# Skipping 10002_var.png as it already has the class suffix.
# Skipping 100091_var.png as it already has the class suffix.
# Skipping 10017_var.png as it already has the class suffix.
# Skipping 100236_var.png as it already has the class suffix.
# Skipping 10024_var.png as it already has the class suffix.
# Skipping 10028_var.png as it already has the class suffix.
# Skipping 10033_var.png as it already has the class suffix.
# Skipping 10036_var.png as it already has the class suffix.
# Skipping 10038_var.png as it already has the class suffix.
# Skipping 10045_var.png as it already has the class suffix.
# Skipping 10046_var.png as it already has the class suffix.
# Skipping 10047_var.png as it already has the class suffix.
# Skipping 10049_var.png as it already has the class suffix.
# Skipping 10050_var.png as it already has the class suffix.
# Skipping 10052_var.png as it already has the class suffix.
# Skipping 10053_var.png as it already has the class suffix.
# Skipping 10062_var.png as it already has the class suffix.
# Skipping 10063_var.png as it already has the class suffix.
# Skipping 10067_var.png as it already has the class suffix.
# Skipping 10072_var.png as it already has the class suffix.
# Skipping 10073_var.png as it already has the class suffix.
# Skipping 10075_var.png as it already has the class suffix.
# Skipping 10077_var.png as it already has the class suffix.
# Skipping 10088_var.png as it already has the class suffix.
# Skipping 10094_var.png as it already has the class suffix.
# Skipping 10095_var.png as it already has the class suffix.
# Skipping 10101_var.png as it already has the class suffix.
# Skipping 10105_var.png as it already has the class suffix.
# Skipping 10108_var.png as it already has the class suffix.
# Skipping 10113_var.png as it already has the class suffix.
# Skipping 10120_var.png as it already has the class suffix.
# Skipping 10123_var.png as it already has the class suffix.
# Skipping 101320_var.png as it already has the class suffix.
# Skipping 10143_var.png as it already has the class suffix.
# Skipping 10145_var.png as it already has the class suffix.
# Skipping 10146_var.png as it already has the class suffix.
# Skipping 10150_var.png as it already has the class suffix.
# Skipping 10151_var.png as it already has the class suffix.
# Skipping 10153_var.png as it already has the class suffix.
# Skipping 10154_var.png as it already has the class suffix.
# Skipping 10155_var.png as it already has the class suffix.
# Skipping 10156_var.png as it already has the class suffix.
# Skipping 10158_var.png as it already has the class suffix.
# Skipping 10160_var.png as it already has the class suffix.
# Skipping 10164_var.png as it already has the class suffix.
# Skipping 10179_var.png as it already has the class suffix.
# Skipping 10181_var.png as it already has the class suffix.
# Skipping 10187_var.png as it already has the class suffix.
# Skipping 10190_var.png as it already has the class suffix.
# Skipping 10194_var.png as it already has the class suffix.
# Skipping 10202_var.png as it already has the class suffix.
# Skipping 102032_var.png as it already has the class suffix.
# Skipping 10206_var.png as it already has the class suffix.
# Skipping 10209_var.png as it already has the class suffix.
# Skipping 10210_var.png as it already has the class suffix.
# Skipping 102118_var.png as it already has the class suffix.
# Skipping 10214_var.png as it already has the class suffix.
# Skipping 102158_var.png as it already has the class suffix.
# Skipping 102187_var.png as it already has the class suffix.
# Skipping 10222_var.png as it already has the class suffix.
# Skipping 10223_var.png as it already has the class suffix.
# Skipping 10227_var.png as it already has the class suffix.
# Skipping 102317_var.png as it already has the class suffix.
# Skipping 10236_var.png as it already has the class suffix.
# Skipping 10238_var.png as it already has the class suffix.
# Skipping 10242_var.png as it already has the class suffix.
# Skipping 10245_var.png as it already has the class suffix.
# Skipping 10248_var.png as it already has the class suffix.
# Skipping 10250_var.png as it already has the class suffix.
# Skipping 10253_var.png as it already has the class suffix.
# Skipping 10258_var.png as it already has the class suffix.
# Skipping 10261_var.png as it already has the class suffix.
# Skipping 10262_var.png as it already has the class suffix.
# Skipping 10263_var.png as it already has the class suffix.
# Skipping 10265_var.png as it already has the class suffix.
# Skipping 10268_var.png as it already has the class suffix.
# Skipping 10271_var.png as it already has the class suffix.
# Skipping 10273_var.png as it already has the class suffix.
# Skipping 10276_var.png as it already has the class suffix.
# Skipping 10278_var.png as it already has the class suffix.
# Skipping 10280_var.png as it already has the class suffix.
# Skipping 10289_var.png as it already has the class suffix.
# Skipping 10290_var.png as it already has the class suffix.
# Skipping 10296_var.png as it already has the class suffix.
# Skipping 10297_var.png as it already has the class suffix.
# Skipping 10298_var.png as it already has the class suffix.
# Skipping 103005_var.png as it already has the class suffix.
# Skipping 10305_var.png as it already has the class suffix.
# Skipping 10307_var.png as it already has the class suffix.
# Skipping 10309_var.png as it already has the class suffix.
# Skipping 10310_var.png as it already has the class suffix.
# Skipping 10317_var.png as it already has the class suffix.
# Skipping 10320_var.png as it already has the class suffix.
# Skipping 10323_var.png as it already has the class suffix.
# Skipping 10328_var.png as it already has the class suffix.
# Skipping 10329_var.png as it already has the class suffix.
# Skipping 10331_var.png as it already has the class suffix.
# Skipping 10332_var.png as it already has the class suffix.
# Skipping 103374_var.png as it already has the class suffix.
# Skipping 103462_var.png as it already has the class suffix.
# Skipping 10346_var.png as it already has the class suffix.
# Skipping 10350_var.png as it already has the class suffix.
# Skipping 10354_var.png as it already has the class suffix.
# Skipping 10355_var.png as it already has the class suffix.
# Skipping 10356_var.png as it already has the class suffix.
# Skipping 10362_var.png as it already has the class suffix.
# Skipping 10363_var.png as it already has the class suffix.
# Skipping 10364_var.png as it already has the class suffix.
# Skipping 10367_var.png as it already has the class suffix.
# Skipping 10372_var.png as it already has the class suffix.
# Skipping 10377_var.png as it already has the class suffix.
# Skipping 10378_var.png as it already has the class suffix.
# Skipping 103818_var.png as it already has the class suffix.
# Skipping 10388_var.png as it already has the class suffix.
# Skipping 10391_var.png as it already has the class suffix.
# Skipping 10394_var.png as it already has the class suffix.
# Skipping 10395_var.png as it already has the class suffix.
# Skipping 10397_var.png as it already has the class suffix.
# Skipping 10399_var.png as it already has the class suffix.
# Skipping 10403_var.png as it already has the class suffix.
# Skipping 10404_var.png as it already has the class suffix.
# Skipping 10418_var.png as it already has the class suffix.
# Skipping 10420_var.png as it already has the class suffix.
# Skipping 10430_var.png as it already has the class suffix.
# Skipping 10434_var.png as it already has the class suffix.
# Skipping 10436_var.png as it already has the class suffix.
# Skipping 10438_var.png as it already has the class suffix.
# Skipping 10442_var.png as it already has the class suffix.
# Skipping 10444_var.png as it already has the class suffix.
# Skipping 10446_var.png as it already has the class suffix.
# Skipping 10447_var.png as it already has the class suffix.
# Skipping 10448_var.png as it already has the class suffix.
# Skipping 10449_var.png as it already has the class suffix.
# Skipping 10453_var.png as it already has the class suffix.
# Skipping 104541_var.png as it already has the class suffix.
# Skipping 10459_var.png as it already has the class suffix.
# Skipping 10460_var.png as it already has the class suffix.
# Skipping 10466_var.png as it already has the class suffix.
# Skipping 10475_var.png as it already has the class suffix.
# Skipping 10476_var.png as it already has the class suffix.
# Skipping 10479_var.png as it already has the class suffix.
# Skipping 10481_var.png as it already has the class suffix.
# Skipping 104830_var.png as it already has the class suffix.
# Skipping 10486_var.png as it already has the class suffix.
# Skipping 10487_var.png as it already has the class suffix.
# Skipping 10488_var.png as it already has the class suffix.
# Skipping 104947_var.png as it already has the class suffix.
# Skipping 10507_var.png as it already has the class suffix.
# Skipping 10509_var.png as it already has the class suffix.
# Skipping 10510_var.png as it already has the class suffix.
# Skipping 10513_var.png as it already has the class suffix.
# Skipping 10519_var.png as it already has the class suffix.
# Skipping 10522_var.png as it already has the class suffix.
# Skipping 10532_var.png as it already has the class suffix.
# Skipping 10538_var.png as it already has the class suffix.
# Skipping 10539_var.png as it already has the class suffix.
# Skipping 10542_var.png as it already has the class suffix.
# Skipping 10547_var.png as it already has the class suffix.
# Skipping 10549_var.png as it already has the class suffix.
# Skipping 10555_var.png as it already has the class suffix.
# Skipping 10561_var.png as it already has the class suffix.
# Skipping 10563_var.png as it already has the class suffix.
# Skipping 10567_var.png as it already has the class suffix.
# Skipping 10568_var.png as it already has the class suffix.
# Skipping 10575_var.png as it already has the class suffix.
# Skipping 10579_var.png as it already has the class suffix.
# Skipping 105824_var.png as it already has the class suffix.
# Skipping 10586_var.png as it already has the class suffix.
# Skipping 10594_var.png as it already has the class suffix.
# Skipping 10595_var.png as it already has the class suffix.
# Skipping 10599_var.png as it already has the class suffix.
# Skipping 10600_var.png as it already has the class suffix.
# Skipping 10605_var.png as it already has the class suffix.
# Skipping 10611_var.png as it already has the class suffix.
# Skipping 10613_var.png as it already has the class suffix.
# Skipping 10618_var.png as it already has the class suffix.
# Skipping 10622_var.png as it already has the class suffix.
# Skipping 10635_var.png as it already has the class suffix.
# Skipping 10637_var.png as it already has the class suffix.
# Skipping 106424_var.png as it already has the class suffix.
# Skipping 10645_var.png as it already has the class suffix.
# Skipping 10648_var.png as it already has the class suffix.
# Skipping 10650_var.png as it already has the class suffix.
# Skipping 106569_var.png as it already has the class suffix.
# Skipping 10657_var.png as it already has the class suffix.
# Skipping 10662_var.png as it already has the class suffix.
# Skipping 106646_var.png as it already has the class suffix.
# Skipping 10671_var.png as it already has the class suffix.
# Skipping 10682_var.png as it already has the class suffix.
# Skipping 10687_var.png as it already has the class suffix.
# Skipping 106882_var.png as it already has the class suffix.
# Skipping 10691_var.png as it already has the class suffix.
# Skipping 10694_var.png as it already has the class suffix.
# Skipping 10696_var.png as it already has the class suffix.
# Skipping 10702_var.png as it already has the class suffix.
# Skipping 10703_var.png as it already has the class suffix.
# Skipping 107056_var.png as it already has the class suffix.
# Skipping 10705_var.png as it already has the class suffix.
# Skipping 10712_var.png as it already has the class suffix.
# Skipping 10713_var.png as it already has the class suffix.
# Skipping 10714_var.png as it already has the class suffix.
# Skipping 10715_var.png as it already has the class suffix.
# Skipping 10719_var.png as it already has the class suffix.
# Skipping 10726_var.png as it already has the class suffix.
# Skipping 10729_var.png as it already has the class suffix.
# Skipping 10730_var.png as it already has the class suffix.
# Skipping 10734_var.png as it already has the class suffix.
# Skipping 10736_var.png as it already has the class suffix.
# Skipping 10737_var.png as it already has the class suffix.
# Skipping 10743_var.png as it already has the class suffix.
# Skipping 10745_var.png as it already has the class suffix.
# Skipping 10747_var.png as it already has the class suffix.
# Skipping 107527_var.png as it already has the class suffix.
# Skipping 10755_var.png as it already has the class suffix.
# Skipping 10758_var.png as it already has the class suffix.
# Skipping 10761_var.png as it already has the class suffix.
# Skipping 10766_var.png as it already has the class suffix.
# Skipping 10769_var.png as it already has the class suffix.
# Skipping 10770_var.png as it already has the class suffix.
# Skipping 10771_var.png as it already has the class suffix.
# Skipping 10777_var.png as it already has the class suffix.
# Skipping 10783_var.png as it already has the class suffix.
# Skipping 10786_var.png as it already has the class suffix.
# Skipping 10787_var.png as it already has the class suffix.
# Skipping 10788_var.png as it already has the class suffix.
# Skipping 10791_var.png as it already has the class suffix.
# Skipping 10793_var.png as it already has the class suffix.
# Skipping 10796_var.png as it already has the class suffix.
# Skipping 10797_var.png as it already has the class suffix.
# Skipping 10806_var.png as it already has the class suffix.
# Skipping 10808_var.png as it already has the class suffix.
# Skipping 10809_var.png as it already has the class suffix.
# Skipping 108126_var.png as it already has the class suffix.
# Skipping 10814_var.png as it already has the class suffix.
# Skipping 10815_var.png as it already has the class suffix.
# Skipping 10816_var.png as it already has the class suffix.
# Skipping 10820_var.png as it already has the class suffix.
# Skipping 10830_var.png as it already has the class suffix.
# Skipping 10846_var.png as it already has the class suffix.
# Skipping 10850_var.png as it already has the class suffix.
# Skipping 10852_var.png as it already has the class suffix.
# Skipping 10853_var.png as it already has the class suffix.
# Skipping 10858_var.png as it already has the class suffix.
# Skipping 10859_var.png as it already has the class suffix.
# Skipping 10865_var.png as it already has the class suffix.
# Skipping 10866_var.png as it already has the class suffix.
# Skipping 10868_var.png as it already has the class suffix.
# Skipping 10870_var.png as it already has the class suffix.
# Skipping 10871_var.png as it already has the class suffix.
# Skipping 10872_var.png as it already has the class suffix.
# Skipping 10876_var.png as it already has the class suffix.
# Skipping 10877_var.png as it already has the class suffix.
# Skipping 10878_var.png as it already has the class suffix.
# Skipping 10884_var.png as it already has the class suffix.
# Skipping 10887_var.png as it already has the class suffix.
# Skipping 10888_var.png as it already has the class suffix.
# Skipping 10889_var.png as it already has the class suffix.
# Skipping 10893_var.png as it already has the class suffix.
# Skipping 10894_var.png as it already has the class suffix.
# Skipping 10898_var.png as it already has the class suffix.
# Skipping 10907_var.png as it already has the class suffix.
# Skipping 10908_var.png as it already has the class suffix.
# Skipping 10921_var.png as it already has the class suffix.
# Skipping 10925_var.png as it already has the class suffix.
# Skipping 10926_var.png as it already has the class suffix.
# Skipping 10928_var.png as it already has the class suffix.
# Skipping 10931_var.png as it already has the class suffix.
# Skipping 10933_var.png as it already has the class suffix.
# Skipping 10937_var.png as it already has the class suffix.
# Skipping 10941_var.png as it already has the class suffix.
# Skipping 109432_var.png as it already has the class suffix.
# Skipping 10943_var.png as it already has the class suffix.
# Skipping 109480_var.png as it already has the class suffix.
# Skipping 10951_var.png as it already has the class suffix.
# Skipping 10952_var.png as it already has the class suffix.
# Skipping 10954_var.png as it already has the class suffix.
# Skipping 10956_var.png as it already has the class suffix.
# Skipping 10959_var.png as it already has the class suffix.
# Skipping 10960_var.png as it already has the class suffix.
# Skipping 10961_var.png as it already has the class suffix.
# Skipping 10962_var.png as it already has the class suffix.
# Skipping 10963_var.png as it already has the class suffix.
# Skipping 10967_var.png as it already has the class suffix.
# Skipping 10977_var.png as it already has the class suffix.
# Skipping 10980_var.png as it already has the class suffix.
# Skipping 10981_var.png as it already has the class suffix.
# Skipping 10984_var.png as it already has the class suffix.
# Skipping 10985_var.png as it already has the class suffix.
# Skipping 10986_var.png as it already has the class suffix.
# Skipping 10987_var.png as it already has the class suffix.
# Skipping 10989_var.png as it already has the class suffix.
# Skipping 10990_var.png as it already has the class suffix.
# Skipping 10992_var.png as it already has the class suffix.
# Skipping 10997_var.png as it already has the class suffix.
# Skipping 109992_var.png as it already has the class suffix.
# Skipping 11004_var.png as it already has the class suffix.
# Skipping 110073_var.png as it already has the class suffix.
# Skipping 11007_var.png as it already has the class suffix.
# Skipping 11008_var.png as it already has the class suffix.
# Skipping 11010_var.png as it already has the class suffix.
# Skipping 11016_var.png as it already has the class suffix.
# Skipping 11019_var.png as it already has the class suffix.
# Skipping 11020_var.png as it already has the class suffix.
# Skipping 11021_var.png as it already has the class suffix.
# Skipping 11028_var.png as it already has the class suffix.
# Skipping 110300_var.png as it already has the class suffix.
# Skipping 11033_var.png as it already has the class suffix.
# Skipping 11036_var.png as it already has the class suffix.
# Skipping 11039_var.png as it already has the class suffix.
# Skipping 11041_var.png as it already has the class suffix.
# Skipping 11046_var.png as it already has the class suffix.
# Skipping 11048_var.png as it already has the class suffix.
# Skipping 11049_var.png as it already has the class suffix.
# Skipping 11055_var.png as it already has the class suffix.
# Skipping 11059_var.png as it already has the class suffix.
# Skipping 110647_var.png as it already has the class suffix.
# Skipping 11065_var.png as it already has the class suffix.
# Skipping 11086_var.png as it already has the class suffix.
# Skipping 11090_var.png as it already has the class suffix.
# Skipping 11091_var.png as it already has the class suffix.
# Skipping 11103_var.png as it already has the class suffix.
# Skipping 11106_var.png as it already has the class suffix.
# Skipping 11112_var.png as it already has the class suffix.
# Skipping 11113_var.png as it already has the class suffix.
# Skipping 11115_var.png as it already has the class suffix.
# Skipping 11117_var.png as it already has the class suffix.
# Skipping 11118_var.png as it already has the class suffix.
# Skipping 11123_var.png as it already has the class suffix.
# Skipping 11124_var.png as it already has the class suffix.
# Skipping 11128_var.png as it already has the class suffix.
# Skipping 11134_var.png as it already has the class suffix.
# Skipping 11136_var.png as it already has the class suffix.
# Skipping 11137_var.png as it already has the class suffix.
# Skipping 11139_var.png as it already has the class suffix.
# Skipping 11143_var.png as it already has the class suffix.
# Skipping 111446_var.png as it already has the class suffix.
# Skipping 11145_var.png as it already has the class suffix.
# Skipping 11151_var.png as it already has the class suffix.
# Skipping 11153_var.png as it already has the class suffix.
# Skipping 11154_var.png as it already has the class suffix.
# Skipping 11156_var.png as it already has the class suffix.
# Skipping 11159_var.png as it already has the class suffix.
# Skipping 11161_var.png as it already has the class suffix.
# Skipping 11162_var.png as it already has the class suffix.
# Skipping 11166_var.png as it already has the class suffix.
# Skipping 11170_var.png as it already has the class suffix.
# Skipping 11171_var.png as it already has the class suffix.
# Skipping 11179_var.png as it already has the class suffix.
# Skipping 11180_var.png as it already has the class suffix.
# Skipping 11181_var.png as it already has the class suffix.
# Skipping 11183_var.png as it already has the class suffix.
# Skipping 11184_var.png as it already has the class suffix.
# Skipping 11193_var.png as it already has the class suffix.
# Skipping 11195_var.png as it already has the class suffix.
# Skipping 11197_var.png as it already has the class suffix.
# Skipping 11200_var.png as it already has the class suffix.
# Skipping 11202_var.png as it already has the class suffix.
# Skipping 11206_var.png as it already has the class suffix.
# Skipping 11208_var.png as it already has the class suffix.
# Skipping 11209_var.png as it already has the class suffix.
# Skipping 112193_var.png as it already has the class suffix.
# Skipping 11220_var.png as it already has the class suffix.
# Skipping 11224_var.png as it already has the class suffix.
# Skipping 11225_var.png as it already has the class suffix.
# Skipping 11226_var.png as it already has the class suffix.
# Skipping 11227_var.png as it already has the class suffix.
# Skipping 11230_var.png as it already has the class suffix.
# Skipping 11233_var.png as it already has the class suffix.
# Skipping 11235_var.png as it already has the class suffix.
# Skipping 11237_var.png as it already has the class suffix.
# Skipping 11238_var.png as it already has the class suffix.
# Skipping 11243_var.png as it already has the class suffix.
# Skipping 11250_var.png as it already has the class suffix.
# Skipping 11254_var.png as it already has the class suffix.
# Skipping 11257_var.png as it already has the class suffix.
# Skipping 11260_var.png as it already has the class suffix.
# Skipping 11266_var.png as it already has the class suffix.
# Skipping 11267_var.png as it already has the class suffix.
# Skipping 11271_var.png as it already has the class suffix.
# Skipping 11272_var.png as it already has the class suffix.
# Skipping 11279_var.png as it already has the class suffix.
# Skipping 11282_var.png as it already has the class suffix.
# Skipping 11284_var.png as it already has the class suffix.
# Skipping 11285_var.png as it already has the class suffix.
# Skipping 11294_var.png as it already has the class suffix.
# Skipping 11296_var.png as it already has the class suffix.
# Skipping 11299_var.png as it already has the class suffix.
# Skipping 11300_var.png as it already has the class suffix.
# Skipping 113019_var.png as it already has the class suffix.
# Skipping 11301_var.png as it already has the class suffix.
# Skipping 11303_var.png as it already has the class suffix.
# Skipping 113091_var.png as it already has the class suffix.
# Skipping 11312_var.png as it already has the class suffix.
# Skipping 11314_var.png as it already has the class suffix.
# Skipping 11315_var.png as it already has the class suffix.
# Skipping 11316_var.png as it already has the class suffix.
# Skipping 11321_var.png as it already has the class suffix.
# Skipping 113227_var.png as it already has the class suffix.
# Skipping 11323_var.png as it already has the class suffix.
# Skipping 11326_var.png as it already has the class suffix.
# Skipping 11327_var.png as it already has the class suffix.
# Skipping 11331_var.png as it already has the class suffix.
# Skipping 11333_var.png as it already has the class suffix.
# Skipping 11335_var.png as it already has the class suffix.
# Skipping 11337_var.png as it already has the class suffix.
# Skipping 11340_var.png as it already has the class suffix.
# Skipping 11350_var.png as it already has the class suffix.
# Skipping 11352_var.png as it already has the class suffix.
# Skipping 11353_var.png as it already has the class suffix.
# Skipping 11355_var.png as it already has the class suffix.
# Skipping 11359_var.png as it already has the class suffix.
# Skipping 11364_var.png as it already has the class suffix.
# Skipping 11375_var.png as it already has the class suffix.
# Skipping 11377_var.png as it already has the class suffix.
# Skipping 11380_var.png as it already has the class suffix.
# Skipping 11386_var.png as it already has the class suffix.
# Skipping 11390_var.png as it already has the class suffix.
# Skipping 11393_var.png as it already has the class suffix.
# Skipping 113946_var.png as it already has the class suffix.
# Skipping 11394_var.png as it already has the class suffix.
# Skipping 11399_var.png as it already has the class suffix.
# Skipping 11400_var.png as it already has the class suffix.
# Skipping 11403_var.png as it already has the class suffix.
# Skipping 11412_var.png as it already has the class suffix.
# Skipping 11415_var.png as it already has the class suffix.
# Skipping 11417_var.png as it already has the class suffix.
# Skipping 11420_var.png as it already has the class suffix.
# Skipping 11424_var.png as it already has the class suffix.
# Skipping 11425_var.png as it already has the class suffix.
# Skipping 11427_var.png as it already has the class suffix.
# Skipping 11432_var.png as it already has the class suffix.
# Skipping 11433_var.png as it already has the class suffix.
# Skipping 114408_var.png as it already has the class suffix.
# Skipping 114508_var.png as it already has the class suffix.
# Skipping 11457_var.png as it already has the class suffix.
# Skipping 11462_var.png as it already has the class suffix.
# Skipping 11466_var.png as it already has the class suffix.
# Skipping 11478_var.png as it already has the class suffix.
# Skipping 11480_var.png as it already has the class suffix.
# Skipping 11483_var.png as it already has the class suffix.
# Skipping 11485_var.png as it already has the class suffix.
# Skipping 11490_var.png as it already has the class suffix.
# Skipping 11491_var.png as it already has the class suffix.
# Skipping 11498_var.png as it already has the class suffix.
# Skipping 11501_var.png as it already has the class suffix.
# Skipping 11506_var.png as it already has the class suffix.
# Skipping 115070_var.png as it already has the class suffix.
# Skipping 11510_var.png as it already has the class suffix.
# Skipping 11516_var.png as it already has the class suffix.
# Skipping 11518_var.png as it already has the class suffix.
# Skipping 11522_var.png as it already has the class suffix.
# Skipping 11523_var.png as it already has the class suffix.
# Skipping 115328_var.png as it already has the class suffix.
# Skipping 115336_var.png as it already has the class suffix.
# Skipping 11534_var.png as it already has the class suffix.
# Skipping 11535_var.png as it already has the class suffix.
# Skipping 11536_var.png as it already has the class suffix.
# Skipping 11545_var.png as it already has the class suffix.
# Skipping 11547_var.png as it already has the class suffix.
# Skipping 11548_var.png as it already has the class suffix.
# Skipping 11551_var.png as it already has the class suffix.
# Skipping 11552_var.png as it already has the class suffix.
# Skipping 11554_var.png as it already has the class suffix.
# Skipping 11560_var.png as it already has the class suffix.
# Skipping 11561_var.png as it already has the class suffix.
# Skipping 11562_var.png as it already has the class suffix.
# Skipping 11567_var.png as it already has the class suffix.
# Skipping 11569_var.png as it already has the class suffix.
# Skipping 11570_var.png as it already has the class suffix.
# Skipping 11574_var.png as it already has the class suffix.
# Skipping 11579_var.png as it already has the class suffix.
# Skipping 11580_var.png as it already has the class suffix.
# Skipping 11587_var.png as it already has the class suffix.
# Skipping 11592_var.png as it already has the class suffix.
# Skipping 11597_var.png as it already has the class suffix.
# Skipping 11598_var.png as it already has the class suffix.
# Skipping 11600_var.png as it already has the class suffix.
# Skipping 11615_var.png as it already has the class suffix.
# Skipping 11617_var.png as it already has the class suffix.
# Skipping 11622_var.png as it already has the class suffix.
# Skipping 11626_var.png as it already has the class suffix.
# Skipping 11629_var.png as it already has the class suffix.
# Skipping 11635_var.png as it already has the class suffix.
# Skipping 11636_var.png as it already has the class suffix.
# Skipping 11638_var.png as it already has the class suffix.
# Skipping 11639_var.png as it already has the class suffix.
# Skipping 11640_var.png as it already has the class suffix.
# Skipping 11649_var.png as it already has the class suffix.
# Skipping 116509_var.png as it already has the class suffix.
# Skipping 11650_var.png as it already has the class suffix.
# Skipping 11653_var.png as it already has the class suffix.
# Skipping 11655_var.png as it already has the class suffix.
# Skipping 11657_var.png as it already has the class suffix.
# Skipping 11659_var.png as it already has the class suffix.
# Skipping 11662_var.png as it already has the class suffix.
# Skipping 11663_var.png as it already has the class suffix.
# Skipping 11671_var.png as it already has the class suffix.
# Skipping 11674_var.png as it already has the class suffix.
# Skipping 11677_var.png as it already has the class suffix.
# Skipping 11680_var.png as it already has the class suffix.
# Skipping 11683_var.png as it already has the class suffix.
# Skipping 11685_var.png as it already has the class suffix.
# Skipping 11686_var.png as it already has the class suffix.
# Skipping 11687_var.png as it already has the class suffix.
# Skipping 11689_var.png as it already has the class suffix.
# Skipping 11693_var.png as it already has the class suffix.
# Skipping 116946_var.png as it already has the class suffix.
# Skipping 11695_var.png as it already has the class suffix.
# Skipping 11698_var.png as it already has the class suffix.
# Skipping 11701_var.png as it already has the class suffix.
# Skipping 11704_var.png as it already has the class suffix.
# Skipping 11716_var.png as it already has the class suffix.
# Skipping 11720_var.png as it already has the class suffix.
# Skipping 11721_var.png as it already has the class suffix.
# Skipping 117238_var.png as it already has the class suffix.
# Skipping 11723_var.png as it already has the class suffix.
# Skipping 11726_var.png as it already has the class suffix.
# Skipping 11729_var.png as it already has the class suffix.
# Skipping 11730_var.png as it already has the class suffix.
# Skipping 11733_var.png as it already has the class suffix.
# Skipping 11735_var.png as it already has the class suffix.
# Skipping 11743_var.png as it already has the class suffix.
# Skipping 11749_var.png as it already has the class suffix.
# Skipping 11756_var.png as it already has the class suffix.
# Skipping 11761_var.png as it already has the class suffix.
# Skipping 117662_var.png as it already has the class suffix.
# Skipping 11766_var.png as it already has the class suffix.
# Skipping 11767_var.png as it already has the class suffix.
# Skipping 11768_var.png as it already has the class suffix.
# Skipping 11772_var.png as it already has the class suffix.
# Skipping 11773_var.png as it already has the class suffix.
# Skipping 11774_var.png as it already has the class suffix.
# Skipping 11781_var.png as it already has the class suffix.
# Skipping 11789_var.png as it already has the class suffix.
# Skipping 11790_var.png as it already has the class suffix.
# Skipping 11794_var.png as it already has the class suffix.
# Skipping 11797_var.png as it already has the class suffix.
# Skipping 11798_var.png as it already has the class suffix.
# Skipping 11799_var.png as it already has the class suffix.
# Skipping 11803_var.png as it already has the class suffix.
# Skipping 11805_var.png as it already has the class suffix.
# Skipping 11810_var.png as it already has the class suffix.
# Skipping 11812_var.png as it already has the class suffix.
# Skipping 11813_var.png as it already has the class suffix.
# Skipping 11814_var.png as it already has the class suffix.
# Skipping 11817_var.png as it already has the class suffix.
# Skipping 11821_var.png as it already has the class suffix.
# Skipping 11829_var.png as it already has the class suffix.
# Skipping 11830_var.png as it already has the class suffix.
# Skipping 11832_var.png as it already has the class suffix.
# Skipping 11834_var.png as it already has the class suffix.
# Skipping 11845_var.png as it already has the class suffix.
# Skipping 11858_var.png as it already has the class suffix.
# Skipping 11860_var.png as it already has the class suffix.
# Skipping 11866_var.png as it already has the class suffix.
# Skipping 11868_var.png as it already has the class suffix.
# Skipping 11871_var.png as it already has the class suffix.
# Skipping 11879_var.png as it already has the class suffix.
# Skipping 11896_var.png as it already has the class suffix.
# Skipping 11900_var.png as it already has the class suffix.
# Skipping 119015_var.png as it already has the class suffix.
# Skipping 11905_var.png as it already has the class suffix.
# Skipping 11906_var.png as it already has the class suffix.
# Skipping 11911_var.png as it already has the class suffix.
# Skipping 11919_var.png as it already has the class suffix.
# Skipping 11930_var.png as it already has the class suffix.
# Skipping 119323_var.png as it already has the class suffix.
# Skipping 11933_var.png as it already has the class suffix.
# Skipping 11936_var.png as it already has the class suffix.
# Skipping 119384_var.png as it already has the class suffix.
# Skipping 11942_var.png as it already has the class suffix.
# Skipping 11946_var.png as it already has the class suffix.
# Skipping 119506_var.png as it already has the class suffix.
# Skipping 119527_var.png as it already has the class suffix.
# Skipping 11952_var.png as it already has the class suffix.
# Skipping 11955_var.png as it already has the class suffix.
# Skipping 11956_var.png as it already has the class suffix.
# Skipping 119707_var.png as it already has the class suffix.
# Skipping 11973_var.png as it already has the class suffix.
# Skipping 11975_var.png as it already has the class suffix.
# Skipping 11981_var.png as it already has the class suffix.
# Skipping 11987_var.png as it already has the class suffix.
# Skipping 11990_var.png as it already has the class suffix.
# Skipping 11992_var.png as it already has the class suffix.
# Skipping 11994_var.png as it already has the class suffix.
# Skipping 11998_var.png as it already has the class suffix.
# Skipping 12001_var.png as it already has the class suffix.
# Skipping 12002_var.png as it already has the class suffix.
# Skipping 12006_var.png as it already has the class suffix.
# Skipping 12016_var.png as it already has the class suffix.
# Skipping 12019_var.png as it already has the class suffix.
# Skipping 120205_var.png as it already has the class suffix.
# Skipping 12021_var.png as it already has the class suffix.
# Skipping 12025_var.png as it already has the class suffix.
# Skipping 12032_var.png as it already has the class suffix.
# Skipping 12033_var.png as it already has the class suffix.
# Skipping 12035_var.png as it already has the class suffix.
# Skipping 12046_var.png as it already has the class suffix.
# Skipping 12048_var.png as it already has the class suffix.
# Skipping 12059_var.png as it already has the class suffix.
# Skipping 12062_var.png as it already has the class suffix.
# Skipping 12063_var.png as it already has the class suffix.
# Skipping 12064_var.png as it already has the class suffix.
# Skipping 120654_var.png as it already has the class suffix.
# Skipping 12067_var.png as it already has the class suffix.
# Skipping 12070_var.png as it already has the class suffix.
# Skipping 12075_var.png as it already has the class suffix.
# Skipping 12076_var.png as it already has the class suffix.
# Skipping 12080_var.png as it already has the class suffix.
# Skipping 12087_var.png as it already has the class suffix.
# Skipping 12090_var.png as it already has the class suffix.
# Skipping 12092_var.png as it already has the class suffix.
# Skipping 120953_var.png as it already has the class suffix.
# Skipping 12095_var.png as it already has the class suffix.
# Skipping 12105_var.png as it already has the class suffix.
# Skipping 121105_var.png as it already has the class suffix.
# Skipping 12111_var.png as it already has the class suffix.
# Skipping 12112_var.png as it already has the class suffix.
# Skipping 12118_var.png as it already has the class suffix.
# Skipping 12119_var.png as it already has the class suffix.
# Skipping 12125_var.png as it already has the class suffix.
# Skipping 12127_var.png as it already has the class suffix.
# Skipping 12134_var.png as it already has the class suffix.
# Skipping 12135_var.png as it already has the class suffix.
# Skipping 121392_var.png as it already has the class suffix.
# Skipping 12141_var.png as it already has the class suffix.
# Skipping 12152_var.png as it already has the class suffix.
# Skipping 12156_var.png as it already has the class suffix.
# Skipping 12159_var.png as it already has the class suffix.
# Skipping 121643_var.png as it already has the class suffix.
# Skipping 12165_var.png as it already has the class suffix.
# Skipping 12168_var.png as it already has the class suffix.
# Skipping 12169_var.png as it already has the class suffix.
# Skipping 12172_var.png as it already has the class suffix.
# Skipping 12173_var.png as it already has the class suffix.
# Skipping 121750_var.png as it already has the class suffix.
# Skipping 12175_var.png as it already has the class suffix.
# Skipping 12179_var.png as it already has the class suffix.
# Skipping 12187_var.png as it already has the class suffix.
# Skipping 12191_var.png as it already has the class suffix.
# Skipping 12193_var.png as it already has the class suffix.
# Skipping 12206_var.png as it already has the class suffix.
# Skipping 122092_var.png as it already has the class suffix.
# Skipping 12214_var.png as it already has the class suffix.
# Skipping 12217_var.png as it already has the class suffix.
# Skipping 122220_var.png as it already has the class suffix.
# Skipping 12229_var.png as it already has the class suffix.
# Skipping 12231_var.png as it already has the class suffix.
# Skipping 12240_var.png as it already has the class suffix.
# Skipping 12241_var.png as it already has the class suffix.
# Skipping 12242_var.png as it already has the class suffix.
# Skipping 12243_var.png as it already has the class suffix.
# Skipping 12262_var.png as it already has the class suffix.
# Skipping 12264_var.png as it already has the class suffix.
# Skipping 122657_var.png as it already has the class suffix.
# Skipping 12266_var.png as it already has the class suffix.
# Skipping 12271_var.png as it already has the class suffix.
# Skipping 12274_var.png as it already has the class suffix.
# Skipping 12275_var.png as it already has the class suffix.
# Skipping 12276_var.png as it already has the class suffix.
# Skipping 12278_var.png as it already has the class suffix.
# Skipping 12281_var.png as it already has the class suffix.
# Skipping 12283_var.png as it already has the class suffix.
# Skipping 12284_var.png as it already has the class suffix.
# Skipping 12287_var.png as it already has the class suffix.
# Skipping 12291_var.png as it already has the class suffix.
# Skipping 12298_var.png as it already has the class suffix.
# Skipping 12299_var.png as it already has the class suffix.
# Skipping 12301_var.png as it already has the class suffix.
# Skipping 12303_var.png as it already has the class suffix.
# Skipping 123045_var.png as it already has the class suffix.
# Skipping 12306_var.png as it already has the class suffix.
# Skipping 12307_var.png as it already has the class suffix.
# Skipping 12309_var.png as it already has the class suffix.
# Skipping 12312_var.png as it already has the class suffix.
# Skipping 12315_var.png as it already has the class suffix.
# Skipping 12318_var.png as it already has the class suffix.
# Skipping 123248_var.png as it already has the class suffix.
# Skipping 12324_var.png as it already has the class suffix.
# Skipping 12325_var.png as it already has the class suffix.
# Skipping 12333_var.png as it already has the class suffix.
# Skipping 12339_var.png as it already has the class suffix.
# Skipping 12341_var.png as it already has the class suffix.
# Skipping 123434_var.png as it already has the class suffix.
# Skipping 12343_var.png as it already has the class suffix.
# Skipping 12346_var.png as it already has the class suffix.
# Skipping 12348_var.png as it already has the class suffix.
# Skipping 12351_var.png as it already has the class suffix.
# Skipping 12356_var.png as it already has the class suffix.
# Skipping 12358_var.png as it already has the class suffix.
# Skipping 12361_var.png as it already has the class suffix.
# Skipping 12363_var.png as it already has the class suffix.
# Skipping 12364_var.png as it already has the class suffix.
# Skipping 12365_var.png as it already has the class suffix.
# Skipping 12370_var.png as it already has the class suffix.
# Skipping 12371_var.png as it already has the class suffix.
# Skipping 12374_var.png as it already has the class suffix.
# Skipping 123773_var.png as it already has the class suffix.
# Skipping 12380_var.png as it already has the class suffix.
# Skipping 12381_var.png as it already has the class suffix.
# Skipping 12384_var.png as it already has the class suffix.
# Skipping 12386_var.png as it already has the class suffix.
# Skipping 12388_var.png as it already has the class suffix.
# Skipping 12390_var.png as it already has the class suffix.
# Skipping 12395_var.png as it already has the class suffix.
# Skipping 12404_var.png as it already has the class suffix.
# Skipping 12405_var.png as it already has the class suffix.
# Skipping 12409_var.png as it already has the class suffix.
# Skipping 12412_var.png as it already has the class suffix.
# Skipping 12413_var.png as it already has the class suffix.
# Skipping 12414_var.png as it already has the class suffix.
# Skipping 12420_var.png as it already has the class suffix.
# Skipping 12422_var.png as it already has the class suffix.
# Skipping 12423_var.png as it already has the class suffix.
# Skipping 12428_var.png as it already has the class suffix.
# Skipping 124323_var.png as it already has the class suffix.
# Skipping 12434_var.png as it already has the class suffix.
# Skipping 12443_var.png as it already has the class suffix.
# Skipping 12446_var.png as it already has the class suffix.
# Skipping 12453_var.png as it already has the class suffix.
# Skipping 12454_var.png as it already has the class suffix.
# Skipping 12455_var.png as it already has the class suffix.
# Skipping 12459_var.png as it already has the class suffix.
# Skipping 12463_var.png as it already has the class suffix.
# Skipping 12465_var.png as it already has the class suffix.
# Skipping 12467_var.png as it already has the class suffix.
# Skipping 12470_var.png as it already has the class suffix.
# Skipping 12471_var.png as it already has the class suffix.
# Skipping 12472_var.png as it already has the class suffix.
# Skipping 12473_var.png as it already has the class suffix.
# Skipping 12477_var.png as it already has the class suffix.
# Skipping 124807_var.png as it already has the class suffix.
# Skipping 12486_var.png as it already has the class suffix.
# Skipping 12492_var.png as it already has the class suffix.
# Skipping 12497_var.png as it already has the class suffix.
# Skipping 12499_var.png as it already has the class suffix.
# Skipping 12500_var.png as it already has the class suffix.
# Skipping 12503_var.png as it already has the class suffix.
# Skipping 12510_var.png as it already has the class suffix.
# Skipping 12512_var.png as it already has the class suffix.
# Skipping 12519_var.png as it already has the class suffix.
# Skipping 12521_var.png as it already has the class suffix.
# Skipping 12523_var.png as it already has the class suffix.
# Skipping 12526_var.png as it already has the class suffix.
# Skipping 12527_var.png as it already has the class suffix.
# Skipping 12529_var.png as it already has the class suffix.
# Skipping 125335_var.png as it already has the class suffix.
# Skipping 12537_var.png as it already has the class suffix.
# Skipping 12539_var.png as it already has the class suffix.
# Skipping 12541_var.png as it already has the class suffix.
# Skipping 12544_var.png as it already has the class suffix.
# Skipping 12547_var.png as it already has the class suffix.
# Skipping 12548_var.png as it already has the class suffix.
# Skipping 12552_var.png as it already has the class suffix.
# Skipping 12554_var.png as it already has the class suffix.
# Skipping 12561_var.png as it already has the class suffix.
# Skipping 12563_var.png as it already has the class suffix.
# Skipping 12567_var.png as it already has the class suffix.
# Skipping 12576_var.png as it already has the class suffix.
# Skipping 12582_var.png as it already has the class suffix.
# Skipping 12583_var.png as it already has the class suffix.
# Skipping 12585_var.png as it already has the class suffix.
# Skipping 12587_var.png as it already has the class suffix.
# Skipping 12589_var.png as it already has the class suffix.
# Skipping 125935_var.png as it already has the class suffix.
# Skipping 12604_var.png as it already has the class suffix.
# Skipping 12606_var.png as it already has the class suffix.
# Skipping 12608_var.png as it already has the class suffix.
# Skipping 12609_var.png as it already has the class suffix.
# Skipping 12614_var.png as it already has the class suffix.
# Skipping 12617_var.png as it already has the class suffix.
# Skipping 12618_var.png as it already has the class suffix.
# Skipping 12619_var.png as it already has the class suffix.
# Skipping 126208_var.png as it already has the class suffix.
# Skipping 12621_var.png as it already has the class suffix.
# Skipping 12624_var.png as it already has the class suffix.
# Skipping 126289_var.png as it already has the class suffix.
# Skipping 12628_var.png as it already has the class suffix.
# Skipping 12630_var.png as it already has the class suffix.
# Skipping 12632_var.png as it already has the class suffix.
# Skipping 12641_var.png as it already has the class suffix.
# Skipping 126423_var.png as it already has the class suffix.
# Skipping 12642_var.png as it already has the class suffix.
# Skipping 12650_var.png as it already has the class suffix.
# Skipping 12651_var.png as it already has the class suffix.
# Skipping 12654_var.png as it already has the class suffix.
# Skipping 12656_var.png as it already has the class suffix.
# Skipping 12658_var.png as it already has the class suffix.
# Skipping 12659_var.png as it already has the class suffix.
# Skipping 12660_var.png as it already has the class suffix.
# Skipping 12666_var.png as it already has the class suffix.
# Skipping 12677_var.png as it already has the class suffix.
# Skipping 12679_var.png as it already has the class suffix.
# Skipping 126819_var.png as it already has the class suffix.
# Skipping 126829_var.png as it already has the class suffix.
# Skipping 12683_var.png as it already has the class suffix.
# Skipping 12684_var.png as it already has the class suffix.
# Skipping 12688_var.png as it already has the class suffix.
# Skipping 12694_var.png as it already has the class suffix.
# Skipping 12695_var.png as it already has the class suffix.
# Skipping 12696_var.png as it already has the class suffix.
# Skipping 12697_var.png as it already has the class suffix.
# Skipping 12698_var.png as it already has the class suffix.
# Skipping 12699_var.png as it already has the class suffix.
# Skipping 12701_var.png as it already has the class suffix.
# Skipping 12703_var.png as it already has the class suffix.
# Skipping 12711_var.png as it already has the class suffix.
# Skipping 12712_var.png as it already has the class suffix.
# Skipping 12714_var.png as it already has the class suffix.
# Skipping 12716_var.png as it already has the class suffix.
# Skipping 12717_var.png as it already has the class suffix.
# Skipping 12719_var.png as it already has the class suffix.
# ...
# Skipping 189172_yok.png as it already has the class suffix.
# Skipping 189190_yok.png as it already has the class suffix.
# Skipping 189517_yok.png as it already has the class suffix.
# Skipping 189687_yok.png as it already has the class suffix.
# Skipping 190270_yok.png as it already has the class suffix.
# Skipping 190486_yok.png as it already has the class suffix.
# Skipping 190503_yok.png as it already has the class suffix.
# Skipping 191115_yok.png as it already has the class suffix.
# Skipping 191178_yok.png as it already has the class suffix.
# Skipping 191203_yok.png as it already has the class suffix.
# Skipping 191636_yok.png as it already has the class suffix.
# Skipping 191730_yok.png as it already has the class suffix.
# Skipping 191974_yok.png as it already has the class suffix.
# Skipping 191978_yok.png as it already has the class suffix.
# Skipping 192070_yok.png as it already has the class suffix.
# Skipping 192195_yok.png as it already has the class suffix.
# Skipping 192277_yok.png as it already has the class suffix.
# Skipping 192410_yok.png as it already has the class suffix.
# Skipping 192422_yok.png as it already has the class suffix.
# Skipping 193262_yok.png as it already has the class suffix.
# Skipping 193460_yok.png as it already has the class suffix.
# Skipping 193467_yok.png as it already has the class suffix.
# Skipping 193468_yok.png as it already has the class suffix.
# Skipping 193651_yok.png as it already has the class suffix.
# Skipping 193861_yok.png as it already has the class suffix.
# Skipping 194209_yok.png as it already has the class suffix.
# Skipping 194267_yok.png as it already has the class suffix.
# Skipping 194547_yok.png as it already has the class suffix.
# Skipping 195022_yok.png as it already has the class suffix.
# Skipping 195137_yok.png as it already has the class suffix.
# Skipping 195693_yok.png as it already has the class suffix.
# Skipping 195983_yok.png as it already has the class suffix.
# Skipping 196113_yok.png as it already has the class suffix.
# Skipping 196143_yok.png as it already has the class suffix.
# Skipping 196767_yok.png as it already has the class suffix.
# Skipping 197471_yok.png as it already has the class suffix.
# Skipping 197567_yok.png as it already has the class suffix.
# Skipping 197829_yok.png as it already has the class suffix.
# Skipping 197864_yok.png as it already has the class suffix.
# Skipping 197910_yok.png as it already has the class suffix.
# Skipping 198263_yok.png as it already has the class suffix.
# Skipping 198514_yok.png as it already has the class suffix.
# Skipping 198708_yok.png as it already has the class suffix.
# Skipping 198731_yok.png as it already has the class suffix.
# Skipping 198796_yok.png as it already has the class suffix.
# Skipping 198962_yok.png as it already has the class suffix.
# Skipping 199002_yok.png as it already has the class suffix.
# Skipping 200340_yok.png as it already has the class suffix.
# Skipping 200821_yok.png as it already has the class suffix.
# Skipping 201221_yok.png as it already has the class suffix.
# Skipping 201320_yok.png as it already has the class suffix.
# Skipping 201446_yok.png as it already has the class suffix.
# Skipping 202120_yok.png as it already has the class suffix.
# Skipping 202589_yok.png as it already has the class suffix.
# Skipping 203011_yok.png as it already has the class suffix.
# Skipping 203952_yok.png as it already has the class suffix.
# Skipping 204783_yok.png as it already has the class suffix.
# Skipping 205164_yok.png as it already has the class suffix.
# Skipping 205593_yok.png as it already has the class suffix.
# Skipping 206085_yok.png as it already has the class suffix.
# Skipping 208407_yok.png as it already has the class suffix.
# Skipping 208758_yok.png as it already has the class suffix.
# Skipping 209448_yok.png as it already has the class suffix.
# Skipping 210486_yok.png as it already has the class suffix.
# Skipping 210656_yok.png as it already has the class suffix.
# Skipping 211342_yok.png as it already has the class suffix.
# Skipping 212376_yok.png as it already has the class suffix.
# Skipping 212478_yok.png as it already has the class suffix.
# Skipping 213302_yok.png as it already has the class suffix.
# Skipping 213547_yok.png as it already has the class suffix.
# Skipping 214284_yok.png as it already has the class suffix.
# Skipping 214774_yok.png as it already has the class suffix.
# Skipping 215907_yok.png as it already has the class suffix.
# Skipping 216398_yok.png as it already has the class suffix.
# Skipping 216539_yok.png as it already has the class suffix.
# Skipping 216853_yok.png as it already has the class suffix.
# Skipping 217068_yok.png as it already has the class suffix.
# Skipping 217587_yok.png as it already has the class suffix.
# Skipping 219727_yok.png as it already has the class suffix.
# Skipping 220832_yok.png as it already has the class suffix.
# Skipping 220874_yok.png as it already has the class suffix.
# Skipping 221726_yok.png as it already has the class suffix.
# Skipping 221889_yok.png as it already has the class suffix.
# Skipping 222025_yok.png as it already has the class suffix.
# Skipping 222553_yok.png as it already has the class suffix.
# Skipping 222849_yok.png as it already has the class suffix.
# Skipping 223118_yok.png as it already has the class suffix.
# Skipping 223364_yok.png as it already has the class suffix.
# Skipping 223562_yok.png as it already has the class suffix.
# Skipping 224399_yok.png as it already has the class suffix.
# Skipping 224530_yok.png as it already has the class suffix.
# Skipping 224805_yok.png as it already has the class suffix.
# Skipping 225141_yok.png as it already has the class suffix.
# Skipping 225614_yok.png as it already has the class suffix.
# Skipping 225717_yok.png as it already has the class suffix.
# Skipping 225734_yok.png as it already has the class suffix.
# Skipping 226514_yok.png as it already has the class suffix.
# Skipping 226991_yok.png as it already has the class suffix.
# Skipping 227396_yok.png as it already has the class suffix.
# Skipping 228722_yok.png as it already has the class suffix.
# Skipping 229160_yok.png as it already has the class suffix.
# Skipping 229346_yok.png as it already has the class suffix.
# Skipping 230409_yok.png as it already has the class suffix.
# Skipping 230824_yok.png as it already has the class suffix.
# Skipping 230972_yok.png as it already has the class suffix.
# Skipping 231032_yok.png as it already has the class suffix.
# Skipping 231398_yok.png as it already has the class suffix.
# Skipping 231715_yok.png as it already has the class suffix.
# Skipping 231731_yok.png as it already has the class suffix.
# Skipping 232437_yok.png as it already has the class suffix.
# Skipping 232896_yok.png as it already has the class suffix.
# Skipping 233247_yok.png as it already has the class suffix.
# Skipping 234257_yok.png as it already has the class suffix.
# Skipping 235945_yok.png as it already has the class suffix.
# Skipping 236762_yok.png as it already has the class suffix.
# Skipping 236785_yok.png as it already has the class suffix.
# Skipping 236828_yok.png as it already has the class suffix.
# Skipping 237022_yok.png as it already has the class suffix.
# Skipping 237592_yok.png as it already has the class suffix.
# Skipping 237797_yok.png as it already has the class suffix.
# Skipping 237916_yok.png as it already has the class suffix.
# Skipping 238026_yok.png as it already has the class suffix.
# Skipping 238228_yok.png as it already has the class suffix.
# Skipping 238740_yok.png as it already has the class suffix.
# Skipping 239211_yok.png as it already has the class suffix.
# Skipping 239683_yok.png as it already has the class suffix.
# Skipping 239733_yok.png as it already has the class suffix.
# Skipping 240434_yok.png as it already has the class suffix.
# Skipping 240515_yok.png as it already has the class suffix.
# Skipping 241052_yok.png as it already has the class suffix.
# Skipping 241355_yok.png as it already has the class suffix.
# Skipping 241463_yok.png as it already has the class suffix.
# Skipping 242495_yok.png as it already has the class suffix.
# Skipping 242551_yok.png as it already has the class suffix.
# Skipping 242691_yok.png as it already has the class suffix.
# Skipping 243156_yok.png as it already has the class suffix.
# Skipping 243372_yok.png as it already has the class suffix.
# Skipping 243839_yok.png as it already has the class suffix.
# Skipping 244019_yok.png as it already has the class suffix.
# Skipping 246025_yok.png as it already has the class suffix.
# Skipping 246109_yok.png as it already has the class suffix.
# Skipping 246346_yok.png as it already has the class suffix.
# Skipping 246698_yok.png as it already has the class suffix.
# Skipping 247368_yok.png as it already has the class suffix.
# Skipping 247636_yok.png as it already has the class suffix.
# Skipping 247931_yok.png as it already has the class suffix.
# Skipping 248006_yok.png as it already has the class suffix.
# Skipping 248054_yok.png as it already has the class suffix.
# Skipping 248057_yok.png as it already has the class suffix.
# Skipping 248653_yok.png as it already has the class suffix.
# Skipping 248700_yok.png as it already has the class suffix.
# Skipping 249257_yok.png as it already has the class suffix.
# Skipping 249877_yok.png as it already has the class suffix.
# Skipping 250005_yok.png as it already has the class suffix.
# Skipping 250016_yok.png as it already has the class suffix.
# Skipping 250972_yok.png as it already has the class suffix.
# Skipping 252184_yok.png as it already has the class suffix.
# Skipping 252590_yok.png as it already has the class suffix.
# Skipping 254431_yok.png as it already has the class suffix.
# Skipping 254623_yok.png as it already has the class suffix.
# Skipping 254823_yok.png as it already has the class suffix.
# Skipping 254888_yok.png as it already has the class suffix.
# Skipping 254968_yok.png as it already has the class suffix.
# Skipping 254973_yok.png as it already has the class suffix.
# Skipping 255070_yok.png as it already has the class suffix.
# Skipping 255140_yok.png as it already has the class suffix.
# Skipping 255144_yok.png as it already has the class suffix.
# Skipping 255223_yok.png as it already has the class suffix.
# Skipping 255838_yok.png as it already has the class suffix.
# Skipping 256541_yok.png as it already has the class suffix.
# Skipping 256794_yok.png as it already has the class suffix.
# Skipping 258625_yok.png as it already has the class suffix.
# Skipping 258637_yok.png as it already has the class suffix.
# Skipping 259038_yok.png as it already has the class suffix.
# Skipping 259243_yok.png as it already has the class suffix.
# Skipping 260354_yok.png as it already has the class suffix.
# Skipping 261389_yok.png as it already has the class suffix.
# Skipping 262828_yok.png as it already has the class suffix.
# Skipping 263030_yok.png as it already has the class suffix.
# Skipping 263081_yok.png as it already has the class suffix.
# Skipping 263226_yok.png as it already has the class suffix.
# Skipping 263267_yok.png as it already has the class suffix.
# Skipping 263999_yok.png as it already has the class suffix.
# Skipping 264011_yok.png as it already has the class suffix.
# Skipping 264593_yok.png as it already has the class suffix.
# Skipping 264782_yok.png as it already has the class suffix.
# Skipping 265101_yok.png as it already has the class suffix.
# Skipping 266594_yok.png as it already has the class suffix.
# Skipping 267443_yok.png as it already has the class suffix.
# Skipping 267485_yok.png as it already has the class suffix.
# Skipping 268145_yok.png as it already has the class suffix.
# Skipping 268421_yok.png as it already has the class suffix.
# Skipping 269189_yok.png as it already has the class suffix.
# Skipping 270182_yok.png as it already has the class suffix.
# Skipping 270244_yok.png as it already has the class suffix.
# Skipping 270893_yok.png as it already has the class suffix.
# Skipping 272179_yok.png as it already has the class suffix.
# Skipping 272904_yok.png as it already has the class suffix.
# Skipping 273300_yok.png as it already has the class suffix.
# Skipping 273305_yok.png as it already has the class suffix.
# Skipping 273468_yok.png as it already has the class suffix.
# Skipping 273859_yok.png as it already has the class suffix.
# Skipping 275592_yok.png as it already has the class suffix.
# Skipping 275976_yok.png as it already has the class suffix.
# Skipping 276168_yok.png as it already has the class suffix.
# Skipping 276367_yok.png as it already has the class suffix.
# Skipping 276518_yok.png as it already has the class suffix.
# Skipping 276711_yok.png as it already has the class suffix.
# Skipping 277004_yok.png as it already has the class suffix.
# Skipping 277534_yok.png as it already has the class suffix.
# Skipping 277576_yok.png as it already has the class suffix.
# Skipping 277749_yok.png as it already has the class suffix.
# Skipping 278839_yok.png as it already has the class suffix.
# Skipping 278941_yok.png as it already has the class suffix.
# Skipping 278997_yok.png as it already has the class suffix.
# Skipping 279663_yok.png as it already has the class suffix.
# Skipping 279721_yok.png as it already has the class suffix.
# Skipping 279934_yok.png as it already has the class suffix.
# Skipping 279969_yok.png as it already has the class suffix.
# Skipping 279987_yok.png as it already has the class suffix.
# Skipping 280019_yok.png as it already has the class suffix.
# Skipping 280487_yok.png as it already has the class suffix.
# Skipping 280539_yok.png as it already has the class suffix.
# Skipping 281465_yok.png as it already has the class suffix.
# Skipping 282207_yok.png as it already has the class suffix.
# Skipping 282209_yok.png as it already has the class suffix.
# Skipping 283464_yok.png as it already has the class suffix.
# Skipping 283686_yok.png as it already has the class suffix.
# Skipping 283967_yok.png as it already has the class suffix.
# Skipping 284155_yok.png as it already has the class suffix.
# Skipping 284370_yok.png as it already has the class suffix.
# Skipping 284552_yok.png as it already has the class suffix.
# Skipping 285313_yok.png as it already has the class suffix.
# Skipping 285723_yok.png as it already has the class suffix.
# Skipping 285783_yok.png as it already has the class suffix.
# Skipping 286000_yok.png as it already has the class suffix.
# Skipping 286624_yok.png as it already has the class suffix.
# Skipping 287076_yok.png as it already has the class suffix.
# Skipping 287884_yok.png as it already has the class suffix.
# Skipping 288118_yok.png as it already has the class suffix.
# Skipping 288160_yok.png as it already has the class suffix.
# Skipping 288232_yok.png as it already has the class suffix.
# Skipping 289430_yok.png as it already has the class suffix.
# Skipping 289878_yok.png as it already has the class suffix.
# Skipping 291022_yok.png as it already has the class suffix.
# Skipping 291833_yok.png as it already has the class suffix.
# Skipping 291871_yok.png as it already has the class suffix.
# Skipping 292249_yok.png as it already has the class suffix.
# Skipping 293225_yok.png as it already has the class suffix.
# Skipping 293727_yok.png as it already has the class suffix.
# Skipping 294252_yok.png as it already has the class suffix.
# Skipping 294891_yok.png as it already has the class suffix.
# Skipping 295995_yok.png as it already has the class suffix.
# Skipping 296149_yok.png as it already has the class suffix.
# Skipping 296254_yok.png as it already has the class suffix.
# Skipping 296260_yok.png as it already has the class suffix.
# Skipping 296312_yok.png as it already has the class suffix.
# Skipping 296600_yok.png as it already has the class suffix.
# Skipping 296862_yok.png as it already has the class suffix.
# Skipping 296863_yok.png as it already has the class suffix.
# Skipping 297300_yok.png as it already has the class suffix.
# Skipping 298534_yok.png as it already has the class suffix.
# Skipping 298697_yok.png as it already has the class suffix.
# Skipping 299059_yok.png as it already has the class suffix.
# Skipping 299907_yok.png as it already has the class suffix.
# Renamed files in ../trainingDatav3\val\yok
# All files have been renamed with their class suffixes.
