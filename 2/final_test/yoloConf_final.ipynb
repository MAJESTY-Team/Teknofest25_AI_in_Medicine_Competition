# %%
from ultralytics import YOLO
model = YOLO("../TrainingCodes/runs/classify/yolo11m-cls_topluv2_2/weights/best.pt") 
HNmodel=YOLO("../TrainingCodes/runs/classify/yolo11m-cls_Hiperakut_normal/weights/best.pt")
HSmodel=YOLO("../TrainingCodes/runs/classify/yolo11m-cls_Hiperakut_subakut/weights/best.pt")
NSmodel=YOLO("../TrainingCodes/runs/classify/yolo11m-cls_Normal_subakut/weights/best.pt")

read_dir="./png_test"
output_dir="./"

# read_dir="../Yolo/Toplu/val"

# %%
from ultralytics import YOLO
import torch
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix
import shutil
from pathlib import Path
import os
IMAGE_EXTENSIONS = {'.png'}

def read_images(root_dir):
    root = Path(root_dir)
    for path in root.rglob('*'):
        if path.suffix.lower() in IMAGE_EXTENSIONS:
            yield path

T = 0
F = 0

# Lists to store true and predicted labels for the confusion matrix
all_true_labels = []
all_pred_labels = []
class_names = list(model.names.values()) # Get class names from the main model

# Usage
for path in read_images(read_dir):
    if "CT" in str(path):
        continue

    label = path.stem.split("_")[-1]
    all_true_labels.append(label)

    result = model.predict(source=path, save=False)
    result = result[0]
    pred = result.probs.top1
    predlabel = result.names[pred]
    conf = result.probs.top1conf
    newResult = None

    if conf < 0.9:
        second_hit_label = result.names[result.probs.top5[1]]
        if (predlabel == "HiperakutAkut" and second_hit_label == "NormalKronik") or \
           (predlabel == "NormalKronik" and second_hit_label == "HiperakutAkut"):
            newResult = HNmodel.predict(source=path, save=False)
            newResult = newResult[0]
        elif (predlabel == "HiperakutAkut" and second_hit_label == "Subakut") or \
             (predlabel == "Subakut" and second_hit_label == "HiperakutAkut"):
            newResult = HSmodel.predict(source=path, save=False)
            newResult = newResult[0]
        elif (predlabel == "NormalKronik" and second_hit_label == "Subakut") or \
             (predlabel == "Subakut" and second_hit_label == "NormalKronik"):
            newResult = NSmodel.predict(source=path, save=False)
            newResult = newResult[0]

    final_pred_label = ""
    if newResult is None:
        final_pred_label = result.names[pred]
        if final_pred_label.lower() == label.lower():
            T += 1
        else:
            F += 1
        print(f"True label: {label}, Predicted: {final_pred_label}")
    else:
        pred = newResult.probs.top1
        final_pred_label = newResult.names[pred]
        if final_pred_label.lower() == label.lower():
            T += 1
        else:
            F += 1
        print(f"True label: {label}, Predicted: {final_pred_label}")
        print(f"First hit: {result.names[result.probs.top1]}, Second hit: {final_pred_label}, First hit conf {result.probs.top1conf}, Second hit conf: {newResult.probs.top1conf}")

    all_pred_labels.append(final_pred_label)

print(f"True: {T}, False: {F}")
print(f"Accuracy: {T / (T + F) * 100:.2f}%")

# --- New Code for Confusion Matrix ---

# Ensure all class names are present for matrix calculation
all_labels = sorted(list(set(all_true_labels + all_pred_labels)))

# Calculate the confusion matrix
cm = confusion_matrix(all_true_labels, all_pred_labels, labels=all_labels)
# cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Create the plot
plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt=".1f", cmap='Blues',
            xticklabels=all_labels, yticklabels=all_labels)
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

# Save the plot
plt.savefig('confusion_matrix.png', dpi=300)
print("\nConfusion matrix saved to confusion_matrix.png")
# Out:
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_801355_944688.1.14_HiperakutAkut.png: 224x224 Subakut 0.76, HiperakutAkut 0.24, NormalKronik 0.00, 22.1ms
# Speed: 2.3ms preprocess, 22.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_801355_944688.1.14_HiperakutAkut.png: 224x224 Subakut 0.95, HiperakutAkut 0.05, 18.7ms
# Speed: 1.7ms preprocess, 18.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: Subakut
# First hit: Subakut, Second hit: Subakut, First hit conf 0.7598439455032349, Second hit conf: 0.9454513788223267
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_801355_944688.1.17_HiperakutAkut.png: 224x224 HiperakutAkut 0.99, Subakut 0.01, NormalKronik 0.00, 12.5ms
# Speed: 1.7ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_801355_944688.1.37_HiperakutAkut.png: 224x224 NormalKronik 0.99, Subakut 0.01, HiperakutAkut 0.00, 9.4ms
# Speed: 1.2ms preprocess, 9.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_801355_944688.1.40_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 9.2ms
# Speed: 1.2ms preprocess, 9.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_801355_944688.3.14_HiperakutAkut.png: 224x224 NormalKronik 0.79, Subakut 0.19, HiperakutAkut 0.02, 9.5ms
# Speed: 1.5ms preprocess, 9.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_801355_944688.3.14_HiperakutAkut.png: 224x224 NormalKronik 1.00, Subakut 0.00, 9.5ms
# Speed: 1.5ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: NormalKronik
# First hit: NormalKronik, Second hit: NormalKronik, First hit conf 0.7897513508796692, Second hit conf: 0.9999552965164185
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_801355_944688.3.17_HiperakutAkut.png: 224x224 HiperakutAkut 0.65, NormalKronik 0.34, Subakut 0.01, 9.0ms
# Speed: 1.4ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_801355_944688.3.17_HiperakutAkut.png: 224x224 HiperakutAkut 0.99, NormalKronik 0.01, 8.8ms
# Speed: 1.7ms preprocess, 8.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
# First hit: HiperakutAkut, Second hit: HiperakutAkut, First hit conf 0.6490039229393005, Second hit conf: 0.9876816272735596
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_802059_984900.0.41_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_802059_984900.0.42_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 8.8ms
# Speed: 2.1ms preprocess, 8.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_802059_984900.0.5_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 8.9ms
# Speed: 1.8ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_802059_984900.0.6_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_802059_984900.1.5_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 10.4ms
# Speed: 1.8ms preprocess, 10.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_802059_984900.1.6_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 9.2ms
# Speed: 1.7ms preprocess, 9.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_802510_934090.1.33_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 8.4ms
# Speed: 1.5ms preprocess, 8.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_802510_934090.1.35_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 8.4ms
# Speed: 1.7ms preprocess, 8.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_802510_934090.1.36_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_802510_934090.1.38_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 8.5ms
# Speed: 2.2ms preprocess, 8.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_802510_934090.1.3_HiperakutAkut.png: 224x224 HiperakutAkut 0.99, NormalKronik 0.01, Subakut 0.00, 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_802510_934090.1.5_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 8.4ms
# Speed: 1.5ms preprocess, 8.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_802510_934090.2.11_HiperakutAkut.png: 224x224 HiperakutAkut 0.92, NormalKronik 0.08, Subakut 0.00, 8.7ms
# Speed: 1.4ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_802510_934090.2.12_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 8.5ms
# Speed: 1.5ms preprocess, 8.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_802510_934090.2.1_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 8.5ms
# Speed: 1.5ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_802934_934784.1.10_NormalKronik.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 8.8ms
# Speed: 1.7ms preprocess, 8.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_802934_934784.1.19_NormalKronik.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 8.9ms
# Speed: 2.0ms preprocess, 8.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_802934_934784.1.20_NormalKronik.png: 224x224 NormalKronik 1.00, HiperakutAkut 0.00, Subakut 0.00, 4.6ms
# Speed: 1.9ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_802934_934784.1.23_NormalKronik.png: 224x224 HiperakutAkut 0.54, NormalKronik 0.46, Subakut 0.00, 5.6ms
# Speed: 1.3ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_802934_934784.1.23_NormalKronik.png: 224x224 HiperakutAkut 0.76, NormalKronik 0.24, 5.2ms
# Speed: 1.7ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
# First hit: HiperakutAkut, Second hit: HiperakutAkut, First hit conf 0.5362561941146851, Second hit conf: 0.759808361530304
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_802934_934784.1.2_NormalKronik.png: 224x224 NormalKronik 1.00, HiperakutAkut 0.00, Subakut 0.00, 5.2ms
# Speed: 1.4ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_802934_934784.1.7_NormalKronik.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 6.0ms
# Speed: 1.3ms preprocess, 6.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_802934_934784.2.17_NormalKronik.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.1ms
# Speed: 1.4ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_802934_934784.2.18_NormalKronik.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 9.1ms
# Speed: 1.8ms preprocess, 9.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_802934_934784.2.19_NormalKronik.png: 224x224 HiperakutAkut 0.97, NormalKronik 0.03, Subakut 0.00, 5.1ms
# Speed: 1.3ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_803472_921299.1.13_HiperakutAkut.png: 224x224 HiperakutAkut 0.56, NormalKronik 0.43, Subakut 0.00, 4.8ms
# Speed: 1.6ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_803472_921299.1.13_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
# First hit: HiperakutAkut, Second hit: HiperakutAkut, First hit conf 0.5647204518318176, Second hit conf: 0.9985142350196838
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_803472_921299.1.29_HiperakutAkut.png: 224x224 HiperakutAkut 0.99, NormalKronik 0.01, Subakut 0.00, 5.7ms
# Speed: 1.6ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_803472_921299.1.33_HiperakutAkut.png: 224x224 HiperakutAkut 0.53, NormalKronik 0.47, Subakut 0.00, 5.2ms
# Speed: 2.0ms preprocess, 5.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_803472_921299.1.33_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, 4.9ms
# Speed: 1.7ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
# First hit: HiperakutAkut, Second hit: HiperakutAkut, First hit conf 0.52815842628479, Second hit conf: 0.9999850988388062
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_803472_921299.1.35_HiperakutAkut.png: 224x224 HiperakutAkut 0.91, NormalKronik 0.09, Subakut 0.00, 6.9ms
# Speed: 1.4ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_803472_921299.1.3_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.3ms
# Speed: 1.4ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_803472_921299.1.44_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 5.2ms
# Speed: 1.4ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_803472_921299.1.4_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 5.9ms
# Speed: 1.6ms preprocess, 5.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_803472_921299.1.9_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 7.1ms
# Speed: 1.5ms preprocess, 7.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_803472_921299.2.10_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 8.6ms
# Speed: 3.4ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_803472_921299.2.12_HiperakutAkut.png: 224x224 NormalKronik 1.00, HiperakutAkut 0.00, Subakut 0.00, 9.0ms
# Speed: 2.1ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_803472_921299.2.16_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 12.2ms
# Speed: 3.0ms preprocess, 12.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_803472_921299.2.20_HiperakutAkut.png: 224x224 NormalKronik 1.00, HiperakutAkut 0.00, Subakut 0.00, 6.1ms
# Speed: 2.5ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804447_988628.4.10_NormalKronik.png: 224x224 NormalKronik 1.00, HiperakutAkut 0.00, Subakut 0.00, 5.9ms
# Speed: 1.6ms preprocess, 5.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804447_988628.4.17_NormalKronik.png: 224x224 HiperakutAkut 0.99, NormalKronik 0.01, Subakut 0.00, 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804447_988628.4.24_NormalKronik.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 6.0ms
# Speed: 2.1ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804447_988628.4.34_NormalKronik.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.4ms
# Speed: 2.0ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804447_988628.4.38_NormalKronik.png: 224x224 HiperakutAkut 0.84, NormalKronik 0.16, Subakut 0.00, 5.1ms
# Speed: 1.5ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804447_988628.4.38_NormalKronik.png: 224x224 NormalKronik 0.55, HiperakutAkut 0.45, 5.3ms
# Speed: 2.0ms preprocess, 5.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
# First hit: HiperakutAkut, Second hit: NormalKronik, First hit conf 0.8357954621315002, Second hit conf: 0.5465832948684692
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804447_988628.4.45_NormalKronik.png: 224x224 HiperakutAkut 0.50, NormalKronik 0.50, Subakut 0.00, 5.8ms
# Speed: 1.7ms preprocess, 5.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804447_988628.4.45_NormalKronik.png: 224x224 NormalKronik 0.76, HiperakutAkut 0.24, 5.5ms
# Speed: 1.5ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
# First hit: HiperakutAkut, Second hit: NormalKronik, First hit conf 0.5011589527130127, Second hit conf: 0.761021614074707
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804447_988628.4.52_NormalKronik.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.9ms
# Speed: 1.6ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804447_988628.4.6_NormalKronik.png: 224x224 NormalKronik 1.00, HiperakutAkut 0.00, Subakut 0.00, 6.3ms
# Speed: 1.6ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804447_988628.5.10_NormalKronik.png: 224x224 NormalKronik 0.56, HiperakutAkut 0.44, Subakut 0.00, 5.0ms
# Speed: 1.6ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804447_988628.5.10_NormalKronik.png: 224x224 NormalKronik 0.67, HiperakutAkut 0.33, 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
# First hit: NormalKronik, Second hit: NormalKronik, First hit conf 0.5591325163841248, Second hit conf: 0.6747939586639404
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804447_988628.5.17_NormalKronik.png: 224x224 HiperakutAkut 0.53, NormalKronik 0.47, Subakut 0.00, 6.9ms
# Speed: 1.7ms preprocess, 6.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804447_988628.5.17_NormalKronik.png: 224x224 NormalKronik 0.96, HiperakutAkut 0.04, 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
# First hit: HiperakutAkut, Second hit: NormalKronik, First hit conf 0.5295568108558655, Second hit conf: 0.960686981678009
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804447_988628.5.24_NormalKronik.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.4ms
# Speed: 1.5ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804447_988628.5.6_NormalKronik.png: 224x224 NormalKronik 0.59, HiperakutAkut 0.41, Subakut 0.00, 6.1ms
# Speed: 2.0ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804447_988628.5.6_NormalKronik.png: 224x224 HiperakutAkut 0.98, NormalKronik 0.02, 4.5ms
# Speed: 1.6ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
# First hit: NormalKronik, Second hit: HiperakutAkut, First hit conf 0.5878431797027588, Second hit conf: 0.9780771732330322
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804628_917126.0.22_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.5ms
# Speed: 1.3ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804628_917126.2.10_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 9.0ms
# Speed: 2.2ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804628_917126.2.38_HiperakutAkut.png: 224x224 HiperakutAkut 0.92, NormalKronik 0.08, Subakut 0.00, 7.6ms
# Speed: 1.3ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804865_929112.1.107_NormalKronik.png: 224x224 NormalKronik 0.84, HiperakutAkut 0.16, Subakut 0.00, 9.7ms
# Speed: 1.5ms preprocess, 9.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804865_929112.1.107_NormalKronik.png: 224x224 NormalKronik 0.58, HiperakutAkut 0.42, 5.1ms
# Speed: 1.4ms preprocess, 5.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
# First hit: NormalKronik, Second hit: NormalKronik, First hit conf 0.8387294411659241, Second hit conf: 0.5797145962715149
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804865_929112.1.111_NormalKronik.png: 224x224 Subakut 0.62, HiperakutAkut 0.23, NormalKronik 0.14, 5.0ms
# Speed: 1.7ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804865_929112.1.111_NormalKronik.png: 224x224 HiperakutAkut 0.59, Subakut 0.41, 6.2ms
# Speed: 1.5ms preprocess, 6.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
# First hit: Subakut, Second hit: HiperakutAkut, First hit conf 0.6242322325706482, Second hit conf: 0.5871785283088684
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804865_929112.2.18_NormalKronik.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.0ms
# Speed: 2.7ms preprocess, 5.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804865_929112.2.3_NormalKronik.png: 224x224 NormalKronik 0.75, HiperakutAkut 0.25, Subakut 0.00, 5.8ms
# Speed: 2.6ms preprocess, 5.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804865_929112.2.3_NormalKronik.png: 224x224 NormalKronik 0.96, HiperakutAkut 0.04, 4.6ms
# Speed: 2.6ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
# First hit: NormalKronik, Second hit: NormalKronik, First hit conf 0.7496657371520996, Second hit conf: 0.9604792594909668
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804865_929112.3.8_NormalKronik.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.2ms
# Speed: 1.3ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804865_929112.3.9_NormalKronik.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.5ms
# Speed: 1.3ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804867_900443.0.15_NormalKronik.png: 224x224 NormalKronik 0.99, HiperakutAkut 0.01, Subakut 0.00, 4.6ms
# Speed: 1.4ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804867_900443.0.17_NormalKronik.png: 224x224 NormalKronik 1.00, HiperakutAkut 0.00, Subakut 0.00, 4.7ms
# Speed: 1.6ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804867_900443.2.15_NormalKronik.png: 224x224 NormalKronik 0.95, HiperakutAkut 0.04, Subakut 0.01, 5.3ms
# Speed: 1.3ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804867_900443.2.17_NormalKronik.png: 224x224 NormalKronik 0.93, HiperakutAkut 0.04, Subakut 0.03, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804867_900443.2.39_NormalKronik.png: 224x224 NormalKronik 0.73, HiperakutAkut 0.27, Subakut 0.00, 5.6ms
# Speed: 1.5ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804867_900443.2.39_NormalKronik.png: 224x224 NormalKronik 0.97, HiperakutAkut 0.03, 5.1ms
# Speed: 1.9ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
# First hit: NormalKronik, Second hit: NormalKronik, First hit conf 0.7343316078186035, Second hit conf: 0.9668817520141602
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_804867_900443.2.41_NormalKronik.png: 224x224 NormalKronik 1.00, HiperakutAkut 0.00, Subakut 0.00, 6.0ms
# Speed: 1.6ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_805270_973207.1.17_NormalKronik.png: 224x224 NormalKronik 1.00, HiperakutAkut 0.00, Subakut 0.00, 5.3ms
# Speed: 1.8ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_805270_973207.1.19_NormalKronik.png: 224x224 NormalKronik 1.00, HiperakutAkut 0.00, Subakut 0.00, 8.0ms
# Speed: 2.3ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_805270_973207.1.20_NormalKronik.png: 224x224 NormalKronik 0.98, HiperakutAkut 0.02, Subakut 0.00, 5.1ms
# Speed: 1.8ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_805270_973207.2.17_NormalKronik.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 9.7ms
# Speed: 2.4ms preprocess, 9.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_805270_973207.2.19_NormalKronik.png: 224x224 NormalKronik 0.56, HiperakutAkut 0.44, Subakut 0.00, 5.4ms
# Speed: 1.9ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_805270_973207.2.19_NormalKronik.png: 224x224 NormalKronik 0.96, HiperakutAkut 0.04, 5.0ms
# Speed: 1.9ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
# First hit: NormalKronik, Second hit: NormalKronik, First hit conf 0.5593922138214111, Second hit conf: 0.9553781747817993
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_805270_973207.2.20_NormalKronik.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 8.7ms
# Speed: 2.1ms preprocess, 8.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_805270_973207.3.17_NormalKronik.png: 224x224 HiperakutAkut 0.71, NormalKronik 0.29, Subakut 0.00, 12.3ms
# Speed: 2.4ms preprocess, 12.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_805270_973207.3.17_NormalKronik.png: 224x224 HiperakutAkut 0.57, NormalKronik 0.43, 7.2ms
# Speed: 2.8ms preprocess, 7.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
# First hit: HiperakutAkut, Second hit: HiperakutAkut, First hit conf 0.707462728023529, Second hit conf: 0.5703622698783875
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_805270_973207.3.19_NormalKronik.png: 224x224 NormalKronik 0.71, HiperakutAkut 0.29, Subakut 0.00, 9.6ms
# Speed: 3.9ms preprocess, 9.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_805270_973207.3.19_NormalKronik.png: 224x224 NormalKronik 0.98, HiperakutAkut 0.02, 5.4ms
# Speed: 2.6ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
# First hit: NormalKronik, Second hit: NormalKronik, First hit conf 0.7132503390312195, Second hit conf: 0.9849964380264282
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_805270_973207.3.20_NormalKronik.png: 224x224 HiperakutAkut 0.51, NormalKronik 0.49, Subakut 0.00, 5.4ms
# Speed: 2.0ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_805270_973207.3.20_NormalKronik.png: 224x224 NormalKronik 0.97, HiperakutAkut 0.03, 5.6ms
# Speed: 2.2ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
# First hit: HiperakutAkut, Second hit: NormalKronik, First hit conf 0.5059860944747925, Second hit conf: 0.9699090123176575
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_805607_985390.1.34_NormalKronik.png: 224x224 HiperakutAkut 0.82, NormalKronik 0.18, Subakut 0.00, 5.4ms
# Speed: 1.5ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_805607_985390.1.34_NormalKronik.png: 224x224 NormalKronik 0.95, HiperakutAkut 0.05, 4.8ms
# Speed: 2.2ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
# First hit: HiperakutAkut, Second hit: NormalKronik, First hit conf 0.8164808750152588, Second hit conf: 0.9546614289283752
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_805607_985390.1.49_NormalKronik.png: 224x224 NormalKronik 0.99, HiperakutAkut 0.01, Subakut 0.00, 4.9ms
# Speed: 1.4ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_805607_985390.2.16_NormalKronik.png: 224x224 NormalKronik 0.97, HiperakutAkut 0.03, Subakut 0.00, 4.9ms
# Speed: 1.6ms preprocess, 4.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_806235_913708.1.24_Subakut.png: 224x224 NormalKronik 0.94, HiperakutAkut 0.06, Subakut 0.00, 4.8ms
# Speed: 1.8ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_806235_913708.1.25_Subakut.png: 224x224 NormalKronik 0.90, HiperakutAkut 0.10, Subakut 0.00, 4.7ms
# Speed: 1.8ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_806235_913708.1.25_Subakut.png: 224x224 NormalKronik 0.99, HiperakutAkut 0.01, 6.8ms
# Speed: 1.8ms preprocess, 6.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: NormalKronik
# First hit: NormalKronik, Second hit: NormalKronik, First hit conf 0.8991552591323853, Second hit conf: 0.9888952970504761
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_806235_913708.1.26_Subakut.png: 224x224 HiperakutAkut 0.93, NormalKronik 0.07, Subakut 0.00, 4.8ms
# Speed: 2.1ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_806235_913708.1.54_Subakut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 4.6ms
# Speed: 1.8ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_806235_913708.1.55_Subakut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 6.3ms
# Speed: 1.8ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_806235_913708.1.56_Subakut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 4.7ms
# Speed: 1.9ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_806235_913708.2.24_Subakut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.7ms
# Speed: 1.6ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_806235_913708.2.25_Subakut.png: 224x224 NormalKronik 0.89, HiperakutAkut 0.11, Subakut 0.00, 4.6ms
# Speed: 2.5ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_806235_913708.2.25_Subakut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, 5.1ms
# Speed: 2.1ms preprocess, 5.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: HiperakutAkut
# First hit: NormalKronik, Second hit: HiperakutAkut, First hit conf 0.8945798873901367, Second hit conf: 0.9998867511749268
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_806235_913708.2.26_Subakut.png: 224x224 NormalKronik 0.62, HiperakutAkut 0.37, Subakut 0.00, 5.0ms
# Speed: 1.7ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_806235_913708.2.26_Subakut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, 4.9ms
# Speed: 3.1ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: HiperakutAkut
# First hit: NormalKronik, Second hit: HiperakutAkut, First hit conf 0.6241398453712463, Second hit conf: 0.9997962117195129
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_806408_976048.0.11_NormalKronik.png: 224x224 NormalKronik 0.91, HiperakutAkut 0.09, Subakut 0.00, 7.4ms
# Speed: 2.6ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_806408_976048.0.12_NormalKronik.png: 224x224 NormalKronik 0.51, HiperakutAkut 0.49, Subakut 0.00, 6.3ms
# Speed: 2.1ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_806408_976048.0.12_NormalKronik.png: 224x224 HiperakutAkut 0.92, NormalKronik 0.08, 5.1ms
# Speed: 2.0ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
# First hit: NormalKronik, Second hit: HiperakutAkut, First hit conf 0.5088266134262085, Second hit conf: 0.9185746312141418
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_806408_976048.0.13_NormalKronik.png: 224x224 HiperakutAkut 0.97, NormalKronik 0.03, Subakut 0.00, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_806408_976048.0.36_NormalKronik.png: 224x224 NormalKronik 0.99, HiperakutAkut 0.01, Subakut 0.00, 9.9ms
# Speed: 2.0ms preprocess, 9.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_806408_976048.0.37_NormalKronik.png: 224x224 NormalKronik 1.00, HiperakutAkut 0.00, Subakut 0.00, 5.0ms
# Speed: 1.8ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_806408_976048.0.38_NormalKronik.png: 224x224 NormalKronik 1.00, HiperakutAkut 0.00, Subakut 0.00, 4.8ms
# Speed: 2.9ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_806408_976048.3.11_NormalKronik.png: 224x224 NormalKronik 1.00, HiperakutAkut 0.00, Subakut 0.00, 9.0ms
# Speed: 2.1ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_806408_976048.3.12_NormalKronik.png: 224x224 NormalKronik 0.86, HiperakutAkut 0.14, Subakut 0.00, 4.5ms
# Speed: 1.9ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_806408_976048.3.12_NormalKronik.png: 224x224 NormalKronik 0.99, HiperakutAkut 0.01, 8.6ms
# Speed: 1.7ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
# First hit: NormalKronik, Second hit: NormalKronik, First hit conf 0.8564111590385437, Second hit conf: 0.9889822602272034
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_806408_976048.3.13_NormalKronik.png: 224x224 NormalKronik 0.99, HiperakutAkut 0.01, Subakut 0.00, 4.6ms
# Speed: 1.7ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_807277_944351.2.12_NormalKronik.png: 224x224 HiperakutAkut 0.97, NormalKronik 0.03, Subakut 0.00, 4.3ms
# Speed: 1.6ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_807277_944351.2.14_NormalKronik.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 8.8ms
# Speed: 1.4ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_807277_944351.2.42_NormalKronik.png: 224x224 HiperakutAkut 0.87, NormalKronik 0.13, Subakut 0.00, 7.7ms
# Speed: 1.4ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_807277_944351.2.42_NormalKronik.png: 224x224 NormalKronik 0.87, HiperakutAkut 0.13, 4.8ms
# Speed: 1.5ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
# First hit: HiperakutAkut, Second hit: NormalKronik, First hit conf 0.8671354055404663, Second hit conf: 0.8667999505996704
#
# ...
# Speed: 2.6ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_895973_951456.1.38_NormalKronik.png: 224x224 NormalKronik 1.00, HiperakutAkut 0.00, Subakut 0.00, 5.9ms
# Speed: 2.1ms preprocess, 5.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_895973_951456.1.39_NormalKronik.png: 224x224 HiperakutAkut 0.94, NormalKronik 0.06, Subakut 0.00, 5.2ms
# Speed: 2.1ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_895973_951456.1.40_NormalKronik.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.2ms
# Speed: 1.8ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_896051_951895.1.11_HiperakutAkut.png: 224x224 HiperakutAkut 0.96, NormalKronik 0.04, Subakut 0.00, 5.2ms
# Speed: 1.7ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_896051_951895.1.13_HiperakutAkut.png: 224x224 HiperakutAkut 0.80, NormalKronik 0.20, Subakut 0.00, 5.3ms
# Speed: 1.6ms preprocess, 5.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_896051_951895.1.13_HiperakutAkut.png: 224x224 HiperakutAkut 0.99, NormalKronik 0.01, 8.6ms
# Speed: 3.4ms preprocess, 8.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
# First hit: HiperakutAkut, Second hit: HiperakutAkut, First hit conf 0.7980641722679138, Second hit conf: 0.9946302175521851
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_896051_951895.1.9_HiperakutAkut.png: 224x224 HiperakutAkut 0.75, NormalKronik 0.25, Subakut 0.00, 14.7ms
# Speed: 3.5ms preprocess, 14.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_896051_951895.1.9_HiperakutAkut.png: 224x224 HiperakutAkut 0.52, NormalKronik 0.48, 12.2ms
# Speed: 3.6ms preprocess, 12.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
# First hit: HiperakutAkut, Second hit: HiperakutAkut, First hit conf 0.7528389096260071, Second hit conf: 0.5216753482818604
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_896051_951895.2.31_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 8.8ms
# Speed: 2.3ms preprocess, 8.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_896051_951895.2.33_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 7.3ms
# Speed: 2.3ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_896051_951895.2.35_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.4ms
# Speed: 1.9ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_896051_951895.3.15_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.4ms
# Speed: 1.6ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_896051_951895.3.16_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 6.6ms
# Speed: 1.6ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_896051_951895.3.17_HiperakutAkut.png: 224x224 HiperakutAkut 0.71, NormalKronik 0.29, Subakut 0.00, 6.7ms
# Speed: 2.4ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_896051_951895.3.17_HiperakutAkut.png: 224x224 HiperakutAkut 0.63, NormalKronik 0.37, 5.7ms
# Speed: 1.8ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
# First hit: HiperakutAkut, Second hit: HiperakutAkut, First hit conf 0.7141916751861572, Second hit conf: 0.6306300759315491
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_896270_987012.1.12_NormalKronik.png: 224x224 NormalKronik 1.00, HiperakutAkut 0.00, Subakut 0.00, 5.5ms
# Speed: 2.1ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_896270_987012.1.16_NormalKronik.png: 224x224 NormalKronik 0.99, HiperakutAkut 0.01, Subakut 0.00, 5.6ms
# Speed: 2.4ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_896270_987012.1.8_NormalKronik.png: 224x224 NormalKronik 1.00, Subakut 0.00, HiperakutAkut 0.00, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_896270_987012.2.12_NormalKronik.png: 224x224 NormalKronik 1.00, Subakut 0.00, HiperakutAkut 0.00, 12.2ms
# Speed: 3.7ms preprocess, 12.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_896270_987012.2.16_NormalKronik.png: 224x224 NormalKronik 1.00, HiperakutAkut 0.00, Subakut 0.00, 12.7ms
# Speed: 3.4ms preprocess, 12.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_896270_987012.2.8_NormalKronik.png: 224x224 NormalKronik 0.99, HiperakutAkut 0.01, Subakut 0.00, 6.2ms
# Speed: 2.6ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_896270_987012.3.12_NormalKronik.png: 224x224 NormalKronik 1.00, HiperakutAkut 0.00, Subakut 0.00, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_896270_987012.3.16_NormalKronik.png: 224x224 NormalKronik 0.99, HiperakutAkut 0.01, Subakut 0.00, 6.1ms
# Speed: 3.6ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_896270_987012.3.8_NormalKronik.png: 224x224 NormalKronik 0.90, HiperakutAkut 0.10, Subakut 0.00, 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_897628_968684.2.12_NormalKronik.png: 224x224 NormalKronik 1.00, HiperakutAkut 0.00, Subakut 0.00, 5.5ms
# Speed: 2.1ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_897628_968684.2.36_NormalKronik.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.4ms
# Speed: 1.7ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_897628_968684.2.37_NormalKronik.png: 224x224 HiperakutAkut 0.85, NormalKronik 0.13, Subakut 0.02, 10.2ms
# Speed: 1.6ms preprocess, 10.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_897628_968684.2.37_NormalKronik.png: 224x224 HiperakutAkut 0.97, NormalKronik 0.03, 5.4ms
# Speed: 1.7ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
# First hit: HiperakutAkut, Second hit: HiperakutAkut, First hit conf 0.852144718170166, Second hit conf: 0.9718653559684753
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_897628_968684.2.40_NormalKronik.png: 224x224 NormalKronik 1.00, HiperakutAkut 0.00, Subakut 0.00, 5.3ms
# Speed: 1.9ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_897628_968684.2.8_NormalKronik.png: 224x224 NormalKronik 0.86, HiperakutAkut 0.14, Subakut 0.00, 7.8ms
# Speed: 1.5ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_897628_968684.2.8_NormalKronik.png: 224x224 NormalKronik 0.77, HiperakutAkut 0.23, 5.4ms
# Speed: 1.5ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
# First hit: NormalKronik, Second hit: NormalKronik, First hit conf 0.859420120716095, Second hit conf: 0.768587052822113
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_897628_968684.2.9_NormalKronik.png: 224x224 NormalKronik 0.96, HiperakutAkut 0.04, Subakut 0.00, 13.8ms
# Speed: 3.0ms preprocess, 13.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_897628_968684.4.12_NormalKronik.png: 224x224 NormalKronik 1.00, Subakut 0.00, HiperakutAkut 0.00, 6.9ms
# Speed: 3.2ms preprocess, 6.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_897628_968684.4.8_NormalKronik.png: 224x224 HiperakutAkut 0.99, NormalKronik 0.01, Subakut 0.00, 7.7ms
# Speed: 2.9ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_897628_968684.4.9_NormalKronik.png: 224x224 NormalKronik 0.86, HiperakutAkut 0.13, Subakut 0.00, 6.4ms
# Speed: 2.1ms preprocess, 6.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_897628_968684.4.9_NormalKronik.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
# First hit: NormalKronik, Second hit: HiperakutAkut, First hit conf 0.8637990355491638, Second hit conf: 0.9985068440437317
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_899400_933867.2.10_NormalKronik.png: 224x224 NormalKronik 1.00, HiperakutAkut 0.00, Subakut 0.00, 5.3ms
# Speed: 1.8ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_899400_933867.2.14_NormalKronik.png: 224x224 NormalKronik 1.00, HiperakutAkut 0.00, Subakut 0.00, 5.5ms
# Speed: 1.9ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_899400_933867.2.35_NormalKronik.png: 224x224 NormalKronik 0.95, HiperakutAkut 0.05, Subakut 0.00, 5.3ms
# Speed: 1.6ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_899400_933867.2.39_NormalKronik.png: 224x224 NormalKronik 1.00, HiperakutAkut 0.00, Subakut 0.00, 17.0ms
# Speed: 3.1ms preprocess, 17.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_899400_933867.3.10_NormalKronik.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 8.4ms
# Speed: 2.0ms preprocess, 8.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\final_test\png_test\Vaka_899400_933867.3.14_NormalKronik.png: 224x224 NormalKronik 1.00, HiperakutAkut 0.00, Subakut 0.00, 8.2ms
# Speed: 3.2ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: NormalKronik, Predicted: NormalKronik
# True: 1070, False: 604
# Accuracy: 63.92%
#
# Confusion matrix saved to confusion_matrix.png

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt=".1f", cmap='Blues',
            xticklabels=all_labels, yticklabels=all_labels)
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

# Save the plot
plt.savefig('confusion_matrix.png', dpi=300)
print("\nConfusion matrix saved to confusion_matrix.png")
# Out:
# Confusion matrix saved to confusion_matrix.png

# %%
from ultralytics import YOLO
import torch
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix
import shutil
from pathlib import Path
import os


T = 0
F = 0

# Lists to store true and predicted labels for the confusion matrix
all_true_labels = []
all_pred_labels = []
class_names = list(model.names.values()) # Get class names from the main model

# Usage
for path in read_images(read_dir):
    if "CT" in str(path):
        continue

    label = path.stem.split("_")[-1]
    all_true_labels.append(label)

    result = model.predict(source=path, save=False)
    result = result[0]
    pred = result.probs.top1
    predlabel = result.names[pred]
    conf = result.probs.top1conf
    newResult = None

    final_pred_label = ""
    if newResult is None:
        final_pred_label = result.names[pred]
        if final_pred_label.lower() == label.lower():
            T += 1
        else:
            F += 1
        print(f"True label: {label}, Predicted: {final_pred_label}")
    else:
        pred = newResult.probs.top1
        final_pred_label = newResult.names[pred]
        if final_pred_label.lower() == label.lower():
            T += 1
        else:
            F += 1
        print(f"True label: {label}, Predicted: {final_pred_label}")
        print(f"First hit: {result.names[result.probs.top1]}, Second hit: {final_pred_label}, First hit conf {result.probs.top1conf}, Second hit conf: {newResult.probs.top1conf}")

    all_pred_labels.append(final_pred_label)

print(f"True: {T}, False: {F}")
print(f"Accuracy: {T / (T + F) * 100:.2f}%")

# --- New Code for Confusion Matrix ---

# Ensure all class names are present for matrix calculation
all_labels = sorted(list(set(all_true_labels + all_pred_labels)))

# Calculate the confusion matrix
cm = confusion_matrix(all_true_labels, all_pred_labels, labels=all_labels)
# cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Create the plot
plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt=".1f", cmap='Blues',
            xticklabels=all_labels, yticklabels=all_labels)
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

# Save the plot
plt.savefig('confusion_matrix_non_hybrid.png', dpi=300)
print("\nConfusion matrix saved to confusion_matrix.png")
# Out:
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_300663_50467107.2.19_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 22.0ms
# Speed: 3.1ms preprocess, 22.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_300663_50467107.4.0_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 22.3ms
# Speed: 3.1ms preprocess, 22.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_302619_50478756.3.11_HiperakutAkut.png: 224x224 Subakut 0.92, HiperakutAkut 0.08, NormalKronik 0.00, 21.9ms
# Speed: 2.3ms preprocess, 21.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: Subakut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_302619_50478756.3.12_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 22.2ms
# Speed: 2.6ms preprocess, 22.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_302619_50478756.4.5_HiperakutAkut.png: 224x224 NormalKronik 0.90, HiperakutAkut 0.10, Subakut 0.00, 21.9ms
# Speed: 3.7ms preprocess, 21.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_302619_50478756.5.10_HiperakutAkut.png: 224x224 HiperakutAkut 0.99, NormalKronik 0.01, Subakut 0.00, 21.3ms
# Speed: 2.3ms preprocess, 21.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_302667_50342134.3.10_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 19.5ms
# Speed: 2.8ms preprocess, 19.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_302861_50479238.3.6_HiperakutAkut.png: 224x224 HiperakutAkut 0.78, NormalKronik 0.22, Subakut 0.00, 19.7ms
# Speed: 3.2ms preprocess, 19.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_302861_50479238.3.7_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 19.5ms
# Speed: 3.4ms preprocess, 19.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_302975_50470135.2.21_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 19.4ms
# Speed: 2.4ms preprocess, 19.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_303746_50524634.2.15_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 19.5ms
# Speed: 2.5ms preprocess, 19.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_303746_50524634.3.14_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 19.3ms
# Speed: 2.1ms preprocess, 19.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_305370_50414099.0.21_HiperakutAkut.png: 224x224 HiperakutAkut 0.83, NormalKronik 0.17, Subakut 0.00, 19.9ms
# Speed: 2.4ms preprocess, 19.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_305995_50327427.3.14_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 9.9ms
# Speed: 2.4ms preprocess, 9.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_305995_50327427.3.49_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 10.3ms
# Speed: 2.6ms preprocess, 10.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_305995_50327427.4.19_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 9.9ms
# Speed: 2.3ms preprocess, 9.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_305995_50327427.5.17_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 9.9ms
# Speed: 2.5ms preprocess, 9.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_308974_50109440.2.16_HiperakutAkut.png: 224x224 HiperakutAkut 0.98, NormalKronik 0.02, Subakut 0.00, 9.8ms
# Speed: 2.6ms preprocess, 9.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_308974_50109440.3.14_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 9.9ms
# Speed: 2.9ms preprocess, 9.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_308974_50109440.3.17_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 9.9ms
# Speed: 2.3ms preprocess, 9.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_309924_50419553.0.33_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 10.1ms
# Speed: 2.3ms preprocess, 10.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_309924_50419553.0.9_HiperakutAkut.png: 224x224 HiperakutAkut 0.99, NormalKronik 0.01, Subakut 0.00, 10.2ms
# Speed: 2.0ms preprocess, 10.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_310915_50237282.1.44_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 9.9ms
# Speed: 2.1ms preprocess, 9.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_310915_50237282.2.10_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 8.7ms
# Speed: 1.9ms preprocess, 8.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_310930_50325358.0.14_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 9.3ms
# Speed: 2.1ms preprocess, 9.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_310930_50325358.0.16_HiperakutAkut.png: 224x224 HiperakutAkut 0.73, NormalKronik 0.27, Subakut 0.00, 9.2ms
# Speed: 2.7ms preprocess, 9.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_310930_50325358.1.16_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 8.9ms
# Speed: 2.3ms preprocess, 8.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_310930_50325358.4.15_HiperakutAkut.png: 224x224 NormalKronik 1.00, HiperakutAkut 0.00, Subakut 0.00, 8.8ms
# Speed: 2.5ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_310930_50325358.4.21_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 8.9ms
# Speed: 2.6ms preprocess, 8.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_311726_50432895.1.32_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 9.2ms
# Speed: 4.1ms preprocess, 9.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_311814_50599684.1.16_HiperakutAkut.png: 224x224 NormalKronik 1.00, HiperakutAkut 0.00, Subakut 0.00, 9.2ms
# Speed: 3.4ms preprocess, 9.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_311991_50201854.0.10_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 9.2ms
# Speed: 2.6ms preprocess, 9.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_311991_50201854.0.11_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 8.9ms
# Speed: 2.6ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_312713_50068912.1.20_HiperakutAkut.png: 224x224 HiperakutAkut 0.93, NormalKronik 0.07, Subakut 0.00, 8.9ms
# Speed: 2.7ms preprocess, 8.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_312713_50068912.1.44_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 8.6ms
# Speed: 2.3ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_312713_50068912.1.45_HiperakutAkut.png: 224x224 HiperakutAkut 0.99, Subakut 0.01, NormalKronik 0.00, 8.7ms
# Speed: 2.2ms preprocess, 8.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_312713_50068912.1.46_HiperakutAkut.png: 224x224 HiperakutAkut 0.95, Subakut 0.05, NormalKronik 0.00, 8.6ms
# Speed: 2.5ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_312713_50068912.2.21_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 8.8ms
# Speed: 2.2ms preprocess, 8.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_313875_50209600.1.2_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 8.9ms
# Speed: 3.1ms preprocess, 8.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_313920_50055774.1.4_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 8.3ms
# Speed: 2.9ms preprocess, 8.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_314463_50033832.1.3_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 8.4ms
# Speed: 2.8ms preprocess, 8.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_315148_50569970.0.66_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 9.6ms
# Speed: 3.0ms preprocess, 9.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_315148_50569970.0.68_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 8.4ms
# Speed: 2.7ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_315148_50569970.2.15_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 8.7ms
# Speed: 2.8ms preprocess, 8.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_315148_50569970.2.16_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 8.4ms
# Speed: 2.9ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_315536_50047497.3.17_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 8.9ms
# Speed: 2.2ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_315536_50047497.3.1_HiperakutAkut.png: 224x224 NormalKronik 0.54, HiperakutAkut 0.46, Subakut 0.00, 3.7ms
# Speed: 2.1ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_315536_50047497.3.56_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.3ms
# Speed: 1.8ms preprocess, 4.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_315843_50468241.2.10_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.3ms
# Speed: 1.9ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_315843_50468241.2.29_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.9ms
# Speed: 2.1ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_316661_50150584.1.34_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 5.3ms
# Speed: 1.9ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_316890_50044252.4.14_HiperakutAkut.png: 224x224 HiperakutAkut 0.77, NormalKronik 0.23, Subakut 0.00, 4.1ms
# Speed: 2.1ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_316890_50044252.4.39_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 5.7ms
# Speed: 2.4ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_317258_50302750.0.23_HiperakutAkut.png: 224x224 NormalKronik 1.00, HiperakutAkut 0.00, Subakut 0.00, 4.4ms
# Speed: 1.9ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_317258_50302750.0.54_HiperakutAkut.png: 224x224 NormalKronik 1.00, HiperakutAkut 0.00, Subakut 0.00, 4.0ms
# Speed: 1.8ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_317258_50302750.0.58_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 4.5ms
# Speed: 2.2ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_317258_50302750.1.5_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.9ms
# Speed: 1.8ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_318322_50056558.3.12_HiperakutAkut.png: 224x224 HiperakutAkut 0.91, NormalKronik 0.09, Subakut 0.00, 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_319126_50031314.2.16_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 7.2ms
# Speed: 2.1ms preprocess, 7.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_319251_50343483.2.18_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 8.1ms
# Speed: 5.2ms preprocess, 8.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_319251_50343483.2.8_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.4ms
# Speed: 3.1ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_320150_50362932.0.24_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.7ms
# Speed: 2.5ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_320150_50362932.0.9_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 4.2ms
# Speed: 2.4ms preprocess, 4.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_320187_50465042.2.36_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.4ms
# Speed: 1.9ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_320187_50465042.3.15_HiperakutAkut.png: 224x224 HiperakutAkut 0.84, NormalKronik 0.16, Subakut 0.00, 4.4ms
# Speed: 2.2ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_320187_50465042.3.18_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.8ms
# Speed: 2.2ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_322243_50158339.0.16_HiperakutAkut.png: 224x224 HiperakutAkut 0.69, NormalKronik 0.30, Subakut 0.00, 4.6ms
# Speed: 1.9ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_322243_50158339.3.14_HiperakutAkut.png: 224x224 NormalKronik 0.83, HiperakutAkut 0.17, Subakut 0.00, 3.9ms
# Speed: 1.9ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_322493_50080951.6.10_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.9ms
# Speed: 2.0ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_322587_50115124.0.41_HiperakutAkut.png: 224x224 HiperakutAkut 0.94, NormalKronik 0.06, Subakut 0.00, 4.8ms
# Speed: 2.0ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_322727_50019091.0.20_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_322727_50019091.3.5_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.1ms
# Speed: 2.2ms preprocess, 5.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_322742_50434227.0.13_HiperakutAkut.png: 224x224 NormalKronik 0.82, HiperakutAkut 0.18, Subakut 0.00, 5.0ms
# Speed: 1.8ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_322742_50434227.3.13_HiperakutAkut.png: 224x224 NormalKronik 0.63, HiperakutAkut 0.37, Subakut 0.00, 4.6ms
# Speed: 1.9ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_323088_50162728.1.32_HiperakutAkut.png: 224x224 NormalKronik 0.65, Subakut 0.25, HiperakutAkut 0.10, 5.4ms
# Speed: 2.5ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_323088_50162728.1.6_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.9ms
# Speed: 1.8ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_323088_50162728.1.7_HiperakutAkut.png: 224x224 HiperakutAkut 0.99, NormalKronik 0.01, Subakut 0.00, 4.3ms
# Speed: 2.1ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_323088_50162728.2.8_HiperakutAkut.png: 224x224 HiperakutAkut 0.96, NormalKronik 0.04, Subakut 0.00, 4.8ms
# Speed: 2.4ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_323182_50473920.1.42_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 4.9ms
# Speed: 2.1ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_323310_50415913.0.10_HiperakutAkut.png: 224x224 NormalKronik 0.99, HiperakutAkut 0.01, Subakut 0.00, 5.0ms
# Speed: 1.8ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_323310_50415913.0.12_HiperakutAkut.png: 224x224 HiperakutAkut 0.99, NormalKronik 0.01, Subakut 0.00, 4.4ms
# Speed: 2.1ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_323310_50415913.0.32_HiperakutAkut.png: 224x224 HiperakutAkut 0.85, Subakut 0.14, NormalKronik 0.00, 3.9ms
# Speed: 3.0ms preprocess, 3.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_323310_50415913.0.47_HiperakutAkut.png: 224x224 HiperakutAkut 0.97, NormalKronik 0.03, Subakut 0.00, 5.5ms
# Speed: 2.4ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_323310_50415913.1.19_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 4.8ms
# Speed: 1.8ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_323707_50255719.1.15_HiperakutAkut.png: 224x224 NormalKronik 0.86, HiperakutAkut 0.14, Subakut 0.00, 26.2ms
# Speed: 3.1ms preprocess, 26.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_323985_50119318.0.11_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.2ms
# Speed: 3.8ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_323985_50119318.0.12_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.2ms
# Speed: 2.5ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_323985_50119318.1.11_HiperakutAkut.png: 224x224 HiperakutAkut 0.57, NormalKronik 0.43, Subakut 0.00, 4.7ms
# Speed: 3.3ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_323985_50119318.2.12_HiperakutAkut.png: 224x224 HiperakutAkut 0.77, NormalKronik 0.23, Subakut 0.00, 5.0ms
# Speed: 2.2ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_324729_50124511.2.14_HiperakutAkut.png: 224x224 HiperakutAkut 0.82, NormalKronik 0.18, Subakut 0.00, 4.6ms
# Speed: 2.1ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_324860_50354915.1.15_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.3ms
# Speed: 2.3ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_324860_50354915.2.11_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.9ms
# Speed: 2.4ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_326120_50002014.1.15_HiperakutAkut.png: 224x224 HiperakutAkut 0.99, NormalKronik 0.01, Subakut 0.00, 6.1ms
# Speed: 2.5ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_326120_50002014.1.35_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 5.8ms
# Speed: 3.6ms preprocess, 5.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_326120_50002014.1.37_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 6.2ms
# Speed: 2.9ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_326120_50002014.2.11_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_326218_50328363.1.54_HiperakutAkut.png: 224x224 Subakut 0.97, HiperakutAkut 0.03, NormalKronik 0.00, 5.9ms
# Speed: 1.9ms preprocess, 5.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: Subakut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_326218_50328363.2.19_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 5.7ms
# Speed: 1.9ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_326847_50254986.2.13_HiperakutAkut.png: 224x224 HiperakutAkut 0.68, NormalKronik 0.32, Subakut 0.00, 6.9ms
# Speed: 2.2ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_327848_50063043.2.11_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 6.4ms
# Speed: 4.6ms preprocess, 6.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_329284_50099969.2.14_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 4.1ms
# Speed: 2.9ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_329284_50099969.3.13_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 7.8ms
# Speed: 4.2ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_329284_50099969.3.15_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.8ms
# Speed: 4.5ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_329284_50099969.3.9_HiperakutAkut.png: 224x224 HiperakutAkut 0.92, NormalKronik 0.07, Subakut 0.01, 6.3ms
# Speed: 3.8ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_330331_50324298.2.14_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.3ms
# Speed: 2.2ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_330331_50324298.2.16_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.5ms
# Speed: 2.1ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_330331_50324298.6.15_HiperakutAkut.png: 224x224 HiperakutAkut 0.64, NormalKronik 0.36, Subakut 0.00, 4.1ms
# Speed: 3.4ms preprocess, 4.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_330362_50126698.0.37_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.2ms
# Speed: 2.9ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_330362_50126698.1.17_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 10.8ms
# Speed: 2.5ms preprocess, 10.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_330369_50255429.3.15_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 13.7ms
# Speed: 4.8ms preprocess, 13.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_330369_50255429.3.20_HiperakutAkut.png: 224x224 HiperakutAkut 0.99, Subakut 0.00, NormalKronik 0.00, 5.5ms
# Speed: 3.6ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_330401_50063326.2.10_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 11.4ms
# Speed: 3.8ms preprocess, 11.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_330401_50063326.2.35_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 5.1ms
# Speed: 2.2ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_330401_50063326.2.37_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 6.4ms
# Speed: 2.4ms preprocess, 6.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_330401_50063326.3.12_HiperakutAkut.png: 224x224 HiperakutAkut 0.99, NormalKronik 0.01, Subakut 0.00, 3.7ms
# Speed: 2.4ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_330401_50063326.3.9_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.4ms
# Speed: 1.9ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_334103_50475885.0.8_HiperakutAkut.png: 224x224 HiperakutAkut 0.99, NormalKronik 0.01, Subakut 0.00, 4.3ms
# Speed: 2.7ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_334103_50475885.2.33_HiperakutAkut.png: 224x224 NormalKronik 0.95, HiperakutAkut 0.05, Subakut 0.00, 7.6ms
# Speed: 3.2ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_334103_50475885.2.34_HiperakutAkut.png: 224x224 HiperakutAkut 0.86, NormalKronik 0.14, Subakut 0.00, 4.9ms
# Speed: 2.6ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_334194_50053334.0.21_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 3.8ms
# Speed: 2.5ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_334224_50173514.0.5_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.1ms
# Speed: 1.8ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_334224_50173514.3.26_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.0ms
# Speed: 2.3ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_334398_50134353.0.18_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.1ms
# Speed: 2.0ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_334398_50134353.0.24_HiperakutAkut.png: 224x224 HiperakutAkut 0.80, NormalKronik 0.20, Subakut 0.00, 5.1ms
# Speed: 1.9ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_334398_50134353.4.11_HiperakutAkut.png: 224x224 NormalKronik 1.00, HiperakutAkut 0.00, Subakut 0.00, 4.6ms
# Speed: 2.3ms preprocess, 4.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_334641_50267130.2.19_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 8.4ms
# Speed: 4.6ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_334641_50267130.2.44_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 4.6ms
# Speed: 2.3ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_334641_50267130.2.52_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.1ms
# Speed: 2.7ms preprocess, 4.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_334820_50109417.0.11_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 4.6ms
# Speed: 2.0ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_334820_50109417.0.12_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 4.1ms
# Speed: 2.0ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_334820_50109417.0.9_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 4.3ms
# Speed: 2.0ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_336117_50132053.0.20_HiperakutAkut.png: 224x224 HiperakutAkut 0.95, NormalKronik 0.05, Subakut 0.00, 4.5ms
# Speed: 1.8ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_336469_50056898.1.15_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 7.4ms
# Speed: 2.9ms preprocess, 7.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\HiperakutAkut\Vaka_336469_50056898.2.15_HiperakutAkut.png: 224x224 HiperakutAkut 0.96, NormalKronik 0.03, Subakut 0.01, 6.4ms
# Speed: 5.0ms preprocess, 6.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: HiperakutAkut, Predicted: HiperakutAkut
#
# ...
# Speed: 2.1ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: Subakut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_308970_50505686.2.42_Subakut.png: 224x224 HiperakutAkut 0.99, Subakut 0.01, NormalKronik 0.00, 5.4ms
# Speed: 2.2ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_308970_50505686.2.47_Subakut.png: 224x224 HiperakutAkut 0.83, NormalKronik 0.16, Subakut 0.01, 5.5ms
# Speed: 2.4ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_308970_50505686.3.8_Subakut.png: 224x224 Subakut 1.00, HiperakutAkut 0.00, NormalKronik 0.00, 14.4ms
# Speed: 4.4ms preprocess, 14.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: Subakut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_309953_50296583.1.21_Subakut.png: 224x224 Subakut 1.00, HiperakutAkut 0.00, NormalKronik 0.00, 5.6ms
# Speed: 3.1ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: Subakut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_310399_50531846.1.41_Subakut.png: 224x224 NormalKronik 0.90, Subakut 0.10, HiperakutAkut 0.00, 5.4ms
# Speed: 2.3ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_310399_50531846.3.19_Subakut.png: 224x224 Subakut 0.99, HiperakutAkut 0.01, NormalKronik 0.00, 5.8ms
# Speed: 3.9ms preprocess, 5.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: Subakut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_310412_50321357.2.41_Subakut.png: 224x224 NormalKronik 1.00, HiperakutAkut 0.00, Subakut 0.00, 5.2ms
# Speed: 2.5ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_312575_50472007.1.18_Subakut.png: 224x224 HiperakutAkut 0.99, Subakut 0.01, NormalKronik 0.00, 7.4ms
# Speed: 1.9ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_312575_50472007.2.18_Subakut.png: 224x224 Subakut 0.83, HiperakutAkut 0.17, NormalKronik 0.00, 5.7ms
# Speed: 2.2ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: Subakut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_313525_50574231.2.21_Subakut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.2ms
# Speed: 2.0ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_313525_50574231.2.33_Subakut.png: 224x224 HiperakutAkut 0.47, NormalKronik 0.44, Subakut 0.09, 5.2ms
# Speed: 1.9ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_313525_50574231.3.17_Subakut.png: 224x224 Subakut 0.99, NormalKronik 0.01, HiperakutAkut 0.00, 5.3ms
# Speed: 1.9ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: Subakut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_313525_50574231.3.2_Subakut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.3ms
# Speed: 1.8ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_314715_50284877.0.20_Subakut.png: 224x224 Subakut 1.00, HiperakutAkut 0.00, NormalKronik 0.00, 5.4ms
# Speed: 2.4ms preprocess, 5.4ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: Subakut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_314715_50284877.2.1_Subakut.png: 224x224 Subakut 1.00, HiperakutAkut 0.00, NormalKronik 0.00, 5.4ms
# Speed: 2.6ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: Subakut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_321052_50513346.1.39_Subakut.png: 224x224 Subakut 0.77, NormalKronik 0.23, HiperakutAkut 0.00, 5.2ms
# Speed: 1.8ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: Subakut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_321052_50513346.2.15_Subakut.png: 224x224 Subakut 0.95, HiperakutAkut 0.05, NormalKronik 0.00, 5.2ms
# Speed: 1.8ms preprocess, 5.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: Subakut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_324757_50383783.1.37_Subakut.png: 224x224 HiperakutAkut 0.95, Subakut 0.05, NormalKronik 0.00, 5.3ms
# Speed: 2.2ms preprocess, 5.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_324757_50383783.2.13_Subakut.png: 224x224 Subakut 1.00, HiperakutAkut 0.00, NormalKronik 0.00, 5.3ms
# Speed: 2.1ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: Subakut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_326765_50184294.2.15_Subakut.png: 224x224 Subakut 1.00, HiperakutAkut 0.00, NormalKronik 0.00, 5.2ms
# Speed: 1.9ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: Subakut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_326765_50184294.8.13_Subakut.png: 224x224 Subakut 1.00, NormalKronik 0.00, HiperakutAkut 0.00, 6.0ms
# Speed: 2.1ms preprocess, 6.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: Subakut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_330776_50343261.1.10_Subakut.png: 224x224 NormalKronik 1.00, Subakut 0.00, HiperakutAkut 0.00, 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_330776_50343261.2.3_Subakut.png: 224x224 Subakut 0.87, NormalKronik 0.13, HiperakutAkut 0.00, 7.1ms
# Speed: 1.9ms preprocess, 7.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: Subakut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_338935_50297952.5.26_Subakut.png: 224x224 Subakut 1.00, NormalKronik 0.00, HiperakutAkut 0.00, 9.9ms
# Speed: 4.1ms preprocess, 9.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: Subakut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_341291_50284944.1.19_Subakut.png: 224x224 Subakut 0.74, NormalKronik 0.23, HiperakutAkut 0.03, 9.0ms
# Speed: 4.7ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: Subakut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_341291_50284944.1.7_Subakut.png: 224x224 NormalKronik 0.74, HiperakutAkut 0.26, Subakut 0.00, 5.3ms
# Speed: 2.5ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_341291_50284944.2.6_Subakut.png: 224x224 HiperakutAkut 0.97, NormalKronik 0.03, Subakut 0.00, 10.9ms
# Speed: 3.8ms preprocess, 10.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_347663_50204467.1.25_Subakut.png: 224x224 HiperakutAkut 0.95, Subakut 0.05, NormalKronik 0.00, 7.2ms
# Speed: 4.3ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_347663_50204467.4.10_Subakut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 8.3ms
# Speed: 3.4ms preprocess, 8.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_349368_50499246.1.14_Subakut.png: 224x224 Subakut 0.70, NormalKronik 0.19, HiperakutAkut 0.11, 6.0ms
# Speed: 2.9ms preprocess, 6.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: Subakut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_349949_50252101.4.7_Subakut.png: 224x224 Subakut 1.00, HiperakutAkut 0.00, NormalKronik 0.00, 12.9ms
# Speed: 5.0ms preprocess, 12.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: Subakut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_351732_50515687.1.14_Subakut.png: 224x224 Subakut 1.00, NormalKronik 0.00, HiperakutAkut 0.00, 5.2ms
# Speed: 2.6ms preprocess, 5.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: Subakut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_351732_50515687.1.39_Subakut.png: 224x224 Subakut 0.97, NormalKronik 0.03, HiperakutAkut 0.00, 6.2ms
# Speed: 2.7ms preprocess, 6.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: Subakut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_351732_50515687.2.15_Subakut.png: 224x224 Subakut 0.92, NormalKronik 0.08, HiperakutAkut 0.00, 5.9ms
# Speed: 2.6ms preprocess, 5.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: Subakut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_359051_50044484.2.18_Subakut.png: 224x224 Subakut 1.00, HiperakutAkut 0.00, NormalKronik 0.00, 5.1ms
# Speed: 3.0ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: Subakut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_359786_50451936.1.9_Subakut.png: 224x224 NormalKronik 0.71, Subakut 0.29, HiperakutAkut 0.00, 5.1ms
# Speed: 2.7ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_359786_50451936.2.4_Subakut.png: 224x224 Subakut 1.00, HiperakutAkut 0.00, NormalKronik 0.00, 16.5ms
# Speed: 6.3ms preprocess, 16.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: Subakut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_363238_50328568.2.19_Subakut.png: 224x224 Subakut 0.89, HiperakutAkut 0.11, NormalKronik 0.00, 12.4ms
# Speed: 2.4ms preprocess, 12.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: Subakut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_363238_50328568.2.7_Subakut.png: 224x224 Subakut 1.00, HiperakutAkut 0.00, NormalKronik 0.00, 6.7ms
# Speed: 2.6ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: Subakut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_363238_50328568.3.18_Subakut.png: 224x224 Subakut 1.00, NormalKronik 0.00, HiperakutAkut 0.00, 8.7ms
# Speed: 2.1ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: Subakut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_363238_50328568.3.19_Subakut.png: 224x224 Subakut 1.00, HiperakutAkut 0.00, NormalKronik 0.00, 5.0ms
# Speed: 1.8ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: Subakut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_367103_50357972.2.22_Subakut.png: 224x224 Subakut 0.98, HiperakutAkut 0.02, NormalKronik 0.01, 5.0ms
# Speed: 1.9ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: Subakut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_367919_50539583.2.5_Subakut.png: 224x224 HiperakutAkut 0.73, NormalKronik 0.25, Subakut 0.02, 5.0ms
# Speed: 2.4ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_367919_50539583.2.7_Subakut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.1ms
# Speed: 1.8ms preprocess, 5.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: HiperakutAkut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_375974_50137090.1.14_Subakut.png: 224x224 NormalKronik 0.50, HiperakutAkut 0.49, Subakut 0.01, 5.1ms
# Speed: 2.2ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: NormalKronik
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_380157_50451845.1.21_Subakut.png: 224x224 Subakut 1.00, HiperakutAkut 0.00, NormalKronik 0.00, 5.0ms
# Speed: 1.9ms preprocess, 5.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: Subakut
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofest25Veri\DoubleModel\..\Yolo\Toplu\val\Subakut\Vaka_380157_50451845.3.9_Subakut.png: 224x224 Subakut 1.00, HiperakutAkut 0.00, NormalKronik 0.00, 5.1ms
# Speed: 2.1ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: Subakut, Predicted: Subakut
# True: 752, False: 129
# Accuracy: 85.36%
#
# Confusion matrix saved to confusion_matrix.png
