# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n-cls.pt")  # load a pretrained model (recommended for training)

# Train the model
results = model.train(data='../AllData/ClassificationData/classification.yaml', epochs=100, imgsz=512)
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'yoloP (Python 3.9.19)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import numpy
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'yoloP (Python 3.9.19)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
