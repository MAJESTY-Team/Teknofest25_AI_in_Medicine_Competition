# %%
from ultralytics import YOLO
model = YOLO("../training_code/runs/classify/yolo11n-cls_init/weights/best.pt") 

read_dir="../trainingData/train"
output_dir="./Assistance_required_data"

# %%
import shutil
from pathlib import Path
import os
IMAGE_EXTENSIONS = {'.png'}

def read_images(root_dir):
    root = Path(root_dir)
    for path in root.rglob('*'):
        if path.suffix.lower() in IMAGE_EXTENSIONS:
            yield path

# Usage
for path in read_images(read_dir):
    # if(str(path).find("CT")!=-1):
    #     continue

    label=path.stem.split("_")[-1]
    # name=f"{caseNum}_"+path.name
    result=model.predict(source=path, save=False)
    result=result[0]
    pred=result.probs.top1
    if result.names[pred].lower() == label.lower():
        continue
    dst=os.path.join(output_dir, label, result.names[pred])
    os.makedirs(dst, exist_ok=True)
    name=path.name
    shutil.copyfile(path, os.path.join(dst, name))
    print(f"True label: {label}, Predicted: {result.names[pred]}")
    print(f"Image saved to {os.path.join(dst, name)}")
# Out:
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10002_var.png: 224x224 var 1.00, yok 0.00, 3.4ms
# Speed: 11.4ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10007_var.png: 224x224 var 1.00, yok 0.00, 3.4ms
# Speed: 2.6ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10017_var.png: 224x224 var 1.00, yok 0.00, 3.8ms
# Speed: 2.7ms preprocess, 3.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10028_var.png: 224x224 var 1.00, yok 0.00, 3.4ms
# Speed: 3.0ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10029_var.png: 224x224 var 1.00, yok 0.00, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10033_var.png: 224x224 var 1.00, yok 0.00, 6.3ms
# Speed: 2.7ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10036_var.png: 224x224 var 1.00, yok 0.00, 3.7ms
# Speed: 2.8ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10038_var.png: 224x224 var 1.00, yok 0.00, 3.5ms
# Speed: 3.3ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10039_var.png: 224x224 var 1.00, yok 0.00, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10046_var.png: 224x224 var 1.00, yok 0.00, 3.6ms
# Speed: 2.9ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10047_var.png: 224x224 var 1.00, yok 0.00, 3.3ms
# Speed: 2.9ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10049_var.png: 224x224 var 1.00, yok 0.00, 3.3ms
# Speed: 3.0ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10050_var.png: 224x224 var 1.00, yok 0.00, 4.1ms
# Speed: 3.3ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10053_var.png: 224x224 var 1.00, yok 0.00, 3.6ms
# Speed: 3.4ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10059_var.png: 224x224 var 1.00, yok 0.00, 3.7ms
# Speed: 2.7ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10062_var.png: 224x224 var 1.00, yok 0.00, 7.6ms
# Speed: 5.5ms preprocess, 7.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10067_var.png: 224x224 var 1.00, yok 0.00, 4.8ms
# Speed: 4.0ms preprocess, 4.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10068_var.png: 224x224 var 1.00, yok 0.00, 3.7ms
# Speed: 3.2ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10072_var.png: 224x224 var 1.00, yok 0.00, 3.8ms
# Speed: 2.9ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10073_var.png: 224x224 var 1.00, yok 0.00, 4.6ms
# Speed: 2.7ms preprocess, 4.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10075_var.png: 224x224 var 1.00, yok 0.00, 3.4ms
# Speed: 3.4ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10077_var.png: 224x224 var 1.00, yok 0.00, 4.6ms
# Speed: 4.0ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10078_var.png: 224x224 var 1.00, yok 0.00, 4.6ms
# Speed: 4.1ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10088_var.png: 224x224 var 1.00, yok 0.00, 4.8ms
# Speed: 3.2ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10094_var.png: 224x224 var 1.00, yok 0.00, 4.5ms
# Speed: 3.2ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10095_var.png: 224x224 var 1.00, yok 0.00, 5.3ms
# Speed: 3.1ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10101_var.png: 224x224 var 1.00, yok 0.00, 5.5ms
# Speed: 3.1ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10105_var.png: 224x224 var 1.00, yok 0.00, 4.3ms
# Speed: 3.4ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10120_var.png: 224x224 var 1.00, yok 0.00, 4.4ms
# Speed: 3.2ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10134_var.png: 224x224 var 1.00, yok 0.00, 4.8ms
# Speed: 3.7ms preprocess, 4.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10143_var.png: 224x224 var 1.00, yok 0.00, 4.1ms
# Speed: 3.2ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10145_var.png: 224x224 var 1.00, yok 0.00, 3.6ms
# Speed: 3.5ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10146_var.png: 224x224 var 1.00, yok 0.00, 6.7ms
# Speed: 4.4ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10150_var.png: 224x224 var 1.00, yok 0.00, 4.7ms
# Speed: 3.3ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10151_var.png: 224x224 var 1.00, yok 0.00, 8.6ms
# Speed: 3.2ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10153_var.png: 224x224 var 1.00, yok 0.00, 3.7ms
# Speed: 3.5ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10155_var.png: 224x224 var 1.00, yok 0.00, 3.8ms
# Speed: 3.8ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10156_var.png: 224x224 var 1.00, yok 0.00, 4.2ms
# Speed: 3.6ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10158_var.png: 224x224 var 1.00, yok 0.00, 3.6ms
# Speed: 3.7ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10164_var.png: 224x224 var 1.00, yok 0.00, 3.9ms
# Speed: 4.1ms preprocess, 3.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10179_var.png: 224x224 var 1.00, yok 0.00, 5.3ms
# Speed: 4.1ms preprocess, 5.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10181_var.png: 224x224 var 0.99, yok 0.01, 10.9ms
# Speed: 8.4ms preprocess, 10.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10187_var.png: 224x224 var 1.00, yok 0.00, 5.1ms
# Speed: 6.8ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10188_var.png: 224x224 var 1.00, yok 0.00, 6.5ms
# Speed: 3.5ms preprocess, 6.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10190_var.png: 224x224 var 1.00, yok 0.00, 4.7ms
# Speed: 3.6ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10194_var.png: 224x224 var 1.00, yok 0.00, 4.6ms
# Speed: 3.8ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10202_var.png: 224x224 var 1.00, yok 0.00, 4.0ms
# Speed: 3.8ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10206_var.png: 224x224 var 1.00, yok 0.00, 5.9ms
# Speed: 3.8ms preprocess, 5.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10209_var.png: 224x224 var 1.00, yok 0.00, 4.2ms
# Speed: 3.9ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10210_var.png: 224x224 var 1.00, yok 0.00, 4.1ms
# Speed: 3.6ms preprocess, 4.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10214_var.png: 224x224 var 1.00, yok 0.00, 3.7ms
# Speed: 3.9ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10222_var.png: 224x224 var 1.00, yok 0.00, 7.0ms
# Speed: 4.1ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10227_var.png: 224x224 var 1.00, yok 0.00, 5.1ms
# Speed: 3.2ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10234_var.png: 224x224 var 1.00, yok 0.00, 7.9ms
# Speed: 3.1ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10236_var.png: 224x224 var 1.00, yok 0.00, 3.5ms
# Speed: 3.6ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10238_var.png: 224x224 var 1.00, yok 0.00, 3.9ms
# Speed: 4.0ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10241_var.png: 224x224 var 1.00, yok 0.00, 4.8ms
# Speed: 4.1ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10242_var.png: 224x224 var 1.00, yok 0.00, 3.6ms
# Speed: 3.9ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10245_var.png: 224x224 var 1.00, yok 0.00, 6.5ms
# Speed: 3.5ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10248_var.png: 224x224 var 0.97, yok 0.03, 4.5ms
# Speed: 3.3ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10250_var.png: 224x224 var 1.00, yok 0.00, 4.6ms
# Speed: 3.2ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10253_var.png: 224x224 var 1.00, yok 0.00, 4.5ms
# Speed: 3.1ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10261_var.png: 224x224 var 1.00, yok 0.00, 3.8ms
# Speed: 3.0ms preprocess, 3.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10262_var.png: 224x224 var 1.00, yok 0.00, 4.6ms
# Speed: 3.5ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10263_var.png: 224x224 var 1.00, yok 0.00, 4.7ms
# Speed: 3.7ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10265_var.png: 224x224 var 1.00, yok 0.00, 4.3ms
# Speed: 3.7ms preprocess, 4.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10268_var.png: 224x224 var 1.00, yok 0.00, 3.9ms
# Speed: 3.8ms preprocess, 3.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10271_var.png: 224x224 var 1.00, yok 0.00, 5.9ms
# Speed: 4.0ms preprocess, 5.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10273_var.png: 224x224 var 1.00, yok 0.00, 5.2ms
# Speed: 3.4ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10276_var.png: 224x224 var 1.00, yok 0.00, 3.9ms
# Speed: 3.7ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10278_var.png: 224x224 var 1.00, yok 0.00, 3.9ms
# Speed: 3.7ms preprocess, 3.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10280_var.png: 224x224 var 1.00, yok 0.00, 3.6ms
# Speed: 3.3ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10289_var.png: 224x224 var 1.00, yok 0.00, 3.7ms
# Speed: 3.1ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10290_var.png: 224x224 var 1.00, yok 0.00, 3.8ms
# Speed: 2.9ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10296_var.png: 224x224 var 1.00, yok 0.00, 13.1ms
# Speed: 5.0ms preprocess, 13.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10305_var.png: 224x224 var 1.00, yok 0.00, 4.7ms
# Speed: 4.0ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10307_var.png: 224x224 var 1.00, yok 0.00, 4.4ms
# Speed: 3.8ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10309_var.png: 224x224 var 1.00, yok 0.00, 4.1ms
# Speed: 3.2ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10310_var.png: 224x224 var 1.00, yok 0.00, 4.5ms
# Speed: 3.3ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10320_var.png: 224x224 var 1.00, yok 0.00, 4.5ms
# Speed: 2.9ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10323_var.png: 224x224 var 1.00, yok 0.00, 4.0ms
# Speed: 3.1ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10328_var.png: 224x224 var 1.00, yok 0.00, 3.7ms
# Speed: 3.3ms preprocess, 3.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10329_var.png: 224x224 var 1.00, yok 0.00, 3.9ms
# Speed: 3.4ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10330_var.png: 224x224 var 1.00, yok 0.00, 4.1ms
# Speed: 3.3ms preprocess, 4.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10331_var.png: 224x224 var 1.00, yok 0.00, 4.3ms
# Speed: 3.6ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10346_var.png: 224x224 var 1.00, yok 0.00, 5.2ms
# Speed: 3.5ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10350_var.png: 224x224 var 1.00, yok 0.00, 3.7ms
# Speed: 3.5ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10351_var.png: 224x224 var 1.00, yok 0.00, 4.9ms
# Speed: 4.0ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10354_var.png: 224x224 var 1.00, yok 0.00, 5.5ms
# Speed: 4.7ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10355_var.png: 224x224 var 1.00, yok 0.00, 4.1ms
# Speed: 3.6ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10356_var.png: 224x224 var 1.00, yok 0.00, 3.5ms
# Speed: 2.9ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10362_var.png: 224x224 var 1.00, yok 0.00, 8.0ms
# Speed: 2.8ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10363_var.png: 224x224 var 1.00, yok 0.00, 3.6ms
# Speed: 3.2ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10364_var.png: 224x224 var 1.00, yok 0.00, 7.8ms
# Speed: 3.6ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10367_var.png: 224x224 var 1.00, yok 0.00, 3.8ms
# Speed: 3.2ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10377_var.png: 224x224 var 1.00, yok 0.00, 3.8ms
# Speed: 3.3ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10388_var.png: 224x224 var 1.00, yok 0.00, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10391_var.png: 224x224 var 1.00, yok 0.00, 4.4ms
# Speed: 2.8ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10395_var.png: 224x224 var 1.00, yok 0.00, 4.2ms
# Speed: 2.9ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10397_var.png: 224x224 var 1.00, yok 0.00, 4.0ms
# Speed: 3.2ms preprocess, 4.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10403_var.png: 224x224 var 1.00, yok 0.00, 3.9ms
# Speed: 3.4ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10404_var.png: 224x224 var 1.00, yok 0.00, 6.6ms
# Speed: 4.0ms preprocess, 6.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10415_var.png: 224x224 var 1.00, yok 0.00, 5.7ms
# Speed: 6.4ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10418_var.png: 224x224 var 1.00, yok 0.00, 5.9ms
# Speed: 5.8ms preprocess, 5.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10430_var.png: 224x224 var 1.00, yok 0.00, 3.8ms
# Speed: 3.3ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10434_var.png: 224x224 var 1.00, yok 0.00, 3.7ms
# Speed: 3.3ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10436_var.png: 224x224 var 1.00, yok 0.00, 7.5ms
# Speed: 3.2ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10437_var.png: 224x224 var 1.00, yok 0.00, 3.8ms
# Speed: 3.1ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10440_var.png: 224x224 var 1.00, yok 0.00, 3.7ms
# Speed: 3.1ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10442_var.png: 224x224 var 1.00, yok 0.00, 3.5ms
# Speed: 3.2ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10444_var.png: 224x224 var 1.00, yok 0.00, 3.8ms
# Speed: 3.1ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10446_var.png: 224x224 var 1.00, yok 0.00, 3.5ms
# Speed: 3.1ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10447_var.png: 224x224 var 1.00, yok 0.00, 3.5ms
# Speed: 3.1ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10448_var.png: 224x224 var 1.00, yok 0.00, 3.4ms
# Speed: 3.1ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10449_var.png: 224x224 var 1.00, yok 0.00, 3.7ms
# Speed: 4.5ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10453_var.png: 224x224 var 1.00, yok 0.00, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10459_var.png: 224x224 var 1.00, yok 0.00, 4.0ms
# Speed: 2.7ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10461_var.png: 224x224 var 1.00, yok 0.00, 4.0ms
# Speed: 2.9ms preprocess, 4.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10466_var.png: 224x224 var 1.00, yok 0.00, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10476_var.png: 224x224 var 1.00, yok 0.00, 4.1ms
# Speed: 3.1ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10477_var.png: 224x224 var 1.00, yok 0.00, 4.0ms
# Speed: 3.1ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10479_var.png: 224x224 var 1.00, yok 0.00, 3.8ms
# Speed: 2.8ms preprocess, 3.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10481_var.png: 224x224 var 1.00, yok 0.00, 3.6ms
# Speed: 3.2ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10485_var.png: 224x224 var 1.00, yok 0.00, 5.6ms
# Speed: 3.4ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10486_var.png: 224x224 var 1.00, yok 0.00, 3.5ms
# Speed: 3.2ms preprocess, 3.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10489_var.png: 224x224 var 0.98, yok 0.02, 3.5ms
# Speed: 3.1ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10499_var.png: 224x224 var 1.00, yok 0.00, 3.9ms
# Speed: 2.8ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10501_var.png: 224x224 var 1.00, yok 0.00, 3.8ms
# Speed: 3.1ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10507_var.png: 224x224 var 1.00, yok 0.00, 3.5ms
# Speed: 3.2ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10509_var.png: 224x224 var 1.00, yok 0.00, 7.6ms
# Speed: 4.3ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10518_var.png: 224x224 var 1.00, yok 0.00, 6.2ms
# Speed: 6.1ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10519_var.png: 224x224 var 1.00, yok 0.00, 7.3ms
# Speed: 3.7ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10522_var.png: 224x224 var 1.00, yok 0.00, 7.9ms
# Speed: 3.4ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10525_var.png: 224x224 var 1.00, yok 0.00, 3.5ms
# Speed: 3.1ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10528_var.png: 224x224 var 1.00, yok 0.00, 3.6ms
# Speed: 3.0ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10532_var.png: 224x224 var 1.00, yok 0.00, 3.7ms
# Speed: 2.8ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10538_var.png: 224x224 var 1.00, yok 0.00, 7.2ms
# Speed: 3.2ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10539_var.png: 224x224 var 1.00, yok 0.00, 3.5ms
# Speed: 2.8ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10542_var.png: 224x224 var 1.00, yok 0.00, 4.4ms
# Speed: 3.7ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10547_var.png: 224x224 var 1.00, yok 0.00, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10555_var.png: 224x224 var 1.00, yok 0.00, 4.0ms
# Speed: 2.8ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10561_var.png: 224x224 var 1.00, yok 0.00, 3.8ms
# Speed: 2.8ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10563_var.png: 224x224 var 1.00, yok 0.00, 4.0ms
# Speed: 3.9ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10567_var.png: 224x224 var 1.00, yok 0.00, 3.9ms
# Speed: 3.2ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10568_var.png: 224x224 var 1.00, yok 0.00, 3.4ms
# Speed: 3.2ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10575_var.png: 224x224 var 1.00, yok 0.00, 3.8ms
# Speed: 2.7ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10579_var.png: 224x224 var 1.00, yok 0.00, 4.1ms
# Speed: 3.2ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10594_var.png: 224x224 var 1.00, yok 0.00, 3.5ms
# Speed: 3.2ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10595_var.png: 224x224 var 1.00, yok 0.00, 3.4ms
# Speed: 3.4ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10599_var.png: 224x224 var 1.00, yok 0.00, 3.8ms
# Speed: 2.8ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10600_var.png: 224x224 var 1.00, yok 0.00, 3.7ms
# Speed: 2.8ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10603_var.png: 224x224 var 1.00, yok 0.00, 3.4ms
# Speed: 3.2ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10611_var.png: 224x224 var 1.00, yok 0.00, 3.6ms
# Speed: 3.0ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10613_var.png: 224x224 var 1.00, yok 0.00, 6.4ms
# Speed: 2.7ms preprocess, 6.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10627_var.png: 224x224 var 1.00, yok 0.00, 5.6ms
# Speed: 5.8ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10635_var.png: 224x224 var 1.00, yok 0.00, 4.4ms
# Speed: 4.0ms preprocess, 4.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10637_var.png: 224x224 var 1.00, yok 0.00, 4.3ms
# Speed: 3.5ms preprocess, 4.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10642_var.png: 224x224 var 1.00, yok 0.00, 5.2ms
# Speed: 3.3ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10644_var.png: 224x224 var 1.00, yok 0.00, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10645_var.png: 224x224 var 1.00, yok 0.00, 3.6ms
# Speed: 2.9ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10650_var.png: 224x224 var 1.00, yok 0.00, 5.5ms
# Speed: 2.8ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10657_var.png: 224x224 var 1.00, yok 0.00, 3.5ms
# Speed: 3.1ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10682_var.png: 224x224 var 1.00, yok 0.00, 3.7ms
# Speed: 3.1ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10687_var.png: 224x224 var 1.00, yok 0.00, 3.7ms
# Speed: 3.1ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10688_var.png: 224x224 var 1.00, yok 0.00, 3.7ms
# Speed: 2.7ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10690_var.png: 224x224 var 1.00, yok 0.00, 3.6ms
# Speed: 3.2ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10691_var.png: 224x224 var 1.00, yok 0.00, 6.3ms
# Speed: 3.3ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10694_var.png: 224x224 var 1.00, yok 0.00, 3.5ms
# Speed: 3.2ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10696_var.png: 224x224 var 1.00, yok 0.00, 3.6ms
# Speed: 2.8ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10697_var.png: 224x224 var 1.00, yok 0.00, 5.3ms
# Speed: 2.9ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10701_var.png: 224x224 var 1.00, yok 0.00, 3.7ms
# Speed: 2.9ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10702_var.png: 224x224 var 1.00, yok 0.00, 3.6ms
# Speed: 3.0ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10703_var.png: 224x224 var 1.00, yok 0.00, 4.1ms
# Speed: 3.2ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10705_var.png: 224x224 var 1.00, yok 0.00, 3.3ms
# Speed: 3.2ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10713_var.png: 224x224 var 1.00, yok 0.00, 3.8ms
# Speed: 2.8ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10714_var.png: 224x224 var 1.00, yok 0.00, 3.8ms
# Speed: 3.0ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10715_var.png: 224x224 var 1.00, yok 0.00, 3.4ms
# Speed: 3.0ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10719_var.png: 224x224 var 1.00, yok 0.00, 4.3ms
# Speed: 3.6ms preprocess, 4.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10726_var.png: 224x224 var 1.00, yok 0.00, 5.7ms
# Speed: 6.1ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10729_var.png: 224x224 var 1.00, yok 0.00, 4.7ms
# Speed: 4.8ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10730_var.png: 224x224 var 1.00, yok 0.00, 4.2ms
# Speed: 3.4ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10734_var.png: 224x224 var 1.00, yok 0.00, 3.9ms
# Speed: 2.8ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10737_var.png: 224x224 var 1.00, yok 0.00, 7.2ms
# Speed: 3.3ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10743_var.png: 224x224 var 1.00, yok 0.00, 3.6ms
# Speed: 2.7ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10745_var.png: 224x224 var 1.00, yok 0.00, 3.6ms
# Speed: 3.1ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10747_var.png: 224x224 var 1.00, yok 0.00, 6.2ms
# Speed: 3.3ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10754_var.png: 224x224 var 1.00, yok 0.00, 3.6ms
# Speed: 3.0ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10755_var.png: 224x224 var 1.00, yok 0.00, 3.7ms
# Speed: 3.2ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10758_var.png: 224x224 var 1.00, yok 0.00, 4.0ms
# Speed: 2.8ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10761_var.png: 224x224 var 1.00, yok 0.00, 3.4ms
# Speed: 3.1ms preprocess, 3.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10766_var.png: 224x224 var 1.00, yok 0.00, 3.4ms
# Speed: 3.0ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10769_var.png: 224x224 var 1.00, yok 0.00, 5.6ms
# Speed: 2.8ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10770_var.png: 224x224 var 1.00, yok 0.00, 3.6ms
# Speed: 2.9ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10771_var.png: 224x224 var 1.00, yok 0.00, 3.6ms
# Speed: 3.2ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10777_var.png: 224x224 var 1.00, yok 0.00, 3.5ms
# Speed: 3.1ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10783_var.png: 224x224 var 1.00, yok 0.00, 3.8ms
# Speed: 2.8ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10786_var.png: 224x224 var 1.00, yok 0.00, 3.5ms
# Speed: 3.0ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10787_var.png: 224x224 var 1.00, yok 0.00, 3.5ms
# Speed: 3.2ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10788_var.png: 224x224 var 1.00, yok 0.00, 3.5ms
# Speed: 3.1ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10793_var.png: 224x224 var 1.00, yok 0.00, 3.7ms
# Speed: 3.3ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\var\10795_var.png: 224x224 var 0.90, yok 0.10, 9.8ms
# ...
# Speed: 4.3ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\96 (13)_yok.png: 224x224 yok 1.00, var 0.00, 6.7ms
# Speed: 4.9ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\96 (14)_yok.png: 224x224 yok 1.00, var 0.00, 6.6ms
# Speed: 3.4ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\96 (16)_yok.png: 224x224 yok 0.99, var 0.01, 6.3ms
# Speed: 3.6ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\96 (17)_yok.png: 224x224 yok 1.00, var 0.00, 11.0ms
# Speed: 10.0ms preprocess, 11.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\96 (19)_yok.png: 224x224 yok 1.00, var 0.00, 6.4ms
# Speed: 4.6ms preprocess, 6.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\96 (2)_yok.png: 224x224 yok 1.00, var 0.00, 6.4ms
# Speed: 5.2ms preprocess, 6.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\96 (20)_yok.png: 224x224 yok 1.00, var 0.00, 9.9ms
# Speed: 6.5ms preprocess, 9.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\96 (21)_yok.png: 224x224 yok 1.00, var 0.00, 7.9ms
# Speed: 7.3ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\96 (22)_yok.png: 224x224 yok 1.00, var 0.00, 6.6ms
# Speed: 5.4ms preprocess, 6.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\96 (23)_yok.png: 224x224 yok 0.98, var 0.02, 6.4ms
# Speed: 4.4ms preprocess, 6.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\96 (26)_yok.png: 224x224 yok 1.00, var 0.00, 6.8ms
# Speed: 5.1ms preprocess, 6.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\96 (28)_yok.png: 224x224 yok 1.00, var 0.00, 6.7ms
# Speed: 4.2ms preprocess, 6.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\96 (29)_yok.png: 224x224 yok 1.00, var 0.00, 6.3ms
# Speed: 8.3ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\96 (3)_yok.png: 224x224 yok 1.00, var 0.00, 6.9ms
# Speed: 6.2ms preprocess, 6.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\96 (30)_yok.png: 224x224 yok 1.00, var 0.00, 6.5ms
# Speed: 6.4ms preprocess, 6.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\96 (31)_yok.png: 224x224 yok 1.00, var 0.00, 7.5ms
# Speed: 3.6ms preprocess, 7.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\96 (32)_yok.png: 224x224 yok 1.00, var 0.00, 6.6ms
# Speed: 4.4ms preprocess, 6.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\96 (4)_yok.png: 224x224 yok 1.00, var 0.00, 6.5ms
# Speed: 6.4ms preprocess, 6.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\96 (5)_yok.png: 224x224 yok 0.99, var 0.01, 10.6ms
# Speed: 4.6ms preprocess, 10.6ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\96 (6)_yok.png: 224x224 yok 1.00, var 0.00, 6.7ms
# Speed: 4.4ms preprocess, 6.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\96 (7)_yok.png: 224x224 yok 1.00, var 0.00, 6.7ms
# Speed: 4.2ms preprocess, 6.7ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\96 (9)_yok.png: 224x224 yok 1.00, var 0.00, 6.7ms
# Speed: 4.4ms preprocess, 6.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\98 (1)_yok.png: 224x224 yok 1.00, var 0.00, 6.7ms
# Speed: 4.6ms preprocess, 6.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\98 (10)_yok.png: 224x224 yok 1.00, var 0.00, 6.3ms
# Speed: 4.0ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\98 (11)_yok.png: 224x224 yok 1.00, var 0.00, 6.7ms
# Speed: 3.9ms preprocess, 6.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\98 (12)_yok.png: 224x224 yok 1.00, var 0.00, 6.3ms
# Speed: 3.5ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\98 (14)_yok.png: 224x224 yok 1.00, var 0.00, 6.4ms
# Speed: 5.5ms preprocess, 6.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\98 (15)_yok.png: 224x224 yok 1.00, var 0.00, 6.8ms
# Speed: 6.1ms preprocess, 6.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\98 (19)_yok.png: 224x224 yok 1.00, var 0.00, 6.6ms
# Speed: 4.0ms preprocess, 6.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\98 (2)_yok.png: 224x224 yok 1.00, var 0.00, 6.4ms
# Speed: 3.7ms preprocess, 6.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\98 (20)_yok.png: 224x224 yok 1.00, var 0.00, 6.5ms
# Speed: 3.3ms preprocess, 6.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\98 (21)_yok.png: 224x224 yok 1.00, var 0.00, 6.3ms
# Speed: 3.4ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\98 (22)_yok.png: 224x224 yok 1.00, var 0.00, 6.7ms
# Speed: 6.3ms preprocess, 6.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\98 (23)_yok.png: 224x224 yok 1.00, var 0.00, 6.6ms
# Speed: 4.6ms preprocess, 6.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\98 (25)_yok.png: 224x224 yok 1.00, var 0.00, 9.5ms
# Speed: 6.4ms preprocess, 9.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\98 (26)_yok.png: 224x224 yok 1.00, var 0.00, 8.0ms
# Speed: 4.4ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\98 (27)_yok.png: 224x224 yok 1.00, var 0.00, 6.4ms
# Speed: 6.5ms preprocess, 6.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\98 (28)_yok.png: 224x224 yok 1.00, var 0.00, 6.3ms
# Speed: 4.6ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\98 (29)_yok.png: 224x224 yok 1.00, var 0.00, 10.8ms
# Speed: 7.2ms preprocess, 10.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\98 (3)_yok.png: 224x224 yok 1.00, var 0.00, 9.5ms
# Speed: 7.3ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\98 (4)_yok.png: 224x224 yok 1.00, var 0.00, 6.4ms
# Speed: 6.8ms preprocess, 6.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\98 (5)_yok.png: 224x224 yok 1.00, var 0.00, 6.3ms
# Speed: 3.5ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\98 (6)_yok.png: 224x224 yok 1.00, var 0.00, 7.2ms
# Speed: 5.0ms preprocess, 7.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\98 (7)_yok.png: 224x224 yok 1.00, var 0.00, 6.3ms
# Speed: 4.2ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\98 (8)_yok.png: 224x224 yok 1.00, var 0.00, 6.6ms
# Speed: 4.2ms preprocess, 6.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\99 (1)_yok.png: 224x224 yok 1.00, var 0.00, 7.4ms
# Speed: 4.1ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\99 (11)_yok.png: 224x224 yok 1.00, var 0.00, 6.3ms
# Speed: 3.7ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\99 (13)_yok.png: 224x224 yok 1.00, var 0.00, 6.6ms
# Speed: 5.6ms preprocess, 6.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\99 (14)_yok.png: 224x224 yok 1.00, var 0.00, 7.7ms
# Speed: 4.6ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\99 (15)_yok.png: 224x224 yok 1.00, var 0.00, 6.3ms
# Speed: 4.3ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\99 (17)_yok.png: 224x224 yok 1.00, var 0.00, 9.2ms
# Speed: 6.4ms preprocess, 9.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\99 (19)_yok.png: 224x224 yok 1.00, var 0.00, 6.3ms
# Speed: 3.8ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\99 (20)_yok.png: 224x224 yok 1.00, var 0.00, 8.9ms
# Speed: 6.3ms preprocess, 8.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\99 (21)_yok.png: 224x224 yok 1.00, var 0.00, 6.6ms
# Speed: 5.6ms preprocess, 6.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\99 (22)_yok.png: 224x224 yok 1.00, var 0.00, 6.3ms
# Speed: 4.8ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\99 (23)_yok.png: 224x224 yok 1.00, var 0.00, 11.2ms
# Speed: 6.8ms preprocess, 11.2ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\99 (24)_yok.png: 224x224 yok 1.00, var 0.00, 8.1ms
# Speed: 4.5ms preprocess, 8.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\99 (26)_yok.png: 224x224 yok 1.00, var 0.00, 6.6ms
# Speed: 3.8ms preprocess, 6.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\99 (27)_yok.png: 224x224 yok 1.00, var 0.00, 7.4ms
# Speed: 3.6ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\99 (29)_yok.png: 224x224 yok 1.00, var 0.00, 6.8ms
# Speed: 4.9ms preprocess, 6.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\99 (4)_yok.png: 224x224 yok 1.00, var 0.00, 6.6ms
# Speed: 4.5ms preprocess, 6.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\99 (5)_yok.png: 224x224 yok 1.00, var 0.00, 10.8ms
# Speed: 4.2ms preprocess, 10.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\99 (6)_yok.png: 224x224 yok 1.00, var 0.00, 7.0ms
# Speed: 4.2ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\99 (7)_yok.png: 224x224 yok 1.00, var 0.00, 6.3ms
# Speed: 3.6ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\99 (8)_yok.png: 224x224 yok 1.00, var 0.00, 6.4ms
# Speed: 5.7ms preprocess, 6.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Desktop\Teknofestt 1\training_pipeline\..\trainingData\train\yok\99 (9)_yok.png: 224x224 yok 1.00, var 0.00, 8.5ms
# Speed: 7.5ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)

# %%
import os
from PIL import Image, ImageEnhance, ImageOps
import random

# 1) Configuration: point these to your folders
input_dir = 'Assistance_required_data'    # Folder containing original images
output_dir = "../trainingData/train"  # Folder to save augmented images
aug_per_image = 3            # How many augmented copies per original

# Ensure output folder exists
os.makedirs(output_dir, exist_ok=True)

def random_flip(img):
    """Random horizontal and/or vertical flip."""
    if random.choice([True, False]):
        img = ImageOps.mirror(img)
    if random.choice([True, False]):
        img = ImageOps.flip(img)
    return img

def random_rotation(img):
    """Rotate by a random angle between -30 and +30 degrees."""
    angle = random.uniform(-40, 40)
    return img.rotate(angle, expand=True)

def random_color_jitter(img):
    """Adjust brightness, contrast, and color randomly."""
    # Brightness
    enhancer = ImageEnhance.Brightness(img)
    img = enhancer.enhance(random.uniform(0.7, 1.3))

    # Contrast
    enhancer = ImageEnhance.Contrast(img)
    img = enhancer.enhance(random.uniform(0.7, 1.3))

    # # Color/Saturation
    # enhancer = ImageEnhance.Color(img)
    # img = enhancer.enhance(random.uniform(0.8, 1.2))

    return img

# def random_crop(img):
#     """
#     Randomly crop 80–100% of the original, then resize back to original size.
#     This simulates a zoom-and-translate effect.
#     """
#     width, height = img.size
#     scale = random.uniform(0.8, 1.0)
#     new_w = int(width * scale)
#     new_h = int(height * scale)
#     left = random.randint(0, width - new_w)
#     top = random.randint(0, height - new_h)
#     cropped = img.crop((left, top, left + new_w, top + new_h))
#     return cropped.resize((width, height), Image.ANTIALIAS)

def augment_image(image_path, output_base, count):
    """
    Apply a sequence of random augmentations and save the results.
    Each run picks a random combination of flip, rotate, color jitter, crop.
    """
    img = Image.open(image_path).convert('RGB')
    base_name = os.path.splitext(os.path.basename(image_path))[0]
    label=base_name.split("_")[-1]
    output_base = os.path.join(output_base, label)
    for i in range(count):
        aug = img.copy()

        # Chain a few random transforms:
        aug = random_flip(aug)
        aug = random_rotation(aug)
        aug = random_color_jitter(aug)

        # Save out as JPEG (you can switch format/quality if desired)
        save_name = f"aug.{i+1}.{base_name}.png"
        aug.save(os.path.join(output_base, save_name), quality=100)

# Loop through each image and produce augmented variants
for image_file in read_images(input_dir):
    image_path = image_file
    augment_image(image_path, output_dir, aug_per_image)
    print(f"Processed {image_path}")

# print(f"Processed {len(image_files)} images, each with {aug_per_image} variants.")
# Out:
# Processed Assistance_required_data\var\yok\93 (20)_var.png
# Processed Assistance_required_data\yok\var\105 (30)_yok.png
# Processed Assistance_required_data\yok\var\12219_yok.png
