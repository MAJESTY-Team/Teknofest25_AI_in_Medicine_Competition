# %%
from ultralytics import YOLO
model = YOLO("..\\training_code\\runs\\classify\\yolo11m-cls_v3_aug2\\weights\\best.pt")

read_dir="..\\trainingDatav3\\val"
# read_dir = "./pngVersion/"1
output_dir="./"

# %%
from ultralytics import YOLO
import torch
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix
import shutil
from pathlib import Path
import os


T = 0
F = 0

# Lists to store true and predicted labels for the confusion matrix
all_true_labels = []
all_pred_labels = []
class_names = list(model.names.values()) # Get class names from the main model

# Usage
for path in read_images(read_dir):
    if "MR" in str(path):
        continue

    label = path.stem.split("_")[-1]
    all_true_labels.append(label)

    result = model.predict(source=path, save=False)
    result = result[0]
    pred = result.probs.top1
    predlabel = result.names[pred]
    conf = result.probs.top1conf
    newResult = None

    final_pred_label = ""
    if newResult is None:
        if(conf < 0.76):  # Threshold for low confidence
            final_pred_label="yok"
        else:
            final_pred_label = result.names[pred]

        if final_pred_label.lower() == label.lower():
            T += 1
        else:
            F += 1
        print(f"True label: {label}, Predicted: {final_pred_label}")
    else:
        pred = newResult.probs.top1
        final_pred_label = newResult.names[pred]
        if final_pred_label.lower() == label.lower():
            T += 1
        else:
            F += 1
        print(f"True label: {label}, Predicted: {final_pred_label}")
        print(f"First hit: {result.names[result.probs.top1]}, Second hit: {final_pred_label}, First hit conf {result.probs.top1conf}, Second hit conf: {newResult.probs.top1conf}")

    all_pred_labels.append(final_pred_label)

print(f"True: {T}, False: {F}")
print(f"Accuracy: {T / (T + F) * 100:.2f}%")

# --- New Code for Confusion Matrix ---

# Ensure all class names are present for matrix calculation
all_labels = sorted(list(set(all_true_labels + all_pred_labels)))

# Calculate the confusion matrix
cm = confusion_matrix(all_true_labels, all_pred_labels, labels=all_labels)
# cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Create the plot
plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt=".1f", cmap='Blues',
            xticklabels=all_labels, yticklabels=all_labels)
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

# Save the plot
plt.savefig('confusion_matrix_non_hybrid.png', dpi=300)
print("\nConfusion matrix saved to confusion_matrix.png")
# Out:
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10003_var.png: 224x224 var 1.00, yok 0.00, 21.8ms
# Speed: 3.2ms preprocess, 21.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\100170_var.png: 224x224 var 0.97, yok 0.03, 21.9ms
# Speed: 3.4ms preprocess, 21.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10039_var.png: 224x224 var 1.00, yok 0.00, 21.8ms
# Speed: 2.7ms preprocess, 21.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\100582_var.png: 224x224 var 0.99, yok 0.01, 21.8ms
# Speed: 2.7ms preprocess, 21.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10059_var.png: 224x224 var 0.99, yok 0.01, 21.8ms
# Speed: 2.6ms preprocess, 21.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10060_var.png: 224x224 var 1.00, yok 0.00, 21.8ms
# Speed: 2.7ms preprocess, 21.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10068_var.png: 224x224 var 1.00, yok 0.00, 21.2ms
# Speed: 2.7ms preprocess, 21.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\100746_var.png: 224x224 var 1.00, yok 0.00, 18.6ms
# Speed: 3.1ms preprocess, 18.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10078_var.png: 224x224 var 1.00, yok 0.00, 19.3ms
# Speed: 2.8ms preprocess, 19.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10116_var.png: 224x224 var 1.00, yok 0.00, 18.9ms
# Speed: 2.9ms preprocess, 18.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\101266_var.png: 224x224 var 1.00, yok 0.00, 18.6ms
# Speed: 2.6ms preprocess, 18.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10134_var.png: 224x224 var 1.00, yok 0.00, 18.4ms
# Speed: 2.7ms preprocess, 18.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10188_var.png: 224x224 var 1.00, yok 0.00, 18.5ms
# Speed: 2.8ms preprocess, 18.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\102091_var.png: 224x224 yok 1.00, var 0.00, 18.6ms
# Speed: 3.6ms preprocess, 18.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\102333_var.png: 224x224 yok 0.93, var 0.07, 9.4ms
# Speed: 2.9ms preprocess, 9.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10234_var.png: 224x224 var 1.00, yok 0.00, 9.2ms
# Speed: 2.6ms preprocess, 9.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\102864_var.png: 224x224 var 1.00, yok 0.00, 9.3ms
# Speed: 2.4ms preprocess, 9.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\103085_var.png: 224x224 var 1.00, yok 0.00, 9.2ms
# Speed: 2.6ms preprocess, 9.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10327_var.png: 224x224 var 1.00, yok 0.00, 9.3ms
# Speed: 2.6ms preprocess, 9.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10330_var.png: 224x224 var 1.00, yok 0.00, 9.9ms
# Speed: 2.6ms preprocess, 9.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10351_var.png: 224x224 var 1.00, yok 0.00, 9.2ms
# Speed: 2.7ms preprocess, 9.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\104066_var.png: 224x224 yok 1.00, var 0.00, 9.2ms
# Speed: 2.6ms preprocess, 9.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10415_var.png: 224x224 var 1.00, yok 0.00, 9.2ms
# Speed: 2.4ms preprocess, 9.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\104291_var.png: 224x224 var 0.76, yok 0.24, 9.2ms
# Speed: 2.3ms preprocess, 9.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10435_var.png: 224x224 var 1.00, yok 0.00, 9.7ms
# Speed: 2.2ms preprocess, 9.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10440_var.png: 224x224 var 0.99, yok 0.01, 8.8ms
# Speed: 2.4ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10477_var.png: 224x224 var 1.00, yok 0.00, 8.5ms
# Speed: 2.7ms preprocess, 8.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10485_var.png: 224x224 var 1.00, yok 0.00, 8.8ms
# Speed: 2.7ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10489_var.png: 224x224 var 0.77, yok 0.23, 8.6ms
# Speed: 2.7ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10499_var.png: 224x224 var 1.00, yok 0.00, 8.5ms
# Speed: 2.6ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10501_var.png: 224x224 var 1.00, yok 0.00, 9.9ms
# Speed: 2.5ms preprocess, 9.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10518_var.png: 224x224 var 1.00, yok 0.00, 8.8ms
# Speed: 2.7ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10525_var.png: 224x224 var 1.00, yok 0.00, 8.6ms
# Speed: 2.7ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10528_var.png: 224x224 var 1.00, yok 0.00, 8.5ms
# Speed: 2.6ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\105967_var.png: 224x224 var 1.00, yok 0.00, 8.5ms
# Speed: 2.5ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10603_var.png: 224x224 var 1.00, yok 0.00, 8.6ms
# Speed: 2.8ms preprocess, 8.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10627_var.png: 224x224 var 1.00, yok 0.00, 9.2ms
# Speed: 2.4ms preprocess, 9.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\106309_var.png: 224x224 var 1.00, yok 0.00, 8.8ms
# Speed: 2.5ms preprocess, 8.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10642_var.png: 224x224 var 1.00, yok 0.00, 4.8ms
# Speed: 2.3ms preprocess, 4.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10644_var.png: 224x224 var 0.94, yok 0.06, 4.0ms
# Speed: 2.3ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10677_var.png: 224x224 var 1.00, yok 0.00, 4.8ms
# Speed: 2.3ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10688_var.png: 224x224 var 1.00, yok 0.00, 4.5ms
# Speed: 2.4ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10689_var.png: 224x224 var 1.00, yok 0.00, 4.4ms
# Speed: 2.3ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10690_var.png: 224x224 var 1.00, yok 0.00, 4.1ms
# Speed: 2.3ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\106921_var.png: 224x224 var 0.95, yok 0.05, 4.4ms
# Speed: 2.3ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10697_var.png: 224x224 var 1.00, yok 0.00, 4.8ms
# Speed: 2.9ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10701_var.png: 224x224 var 1.00, yok 0.00, 4.5ms
# Speed: 2.5ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\107137_var.png: 224x224 var 1.00, yok 0.00, 4.1ms
# Speed: 2.2ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\107218_var.png: 224x224 var 1.00, yok 0.00, 4.2ms
# Speed: 2.3ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\107379_var.png: 224x224 var 0.64, yok 0.36, 4.1ms
# Speed: 2.5ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\107487_var.png: 224x224 var 1.00, yok 0.00, 4.3ms
# Speed: 2.2ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10754_var.png: 224x224 var 1.00, yok 0.00, 4.0ms
# Speed: 2.3ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10765_var.png: 224x224 var 1.00, yok 0.00, 4.1ms
# Speed: 2.4ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10795_var.png: 224x224 var 0.99, yok 0.01, 4.3ms
# Speed: 2.2ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10832_var.png: 224x224 var 1.00, yok 0.00, 4.0ms
# Speed: 2.3ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10845_var.png: 224x224 var 1.00, yok 0.00, 4.2ms
# Speed: 2.1ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10867_var.png: 224x224 var 1.00, yok 0.00, 4.3ms
# Speed: 2.3ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\109022_var.png: 224x224 var 1.00, yok 0.00, 4.4ms
# Speed: 2.3ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10920_var.png: 224x224 var 1.00, yok 0.00, 4.1ms
# Speed: 2.2ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10927_var.png: 224x224 var 1.00, yok 0.00, 4.2ms
# Speed: 2.2ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10955_var.png: 224x224 var 1.00, yok 0.00, 5.0ms
# Speed: 2.3ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10975_var.png: 224x224 var 1.00, yok 0.00, 4.5ms
# Speed: 2.2ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\110134_var.png: 224x224 var 0.74, yok 0.26, 4.4ms
# Speed: 2.3ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11015_var.png: 224x224 var 1.00, yok 0.00, 4.9ms
# Speed: 3.2ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\110377_var.png: 224x224 var 1.00, yok 0.00, 5.0ms
# Speed: 2.7ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11052_var.png: 224x224 var 1.00, yok 0.00, 6.5ms
# Speed: 2.5ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\110537_var.png: 224x224 var 0.81, yok 0.19, 4.8ms
# Speed: 2.4ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11101_var.png: 224x224 var 1.00, yok 0.00, 4.6ms
# Speed: 2.3ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\111102_var.png: 224x224 yok 1.00, var 0.00, 4.0ms
# Speed: 2.6ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11119_var.png: 224x224 yok 0.82, var 0.18, 4.0ms
# Speed: 2.3ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\111697_var.png: 224x224 var 1.00, yok 0.00, 5.3ms
# Speed: 2.2ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\111774_var.png: 224x224 var 1.00, yok 0.00, 5.7ms
# Speed: 2.8ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11210_var.png: 224x224 var 1.00, yok 0.00, 6.7ms
# Speed: 2.9ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11211_var.png: 224x224 var 1.00, yok 0.00, 5.9ms
# Speed: 2.9ms preprocess, 5.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11248_var.png: 224x224 var 1.00, yok 0.00, 5.4ms
# Speed: 2.6ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11249_var.png: 224x224 var 1.00, yok 0.00, 4.8ms
# Speed: 2.4ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11262_var.png: 224x224 var 0.99, yok 0.01, 5.5ms
# Speed: 2.3ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11268_var.png: 224x224 var 1.00, yok 0.00, 7.1ms
# Speed: 2.5ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11275_var.png: 224x224 var 1.00, yok 0.00, 4.8ms
# Speed: 4.1ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11320_var.png: 224x224 var 1.00, yok 0.00, 5.1ms
# Speed: 2.7ms preprocess, 5.1ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\113417_var.png: 224x224 yok 0.98, var 0.02, 7.2ms
# Speed: 2.6ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11381_var.png: 224x224 var 1.00, yok 0.00, 7.0ms
# Speed: 3.7ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11430_var.png: 224x224 var 1.00, yok 0.00, 7.2ms
# Speed: 3.2ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11443_var.png: 224x224 var 1.00, yok 0.00, 6.3ms
# Speed: 2.8ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11471_var.png: 224x224 var 1.00, yok 0.00, 4.9ms
# Speed: 2.4ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11492_var.png: 224x224 var 0.82, yok 0.18, 4.9ms
# Speed: 2.4ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11504_var.png: 224x224 var 1.00, yok 0.00, 4.9ms
# Speed: 2.3ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\115063_var.png: 224x224 yok 1.00, var 0.00, 5.1ms
# Speed: 2.6ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\115084_var.png: 224x224 var 1.00, yok 0.00, 5.2ms
# Speed: 2.6ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11513_var.png: 224x224 var 1.00, yok 0.00, 4.2ms
# Speed: 3.3ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11517_var.png: 224x224 var 1.00, yok 0.00, 6.0ms
# Speed: 3.1ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11521_var.png: 224x224 var 1.00, yok 0.00, 4.2ms
# Speed: 2.8ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11556_var.png: 224x224 var 0.98, yok 0.02, 4.7ms
# Speed: 2.9ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11565_var.png: 224x224 var 0.98, yok 0.02, 5.6ms
# Speed: 3.0ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11573_var.png: 224x224 var 1.00, yok 0.00, 4.6ms
# Speed: 2.9ms preprocess, 4.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11593_var.png: 224x224 var 1.00, yok 0.00, 4.7ms
# Speed: 2.8ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11624_var.png: 224x224 var 1.00, yok 0.00, 4.3ms
# Speed: 2.9ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11642_var.png: 224x224 var 0.99, yok 0.01, 4.5ms
# Speed: 3.1ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11715_var.png: 224x224 var 1.00, yok 0.00, 4.4ms
# Speed: 3.0ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11728_var.png: 224x224 var 1.00, yok 0.00, 5.4ms
# Speed: 2.4ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11734_var.png: 224x224 var 1.00, yok 0.00, 4.9ms
# Speed: 2.5ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11776_var.png: 224x224 var 1.00, yok 0.00, 4.9ms
# Speed: 2.4ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11780_var.png: 224x224 var 1.00, yok 0.00, 5.1ms
# Speed: 2.5ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11862_var.png: 224x224 yok 1.00, var 0.00, 7.3ms
# Speed: 3.1ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\118978_var.png: 224x224 var 1.00, yok 0.00, 4.6ms
# Speed: 3.1ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11941_var.png: 224x224 var 1.00, yok 0.00, 5.0ms
# Speed: 2.7ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11971_var.png: 224x224 var 1.00, yok 0.00, 4.5ms
# Speed: 2.6ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11974_var.png: 224x224 var 1.00, yok 0.00, 5.0ms
# Speed: 3.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12029_var.png: 224x224 var 1.00, yok 0.00, 11.5ms
# Speed: 2.7ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12037_var.png: 224x224 var 1.00, yok 0.00, 9.8ms
# Speed: 4.3ms preprocess, 9.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\120704_var.png: 224x224 yok 0.85, var 0.15, 9.6ms
# Speed: 3.2ms preprocess, 9.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12081_var.png: 224x224 var 1.00, yok 0.00, 4.5ms
# Speed: 3.3ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12083_var.png: 224x224 var 1.00, yok 0.00, 4.5ms
# Speed: 3.5ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12084_var.png: 224x224 var 1.00, yok 0.00, 5.7ms
# Speed: 2.8ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12102_var.png: 224x224 var 1.00, yok 0.00, 4.3ms
# Speed: 2.8ms preprocess, 4.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12107_var.png: 224x224 var 1.00, yok 0.00, 4.0ms
# Speed: 2.4ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12146_var.png: 224x224 var 1.00, yok 0.00, 7.3ms
# Speed: 4.0ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12149_var.png: 224x224 var 1.00, yok 0.00, 4.6ms
# Speed: 2.3ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12161_var.png: 224x224 var 1.00, yok 0.00, 5.1ms
# Speed: 2.6ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\121738_var.png: 224x224 var 1.00, yok 0.00, 6.7ms
# Speed: 3.2ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\121803_var.png: 224x224 var 1.00, yok 0.00, 4.9ms
# Speed: 2.9ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12254_var.png: 224x224 var 1.00, yok 0.00, 4.4ms
# Speed: 2.9ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12270_var.png: 224x224 var 1.00, yok 0.00, 4.8ms
# Speed: 3.2ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12292_var.png: 224x224 var 1.00, yok 0.00, 5.1ms
# Speed: 3.0ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\122946_var.png: 224x224 yok 0.95, var 0.05, 7.2ms
# Speed: 2.8ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12297_var.png: 224x224 var 1.00, yok 0.00, 4.1ms
# Speed: 2.6ms preprocess, 4.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12300_var.png: 224x224 var 1.00, yok 0.00, 6.4ms
# Speed: 3.1ms preprocess, 6.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12314_var.png: 224x224 var 1.00, yok 0.00, 6.6ms
# Speed: 3.0ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\123606_var.png: 224x224 var 1.00, yok 0.00, 4.9ms
# Speed: 2.8ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\123685_var.png: 224x224 yok 1.00, var 0.00, 4.8ms
# Speed: 3.2ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\123907_var.png: 224x224 yok 1.00, var 0.00, 4.8ms
# Speed: 2.7ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\124091_var.png: 224x224 var 0.73, yok 0.27, 4.6ms
# Speed: 2.5ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12433_var.png: 224x224 var 1.00, yok 0.00, 4.7ms
# Speed: 2.4ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12440_var.png: 224x224 var 1.00, yok 0.00, 4.5ms
# Speed: 2.9ms preprocess, 4.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12474_var.png: 224x224 var 1.00, yok 0.00, 4.5ms
# Speed: 2.6ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12490_var.png: 224x224 var 1.00, yok 0.00, 6.6ms
# Speed: 3.2ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\124960_var.png: 224x224 var 0.79, yok 0.21, 4.7ms
# Speed: 3.0ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12498_var.png: 224x224 var 1.00, yok 0.00, 4.1ms
# Speed: 2.7ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\125121_var.png: 224x224 var 0.99, yok 0.01, 5.1ms
# Speed: 2.6ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12518_var.png: 224x224 var 1.00, yok 0.00, 5.4ms
# Speed: 2.6ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12525_var.png: 224x224 var 1.00, yok 0.00, 4.4ms
# Speed: 3.0ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\125466_var.png: 224x224 var 1.00, yok 0.00, 4.6ms
# Speed: 2.5ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12556_var.png: 224x224 yok 1.00, var 0.00, 5.1ms
# Speed: 2.5ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\125604_var.png: 224x224 var 1.00, yok 0.00, 5.2ms
# Speed: 2.6ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12572_var.png: 224x224 var 1.00, yok 0.00, 4.3ms
# Speed: 2.8ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12581_var.png: 224x224 var 1.00, yok 0.00, 4.4ms
# Speed: 2.5ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12584_var.png: 224x224 var 1.00, yok 0.00, 4.5ms
# Speed: 2.5ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12600_var.png: 224x224 var 1.00, yok 0.00, 5.4ms
# Speed: 2.2ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12627_var.png: 224x224 var 1.00, yok 0.00, 4.5ms
# Speed: 2.5ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12647_var.png: 224x224 var 1.00, yok 0.00, 6.6ms
# Speed: 2.5ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\126506_var.png: 224x224 var 1.00, yok 0.00, 10.7ms
# Speed: 4.9ms preprocess, 10.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\126810_var.png: 224x224 var 1.00, yok 0.00, 5.6ms
# Speed: 2.8ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12689_var.png: 224x224 var 1.00, yok 0.00, 5.2ms
# Speed: 2.7ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12729_var.png: 224x224 var 1.00, yok 0.00, 4.4ms
# Speed: 2.4ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12757_var.png: 224x224 var 1.00, yok 0.00, 4.0ms
# Speed: 2.3ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12768_var.png: 224x224 var 1.00, yok 0.00, 4.4ms
# Speed: 3.8ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12794_var.png: 224x224 var 0.91, yok 0.09, 5.0ms
# Speed: 2.4ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: var, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\12795_var.png: 224x224 var 1.00, yok 0.00, 4.0ms
# ...
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\278941_yok.png: 224x224 yok 1.00, var 0.00, 10.4ms
# Speed: 3.8ms preprocess, 10.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\278997_yok.png: 224x224 var 0.51, yok 0.49, 11.9ms
# Speed: 4.1ms preprocess, 11.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\279663_yok.png: 224x224 yok 1.00, var 0.00, 11.3ms
# Speed: 5.0ms preprocess, 11.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\279721_yok.png: 224x224 yok 0.99, var 0.01, 9.6ms
# Speed: 4.2ms preprocess, 9.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\279934_yok.png: 224x224 var 0.93, yok 0.07, 8.7ms
# Speed: 4.0ms preprocess, 8.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\279969_yok.png: 224x224 yok 0.85, var 0.15, 14.4ms
# Speed: 6.1ms preprocess, 14.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\279987_yok.png: 224x224 var 0.98, yok 0.02, 8.6ms
# Speed: 3.8ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\280019_yok.png: 224x224 yok 1.00, var 0.00, 8.9ms
# Speed: 3.5ms preprocess, 8.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\280487_yok.png: 224x224 yok 1.00, var 0.00, 8.8ms
# Speed: 3.9ms preprocess, 8.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\280539_yok.png: 224x224 yok 1.00, var 0.00, 11.6ms
# Speed: 4.7ms preprocess, 11.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\281465_yok.png: 224x224 yok 1.00, var 0.00, 10.1ms
# Speed: 4.6ms preprocess, 10.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\282207_yok.png: 224x224 yok 0.98, var 0.02, 21.7ms
# Speed: 4.7ms preprocess, 21.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\282209_yok.png: 224x224 var 0.99, yok 0.01, 20.7ms
# Speed: 5.1ms preprocess, 20.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\283464_yok.png: 224x224 yok 1.00, var 0.00, 12.7ms
# Speed: 5.0ms preprocess, 12.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\283686_yok.png: 224x224 yok 1.00, var 0.00, 11.3ms
# Speed: 4.9ms preprocess, 11.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\283967_yok.png: 224x224 yok 1.00, var 0.00, 13.3ms
# Speed: 5.2ms preprocess, 13.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\284155_yok.png: 224x224 yok 1.00, var 0.00, 9.6ms
# Speed: 4.3ms preprocess, 9.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\284370_yok.png: 224x224 var 0.67, yok 0.33, 8.6ms
# Speed: 3.2ms preprocess, 8.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\284552_yok.png: 224x224 yok 1.00, var 0.00, 11.0ms
# Speed: 5.5ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\285313_yok.png: 224x224 yok 0.99, var 0.01, 9.2ms
# Speed: 3.4ms preprocess, 9.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\285723_yok.png: 224x224 yok 0.93, var 0.07, 9.4ms
# Speed: 4.4ms preprocess, 9.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\285783_yok.png: 224x224 yok 1.00, var 0.00, 9.1ms
# Speed: 5.0ms preprocess, 9.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\286000_yok.png: 224x224 yok 0.76, var 0.24, 9.9ms
# Speed: 4.9ms preprocess, 9.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\286624_yok.png: 224x224 yok 0.92, var 0.08, 8.9ms
# Speed: 3.6ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\287076_yok.png: 224x224 yok 1.00, var 0.00, 12.5ms
# Speed: 8.9ms preprocess, 12.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\287884_yok.png: 224x224 yok 0.76, var 0.24, 10.3ms
# Speed: 3.6ms preprocess, 10.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\288118_yok.png: 224x224 yok 1.00, var 0.00, 9.8ms
# Speed: 4.4ms preprocess, 9.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\288160_yok.png: 224x224 yok 1.00, var 0.00, 9.0ms
# Speed: 3.9ms preprocess, 9.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\288232_yok.png: 224x224 yok 1.00, var 0.00, 9.3ms
# Speed: 4.3ms preprocess, 9.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\289430_yok.png: 224x224 yok 1.00, var 0.00, 8.6ms
# Speed: 3.5ms preprocess, 8.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\289878_yok.png: 224x224 yok 1.00, var 0.00, 8.6ms
# Speed: 3.9ms preprocess, 8.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\291022_yok.png: 224x224 yok 0.96, var 0.04, 8.8ms
# Speed: 6.0ms preprocess, 8.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\291833_yok.png: 224x224 var 0.99, yok 0.01, 10.0ms
# Speed: 3.8ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\291871_yok.png: 224x224 yok 1.00, var 0.00, 8.7ms
# Speed: 4.5ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\292249_yok.png: 224x224 yok 1.00, var 0.00, 11.4ms
# Speed: 6.6ms preprocess, 11.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\293225_yok.png: 224x224 yok 1.00, var 0.00, 10.9ms
# Speed: 4.4ms preprocess, 10.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\293727_yok.png: 224x224 yok 1.00, var 0.00, 8.6ms
# Speed: 3.8ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\294252_yok.png: 224x224 var 0.90, yok 0.10, 9.3ms
# Speed: 4.3ms preprocess, 9.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\294891_yok.png: 224x224 yok 1.00, var 0.00, 9.2ms
# Speed: 5.5ms preprocess, 9.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\295995_yok.png: 224x224 yok 1.00, var 0.00, 8.6ms
# Speed: 4.2ms preprocess, 8.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\296149_yok.png: 224x224 yok 1.00, var 0.00, 8.6ms
# Speed: 4.3ms preprocess, 8.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\296254_yok.png: 224x224 yok 1.00, var 0.00, 10.3ms
# Speed: 3.8ms preprocess, 10.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\296260_yok.png: 224x224 yok 1.00, var 0.00, 8.7ms
# Speed: 4.1ms preprocess, 8.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\296312_yok.png: 224x224 yok 0.92, var 0.08, 9.7ms
# Speed: 3.6ms preprocess, 9.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\296600_yok.png: 224x224 yok 1.00, var 0.00, 8.7ms
# Speed: 2.3ms preprocess, 8.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\296862_yok.png: 224x224 yok 1.00, var 0.00, 10.4ms
# Speed: 6.7ms preprocess, 10.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\296863_yok.png: 224x224 yok 1.00, var 0.00, 8.6ms
# Speed: 4.5ms preprocess, 8.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\297300_yok.png: 224x224 yok 1.00, var 0.00, 9.8ms
# Speed: 6.9ms preprocess, 9.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\298534_yok.png: 224x224 yok 0.96, var 0.04, 8.8ms
# Speed: 6.0ms preprocess, 8.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\298697_yok.png: 224x224 var 0.98, yok 0.02, 11.8ms
# Speed: 5.0ms preprocess, 11.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: var
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\299059_yok.png: 224x224 yok 1.00, var 0.00, 11.1ms
# Speed: 4.8ms preprocess, 11.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\299907_yok.png: 224x224 yok 0.99, var 0.01, 9.2ms
# Speed: 4.2ms preprocess, 9.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# True label: yok, Predicted: yok
# True: 2155, False: 263
# Accuracy: 89.12%
#
# Confusion matrix saved to confusion_matrix.png

# %%
# Define read_images function if not already defined
def read_images(directory):
    """Generator function to read images from directory structure"""
    from pathlib import Path
    
    directory = Path(directory)
    if not directory.exists():
        print(f"Directory {directory} does not exist")
        return
    
    # Look for images in subdirectories
    for subdir in directory.iterdir():
        if subdir.is_dir():
            for img_file in subdir.glob("*.png"):
                yield img_file
            for img_file in subdir.glob("*.jpg"):
                yield img_file
            for img_file in subdir.glob("*.jpeg"):
                yield img_file

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt=".1f", cmap='Blues',
            xticklabels=all_labels, yticklabels=all_labels)
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

# Save the plot
plt.savefig('confusion_matrix.png', dpi=300)
print("\nConfusion matrix saved to confusion_matrix.png")
# Out:
# Confusion matrix saved to confusion_matrix.png

# %%
# ===== THRESHOLD OPTIMIZATION FOR MAXIMUM ACCURACY =====
import numpy as np
print("\n" + "="*60)
print("THRESHOLD OPTIMIZATION ANALYSIS")
print("="*60)

# Collect all prediction data with confidence scores
prediction_data = []
true_labels_for_threshold = []
confidence_scores = []

print("Collecting prediction data with confidence scores...")

for path in read_images(read_dir):
    if "MR" in str(path):
        continue

    label = path.stem.split("_")[-1]
    true_labels_for_threshold.append(label)

    result = model.predict(source=path, save=False)
    result = result[0]
    
    # Get top predictions and their confidence scores
    probs = result.probs.data.cpu().numpy()  # All class probabilities
    top1_idx = result.probs.top1
    top1_conf = result.probs.top1conf.item()
    top1_label = result.names[top1_idx]
    
    # Store prediction data
    prediction_data.append({
        'true_label': label,
        'top1_label': top1_label,
        'top1_conf': top1_conf,
        'all_probs': probs,
        'class_names': result.names
    })
    
    confidence_scores.append(top1_conf)

print(f"Collected {len(prediction_data)} predictions")

# Test different threshold values
threshold_range = np.arange(0.1, 1.0, 0.05)  # From 10% to 95% confidence
threshold_results = []

print(f"\nTesting {len(threshold_range)} different threshold values...")

for threshold in threshold_range:
    correct_predictions = 0
    total_predictions = 0
    yok_predictions = 0  # Predictions assigned to "yok" due to low confidence
    
    for data in prediction_data:
        total_predictions += 1
        
        if data['top1_conf'] >= threshold:
            # Accept original prediction if confidence >= threshold
            final_prediction = data['top1_label']
        else:
            # Assign to "yok" class if confidence < threshold
            final_prediction = "yok"
            yok_predictions += 1
        
        # Check if final prediction is correct
        if final_prediction.lower() == data['true_label'].lower():
            correct_predictions += 1
    
    # Calculate metrics (now all predictions are made, no rejections)
    accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0
    coverage = 1.0  # Always 100% coverage since we make prediction for all samples
    
    threshold_results.append({
        'threshold': threshold,
        'accuracy': accuracy,
        'coverage': coverage,
        'correct': correct_predictions,
        'total': total_predictions,
        'yok_assigned': yok_predictions,
        'original_predictions': total_predictions - yok_predictions
    })

# Convert to DataFrame for easier analysis
import pandas as pd
results_df = pd.DataFrame(threshold_results)

# Find optimal threshold (you can adjust the criteria)
# Since coverage is always 100%, we focus on maximum accuracy
best_accuracy_idx = results_df['accuracy'].idxmax()
best_accuracy_threshold = results_df.iloc[best_accuracy_idx]

# Option 2: Find threshold that minimizes "yok" assignments while maintaining good accuracy
# This balances between accuracy and keeping original model predictions
results_df['yok_ratio'] = results_df['yok_assigned'] / results_df['total']
results_df['score'] = results_df['accuracy'] * (1 - results_df['yok_ratio'])  # Penalize high "yok" assignments
best_tradeoff_idx = results_df['score'].idxmax()
best_tradeoff_threshold = results_df.iloc[best_tradeoff_idx]

# Option 3: Maximum accuracy with minimal "yok" assignments (less than 20% assigned to "yok")
low_yok_df = results_df[results_df['yok_ratio'] <= 0.2]
if len(low_yok_df) > 0:
    best_low_yok_idx = low_yok_df['accuracy'].idxmax()
    best_low_yok_threshold = low_yok_df.iloc[best_low_yok_idx]
else:
    best_low_yok_threshold = None

print("\n" + "="*50)
print("THRESHOLD OPTIMIZATION RESULTS")
print("(Low confidence predictions assigned to 'yok' class)")
print("="*50)

print(f"\n1. MAXIMUM ACCURACY:")
print(f"   Threshold: {best_accuracy_threshold['threshold']:.2f}")
print(f"   Accuracy: {best_accuracy_threshold['accuracy']:.4f} ({best_accuracy_threshold['accuracy']*100:.2f}%)")
print(f"   Original predictions: {best_accuracy_threshold['original_predictions']}")
print(f"   Assigned to 'yok': {best_accuracy_threshold['yok_assigned']}")
print(f"   Yok assignment ratio: {best_accuracy_threshold['yok_assigned']/best_accuracy_threshold['total']*100:.1f}%")
print(f"   Correct predictions: {best_accuracy_threshold['correct']}/{best_accuracy_threshold['total']}")

print(f"\n2. BEST ACCURACY WITH MINIMAL 'YOK' ASSIGNMENTS:")
print(f"   Threshold: {best_tradeoff_threshold['threshold']:.2f}")
print(f"   Accuracy: {best_tradeoff_threshold['accuracy']:.4f} ({best_tradeoff_threshold['accuracy']*100:.2f}%)")
print(f"   Original predictions: {best_tradeoff_threshold['original_predictions']}")
print(f"   Assigned to 'yok': {best_tradeoff_threshold['yok_assigned']}")
print(f"   Yok assignment ratio: {best_tradeoff_threshold['yok_assigned']/best_tradeoff_threshold['total']*100:.1f}%")
print(f"   Score (Acc × (1-YokRatio)): {best_tradeoff_threshold['score']:.4f}")
print(f"   Correct predictions: {best_tradeoff_threshold['correct']}/{best_tradeoff_threshold['total']}")

if best_low_yok_threshold is not None:
    print(f"\n3. BEST ACCURACY WITH ≤20% 'YOK' ASSIGNMENTS:")
    print(f"   Threshold: {best_low_yok_threshold['threshold']:.2f}")
    print(f"   Accuracy: {best_low_yok_threshold['accuracy']:.4f} ({best_low_yok_threshold['accuracy']*100:.2f}%)")
    print(f"   Original predictions: {best_low_yok_threshold['original_predictions']}")
    print(f"   Assigned to 'yok': {best_low_yok_threshold['yok_assigned']}")
    print(f"   Yok assignment ratio: {best_low_yok_threshold['yok_assigned']/best_low_yok_threshold['total']*100:.1f}%")
    print(f"   Correct predictions: {best_low_yok_threshold['correct']}/{best_low_yok_threshold['total']}")
else:
    print(f"\n3. No threshold found with ≤20% 'yok' assignments")

# Original accuracy (no threshold)
original_accuracy = results_df.iloc[0]['accuracy'] if results_df.iloc[0]['threshold'] <= 0.1 else None
if original_accuracy:
    print(f"\nORIGINAL ACCURACY (no threshold): {original_accuracy:.4f} ({original_accuracy*100:.2f}%)")

print(f"\nConfidence score statistics:")
print(f"Mean confidence: {np.mean(confidence_scores):.4f}")
print(f"Std confidence: {np.std(confidence_scores):.4f}")
print(f"Min confidence: {np.min(confidence_scores):.4f}")
print(f"Max confidence: {np.max(confidence_scores):.4f}")
# Out:
# ============================================================
# THRESHOLD OPTIMIZATION ANALYSIS
# ============================================================
# Collecting prediction data with confidence scores...
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10003_var.png: 224x224 var 1.00, yok 0.00, 21.8ms
# Speed: 3.3ms preprocess, 21.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10003_var.png: 224x224 var 1.00, yok 0.00, 21.8ms
# Speed: 3.3ms preprocess, 21.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\100170_var.png: 224x224 var 0.97, yok 0.03, 22.0ms
# Speed: 3.0ms preprocess, 22.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\100170_var.png: 224x224 var 0.97, yok 0.03, 22.0ms
# Speed: 3.0ms preprocess, 22.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10039_var.png: 224x224 var 1.00, yok 0.00, 21.8ms
# Speed: 2.8ms preprocess, 21.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10039_var.png: 224x224 var 1.00, yok 0.00, 21.8ms
# Speed: 2.8ms preprocess, 21.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\100582_var.png: 224x224 var 0.99, yok 0.01, 21.7ms
# Speed: 3.0ms preprocess, 21.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\100582_var.png: 224x224 var 0.99, yok 0.01, 21.7ms
# Speed: 3.0ms preprocess, 21.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10059_var.png: 224x224 var 0.99, yok 0.01, 20.9ms
# Speed: 2.6ms preprocess, 20.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10059_var.png: 224x224 var 0.99, yok 0.01, 20.9ms
# Speed: 2.6ms preprocess, 20.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10060_var.png: 224x224 var 1.00, yok 0.00, 20.8ms
# Speed: 2.7ms preprocess, 20.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10060_var.png: 224x224 var 1.00, yok 0.00, 20.8ms
# Speed: 2.7ms preprocess, 20.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10068_var.png: 224x224 var 1.00, yok 0.00, 21.1ms
# Speed: 3.0ms preprocess, 21.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10068_var.png: 224x224 var 1.00, yok 0.00, 21.1ms
# Speed: 3.0ms preprocess, 21.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\100746_var.png: 224x224 var 1.00, yok 0.00, 20.8ms
# Speed: 3.2ms preprocess, 20.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\100746_var.png: 224x224 var 1.00, yok 0.00, 20.8ms
# Speed: 3.2ms preprocess, 20.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10078_var.png: 224x224 var 1.00, yok 0.00, 20.7ms
# Speed: 2.7ms preprocess, 20.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10078_var.png: 224x224 var 1.00, yok 0.00, 20.7ms
# Speed: 2.7ms preprocess, 20.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10116_var.png: 224x224 var 1.00, yok 0.00, 20.7ms
# Speed: 2.7ms preprocess, 20.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10116_var.png: 224x224 var 1.00, yok 0.00, 20.7ms
# Speed: 2.7ms preprocess, 20.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\101266_var.png: 224x224 var 1.00, yok 0.00, 20.7ms
# Speed: 2.5ms preprocess, 20.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10134_var.png: 224x224 var 1.00, yok 0.00, 4.1ms
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\101266_var.png: 224x224 var 1.00, yok 0.00, 20.7ms
# Speed: 2.5ms preprocess, 20.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10134_var.png: 224x224 var 1.00, yok 0.00, 4.1ms
# Speed: 2.2ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10188_var.png: 224x224 var 1.00, yok 0.00, 4.1ms
# Speed: 2.2ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10188_var.png: 224x224 var 1.00, yok 0.00, 4.1ms
# Speed: 2.4ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Speed: 2.4ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\102091_var.png: 224x224 yok 1.00, var 0.00, 5.1ms
# Speed: 2.4ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\102333_var.png: 224x224 yok 0.93, var 0.07, 4.2ms
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\102091_var.png: 224x224 yok 1.00, var 0.00, 5.1ms
# Speed: 2.4ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\102333_var.png: 224x224 yok 0.93, var 0.07, 4.2ms
# Speed: 2.3ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Speed: 2.3ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10234_var.png: 224x224 var 1.00, yok 0.00, 5.1ms
# Speed: 2.4ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\102864_var.png: 224x224 var 1.00, yok 0.00, 7.5ms
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10234_var.png: 224x224 var 1.00, yok 0.00, 5.1ms
# Speed: 2.4ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\102864_var.png: 224x224 var 1.00, yok 0.00, 7.5ms
# Speed: 2.6ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Speed: 2.6ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\103085_var.png: 224x224 var 1.00, yok 0.00, 4.3ms
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\103085_var.png: 224x224 var 1.00, yok 0.00, 4.3ms
# Speed: 2.9ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10327_var.png: 224x224 var 1.00, yok 0.00, 4.3ms
# Speed: 2.9ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10327_var.png: 224x224 var 1.00, yok 0.00, 4.3ms
# Speed: 2.6ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Speed: 2.6ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10330_var.png: 224x224 var 1.00, yok 0.00, 4.6ms
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10330_var.png: 224x224 var 1.00, yok 0.00, 4.6ms
# Speed: 2.3ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10351_var.png: 224x224 var 1.00, yok 0.00, 4.2ms
# Speed: 2.3ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10351_var.png: 224x224 var 1.00, yok 0.00, 4.2ms
# Speed: 2.5ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Speed: 2.5ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\104066_var.png: 224x224 yok 1.00, var 0.00, 4.2ms
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\104066_var.png: 224x224 yok 1.00, var 0.00, 4.2ms
# Speed: 2.9ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10415_var.png: 224x224 var 1.00, yok 0.00, 4.6ms
# Speed: 2.9ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10415_var.png: 224x224 var 1.00, yok 0.00, 4.6ms
# Speed: 2.3ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# Speed: 2.3ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\104291_var.png: 224x224 var 0.76, yok 0.24, 6.1ms
# Speed: 2.4ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10435_var.png: 224x224 var 1.00, yok 0.00, 4.6ms
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\104291_var.png: 224x224 var 0.76, yok 0.24, 6.1ms
# Speed: 2.4ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10435_var.png: 224x224 var 1.00, yok 0.00, 4.6ms
# Speed: 2.6ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Speed: 2.6ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10440_var.png: 224x224 var 0.99, yok 0.01, 4.3ms
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10440_var.png: 224x224 var 0.99, yok 0.01, 4.3ms
# Speed: 2.6ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10477_var.png: 224x224 var 1.00, yok 0.00, 4.6ms
# Speed: 2.6ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10477_var.png: 224x224 var 1.00, yok 0.00, 4.6ms
# Speed: 2.4ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10485_var.png: 224x224 var 1.00, yok 0.00, 4.2ms
# Speed: 2.4ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10485_var.png: 224x224 var 1.00, yok 0.00, 4.2ms
# Speed: 2.4ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10489_var.png: 224x224 var 0.77, yok 0.23, 4.3ms
# Speed: 2.4ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10489_var.png: 224x224 var 0.77, yok 0.23, 4.3ms
# Speed: 2.4ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Speed: 2.4ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10499_var.png: 224x224 var 1.00, yok 0.00, 4.2ms
# Speed: 2.4ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10499_var.png: 224x224 var 1.00, yok 0.00, 4.2ms
# Speed: 2.4ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10501_var.png: 224x224 var 1.00, yok 0.00, 4.1ms
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10501_var.png: 224x224 var 1.00, yok 0.00, 4.1ms
# Speed: 2.4ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10518_var.png: 224x224 var 1.00, yok 0.00, 4.3ms
# Speed: 2.4ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10518_var.png: 224x224 var 1.00, yok 0.00, 4.3ms
# Speed: 2.3ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10525_var.png: 224x224 var 1.00, yok 0.00, 4.2ms
# Speed: 2.3ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10525_var.png: 224x224 var 1.00, yok 0.00, 4.2ms
# Speed: 2.4ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10528_var.png: 224x224 var 1.00, yok 0.00, 4.6ms
# Speed: 2.4ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10528_var.png: 224x224 var 1.00, yok 0.00, 4.6ms
# Speed: 2.5ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\105967_var.png: 224x224 var 1.00, yok 0.00, 4.8ms
# Speed: 2.5ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\105967_var.png: 224x224 var 1.00, yok 0.00, 4.8ms
# Speed: 2.4ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Speed: 2.4ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10603_var.png: 224x224 var 1.00, yok 0.00, 6.8ms
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10603_var.png: 224x224 var 1.00, yok 0.00, 6.8ms
# Speed: 3.6ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10627_var.png: 224x224 var 1.00, yok 0.00, 4.3ms
# Speed: 3.6ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10627_var.png: 224x224 var 1.00, yok 0.00, 4.3ms
# Speed: 2.4ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\106309_var.png: 224x224 var 1.00, yok 0.00, 4.4ms
# Speed: 2.4ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\106309_var.png: 224x224 var 1.00, yok 0.00, 4.4ms
# Speed: 2.6ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10642_var.png: 224x224 var 1.00, yok 0.00, 5.5ms
# Speed: 2.6ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10642_var.png: 224x224 var 1.00, yok 0.00, 5.5ms
# Speed: 2.5ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Speed: 2.5ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10644_var.png: 224x224 var 0.94, yok 0.06, 5.4ms
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10644_var.png: 224x224 var 0.94, yok 0.06, 5.4ms
# Speed: 2.5ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Speed: 2.5ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10677_var.png: 224x224 var 1.00, yok 0.00, 9.5ms
# Speed: 3.1ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10677_var.png: 224x224 var 1.00, yok 0.00, 9.5ms
# Speed: 3.1ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10688_var.png: 224x224 var 1.00, yok 0.00, 8.6ms
# Speed: 3.0ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10688_var.png: 224x224 var 1.00, yok 0.00, 8.6ms
# Speed: 3.0ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10689_var.png: 224x224 var 1.00, yok 0.00, 4.6ms
# Speed: 2.5ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10690_var.png: 224x224 var 1.00, yok 0.00, 4.1ms
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10689_var.png: 224x224 var 1.00, yok 0.00, 4.6ms
# Speed: 2.5ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10690_var.png: 224x224 var 1.00, yok 0.00, 4.1ms
# Speed: 2.4ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\106921_var.png: 224x224 var 0.95, yok 0.05, 5.3ms
# Speed: 2.4ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\106921_var.png: 224x224 var 0.95, yok 0.05, 5.3ms
# Speed: 2.5ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10697_var.png: 224x224 var 1.00, yok 0.00, 4.7ms
# Speed: 2.5ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10697_var.png: 224x224 var 1.00, yok 0.00, 4.7ms
# Speed: 2.6ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Speed: 2.6ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10701_var.png: 224x224 var 1.00, yok 0.00, 4.8ms
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10701_var.png: 224x224 var 1.00, yok 0.00, 4.8ms
# Speed: 2.7ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Speed: 2.7ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\107137_var.png: 224x224 var 1.00, yok 0.00, 4.5ms
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\107137_var.png: 224x224 var 1.00, yok 0.00, 4.5ms
# Speed: 2.6ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\107218_var.png: 224x224 var 1.00, yok 0.00, 4.2ms
# Speed: 2.6ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\107218_var.png: 224x224 var 1.00, yok 0.00, 4.2ms
# Speed: 2.4ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\107379_var.png: 224x224 var 0.64, yok 0.36, 4.5ms
# Speed: 2.4ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\107379_var.png: 224x224 var 0.64, yok 0.36, 4.5ms
# Speed: 2.7ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Speed: 2.7ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\107487_var.png: 224x224 var 1.00, yok 0.00, 4.8ms
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\107487_var.png: 224x224 var 1.00, yok 0.00, 4.8ms
# Speed: 2.3ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10754_var.png: 224x224 var 1.00, yok 0.00, 4.5ms
# Speed: 2.3ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10754_var.png: 224x224 var 1.00, yok 0.00, 4.5ms
# Speed: 2.5ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Speed: 2.5ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10765_var.png: 224x224 var 1.00, yok 0.00, 4.1ms
# Speed: 2.6ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10765_var.png: 224x224 var 1.00, yok 0.00, 4.1ms
# Speed: 2.6ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10795_var.png: 224x224 var 0.99, yok 0.01, 4.7ms
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10795_var.png: 224x224 var 0.99, yok 0.01, 4.7ms
# Speed: 2.4ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Speed: 2.4ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10832_var.png: 224x224 var 1.00, yok 0.00, 4.5ms
# Speed: 2.5ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10845_var.png: 224x224 var 1.00, yok 0.00, 4.2ms
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10832_var.png: 224x224 var 1.00, yok 0.00, 4.5ms
# Speed: 2.5ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10845_var.png: 224x224 var 1.00, yok 0.00, 4.2ms
# Speed: 2.5ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Speed: 2.5ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10867_var.png: 224x224 var 1.00, yok 0.00, 4.3ms
# Speed: 2.6ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10867_var.png: 224x224 var 1.00, yok 0.00, 4.3ms
# Speed: 2.6ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\109022_var.png: 224x224 var 1.00, yok 0.00, 4.2ms
# Speed: 2.4ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\109022_var.png: 224x224 var 1.00, yok 0.00, 4.2ms
# Speed: 2.4ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10920_var.png: 224x224 var 1.00, yok 0.00, 4.2ms
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10920_var.png: 224x224 var 1.00, yok 0.00, 4.2ms
# Speed: 2.5ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10927_var.png: 224x224 var 1.00, yok 0.00, 4.5ms
# Speed: 2.5ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10927_var.png: 224x224 var 1.00, yok 0.00, 4.5ms
# Speed: 2.5ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Speed: 2.5ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10955_var.png: 224x224 var 1.00, yok 0.00, 5.0ms
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10955_var.png: 224x224 var 1.00, yok 0.00, 5.0ms
# Speed: 3.1ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Speed: 3.1ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10975_var.png: 224x224 var 1.00, yok 0.00, 4.3ms
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\10975_var.png: 224x224 var 1.00, yok 0.00, 4.3ms
# Speed: 2.4ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\110134_var.png: 224x224 var 0.74, yok 0.26, 4.3ms
# Speed: 2.4ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Speed: 2.4ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\110134_var.png: 224x224 var 0.74, yok 0.26, 4.3ms
# Speed: 2.4ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11015_var.png: 224x224 var 1.00, yok 0.00, 4.1ms
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11015_var.png: 224x224 var 1.00, yok 0.00, 4.1ms
# Speed: 2.4ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Speed: 2.4ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\110377_var.png: 224x224 var 1.00, yok 0.00, 4.8ms
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\110377_var.png: 224x224 var 1.00, yok 0.00, 4.8ms
# Speed: 2.5ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11052_var.png: 224x224 var 1.00, yok 0.00, 4.3ms
# Speed: 2.5ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11052_var.png: 224x224 var 1.00, yok 0.00, 4.3ms
# Speed: 2.3ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\110537_var.png: 224x224 var 0.81, yok 0.19, 4.0ms
# Speed: 2.3ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Speed: 2.3ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\110537_var.png: 224x224 var 0.81, yok 0.19, 4.0ms
# Speed: 2.3ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11101_var.png: 224x224 var 1.00, yok 0.00, 4.4ms
# Speed: 2.4ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11101_var.png: 224x224 var 1.00, yok 0.00, 4.4ms
# Speed: 2.4ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\111102_var.png: 224x224 yok 1.00, var 0.00, 4.3ms
# Speed: 2.7ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\111102_var.png: 224x224 yok 1.00, var 0.00, 4.3ms
# Speed: 2.7ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11119_var.png: 224x224 yok 0.82, var 0.18, 5.0ms
# Speed: 2.7ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\111697_var.png: 224x224 var 1.00, yok 0.00, 4.3ms
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11119_var.png: 224x224 yok 0.82, var 0.18, 5.0ms
# Speed: 2.7ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\111697_var.png: 224x224 var 1.00, yok 0.00, 4.3ms
# Speed: 2.4ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\111774_var.png: 224x224 var 1.00, yok 0.00, 4.3ms
# Speed: 2.4ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\111774_var.png: 224x224 var 1.00, yok 0.00, 4.3ms
# Speed: 2.6ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Speed: 2.6ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11210_var.png: 224x224 var 1.00, yok 0.00, 4.2ms
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11210_var.png: 224x224 var 1.00, yok 0.00, 4.2ms
# Speed: 2.4ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# Speed: 2.4ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11211_var.png: 224x224 var 1.00, yok 0.00, 4.1ms
# Speed: 2.4ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11248_var.png: 224x224 var 1.00, yok 0.00, 4.2ms
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11211_var.png: 224x224 var 1.00, yok 0.00, 4.1ms
# Speed: 2.4ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11248_var.png: 224x224 var 1.00, yok 0.00, 4.2ms
# Speed: 2.4ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Speed: 2.4ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11249_var.png: 224x224 var 1.00, yok 0.00, 4.4ms
# Speed: 2.5ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11249_var.png: 224x224 var 1.00, yok 0.00, 4.4ms
# Speed: 2.5ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11262_var.png: 224x224 var 0.99, yok 0.01, 4.5ms
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11262_var.png: 224x224 var 0.99, yok 0.01, 4.5ms
# Speed: 2.5ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Speed: 2.5ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11268_var.png: 224x224 var 1.00, yok 0.00, 4.5ms
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11268_var.png: 224x224 var 1.00, yok 0.00, 4.5ms
# Speed: 2.4ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11275_var.png: 224x224 var 1.00, yok 0.00, 4.0ms
# Speed: 2.4ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11275_var.png: 224x224 var 1.00, yok 0.00, 4.0ms
# Speed: 2.4ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11320_var.png: 224x224 var 1.00, yok 0.00, 4.1ms
# Speed: 2.4ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11320_var.png: 224x224 var 1.00, yok 0.00, 4.1ms
# Speed: 2.5ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Speed: 2.5ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\113417_var.png: 224x224 yok 0.98, var 0.02, 4.8ms
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\113417_var.png: 224x224 yok 0.98, var 0.02, 4.8ms
# Speed: 2.4ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# Speed: 2.4ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11381_var.png: 224x224 var 1.00, yok 0.00, 6.3ms
# Speed: 3.3ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11430_var.png: 224x224 var 1.00, yok 0.00, 4.2ms
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11381_var.png: 224x224 var 1.00, yok 0.00, 6.3ms
# Speed: 3.3ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11430_var.png: 224x224 var 1.00, yok 0.00, 4.2ms
# Speed: 2.3ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Speed: 2.3ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11443_var.png: 224x224 var 1.00, yok 0.00, 4.6ms
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11443_var.png: 224x224 var 1.00, yok 0.00, 4.6ms
# Speed: 2.5ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11471_var.png: 224x224 var 1.00, yok 0.00, 4.5ms
# Speed: 2.5ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11471_var.png: 224x224 var 1.00, yok 0.00, 4.5ms
# Speed: 2.6ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Speed: 2.6ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11492_var.png: 224x224 var 0.82, yok 0.18, 4.9ms
# Speed: 2.6ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11504_var.png: 224x224 var 1.00, yok 0.00, 4.5ms
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11492_var.png: 224x224 var 0.82, yok 0.18, 4.9ms
# Speed: 2.6ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\11504_var.png: 224x224 var 1.00, yok 0.00, 4.5ms
# Speed: 2.6ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\115063_var.png: 224x224 yok 1.00, var 0.00, 8.7ms
# Speed: 2.6ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\var\115063_var.png: 224x224 yok 1.00, var 0.00, 8.7ms
# ...
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\288118_yok.png: 224x224 yok 1.00, var 0.00, 9.0ms
# Speed: 3.8ms preprocess, 9.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\288118_yok.png: 224x224 yok 1.00, var 0.00, 9.0ms
# Speed: 3.8ms preprocess, 9.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\288160_yok.png: 224x224 yok 1.00, var 0.00, 9.0ms
# Speed: 3.8ms preprocess, 9.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\288160_yok.png: 224x224 yok 1.00, var 0.00, 9.0ms
# Speed: 3.8ms preprocess, 9.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\288232_yok.png: 224x224 yok 1.00, var 0.00, 9.2ms
# Speed: 3.9ms preprocess, 9.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\288232_yok.png: 224x224 yok 1.00, var 0.00, 9.2ms
# Speed: 3.9ms preprocess, 9.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\289430_yok.png: 224x224 yok 1.00, var 0.00, 9.1ms
# Speed: 5.3ms preprocess, 9.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\289430_yok.png: 224x224 yok 1.00, var 0.00, 9.1ms
# Speed: 5.3ms preprocess, 9.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\289878_yok.png: 224x224 yok 1.00, var 0.00, 8.9ms
# Speed: 5.0ms preprocess, 8.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\289878_yok.png: 224x224 yok 1.00, var 0.00, 8.9ms
# Speed: 5.0ms preprocess, 8.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\291022_yok.png: 224x224 yok 0.96, var 0.04, 8.9ms
# Speed: 3.7ms preprocess, 8.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\291022_yok.png: 224x224 yok 0.96, var 0.04, 8.9ms
# Speed: 3.7ms preprocess, 8.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\291833_yok.png: 224x224 var 0.99, yok 0.01, 10.4ms
# Speed: 3.2ms preprocess, 10.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\291871_yok.png: 224x224 yok 1.00, var 0.00, 8.9ms
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\291833_yok.png: 224x224 var 0.99, yok 0.01, 10.4ms
# Speed: 3.2ms preprocess, 10.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\291871_yok.png: 224x224 yok 1.00, var 0.00, 8.9ms
# Speed: 3.6ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# Speed: 3.6ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\292249_yok.png: 224x224 yok 1.00, var 0.00, 10.2ms
# Speed: 2.6ms preprocess, 10.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\292249_yok.png: 224x224 yok 1.00, var 0.00, 10.2ms
# Speed: 2.6ms preprocess, 10.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\293225_yok.png: 224x224 yok 1.00, var 0.00, 10.6ms
# Speed: 2.9ms preprocess, 10.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\293225_yok.png: 224x224 yok 1.00, var 0.00, 10.6ms
# Speed: 2.9ms preprocess, 10.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\293727_yok.png: 224x224 yok 1.00, var 0.00, 9.1ms
# Speed: 4.6ms preprocess, 9.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\293727_yok.png: 224x224 yok 1.00, var 0.00, 9.1ms
# Speed: 4.6ms preprocess, 9.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\294252_yok.png: 224x224 var 0.90, yok 0.10, 9.0ms
# Speed: 3.6ms preprocess, 9.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\294252_yok.png: 224x224 var 0.90, yok 0.10, 9.0ms
# Speed: 3.6ms preprocess, 9.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\294891_yok.png: 224x224 yok 1.00, var 0.00, 9.1ms
# Speed: 3.0ms preprocess, 9.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\294891_yok.png: 224x224 yok 1.00, var 0.00, 9.1ms
# Speed: 3.0ms preprocess, 9.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\295995_yok.png: 224x224 yok 1.00, var 0.00, 9.0ms
# Speed: 3.3ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\296149_yok.png: 224x224 yok 1.00, var 0.00, 10.8ms
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\295995_yok.png: 224x224 yok 1.00, var 0.00, 9.0ms
# Speed: 3.3ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\296149_yok.png: 224x224 yok 1.00, var 0.00, 10.8ms
# Speed: 3.1ms preprocess, 10.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# Speed: 3.1ms preprocess, 10.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\296254_yok.png: 224x224 yok 1.00, var 0.00, 8.7ms
# Speed: 3.2ms preprocess, 8.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\296254_yok.png: 224x224 yok 1.00, var 0.00, 8.7ms
# Speed: 3.2ms preprocess, 8.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\296260_yok.png: 224x224 yok 1.00, var 0.00, 10.3ms
# Speed: 3.5ms preprocess, 10.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\296260_yok.png: 224x224 yok 1.00, var 0.00, 10.3ms
# Speed: 3.5ms preprocess, 10.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\296312_yok.png: 224x224 yok 0.92, var 0.08, 9.0ms
# Speed: 3.1ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\296600_yok.png: 224x224 yok 1.00, var 0.00, 8.4ms
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\296312_yok.png: 224x224 yok 0.92, var 0.08, 9.0ms
# Speed: 3.1ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\296600_yok.png: 224x224 yok 1.00, var 0.00, 8.4ms
# Speed: 2.5ms preprocess, 8.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# Speed: 2.5ms preprocess, 8.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\296862_yok.png: 224x224 yok 1.00, var 0.00, 8.6ms
# Speed: 3.0ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\296863_yok.png: 224x224 yok 1.00, var 0.00, 8.5ms
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\296862_yok.png: 224x224 yok 1.00, var 0.00, 8.6ms
# Speed: 3.0ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\296863_yok.png: 224x224 yok 1.00, var 0.00, 8.5ms
# Speed: 2.8ms preprocess, 8.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# Speed: 2.8ms preprocess, 8.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\297300_yok.png: 224x224 yok 1.00, var 0.00, 8.8ms
# Speed: 3.2ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\297300_yok.png: 224x224 yok 1.00, var 0.00, 8.8ms
# Speed: 3.2ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\298534_yok.png: 224x224 yok 0.96, var 0.04, 11.4ms
# Speed: 3.7ms preprocess, 11.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\298534_yok.png: 224x224 yok 0.96, var 0.04, 11.4ms
# Speed: 3.7ms preprocess, 11.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\298697_yok.png: 224x224 var 0.98, yok 0.02, 8.9ms
# Speed: 3.8ms preprocess, 8.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\298697_yok.png: 224x224 var 0.98, yok 0.02, 8.9ms
# Speed: 3.8ms preprocess, 8.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\299059_yok.png: 224x224 yok 1.00, var 0.00, 9.4ms
# Speed: 5.3ms preprocess, 9.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\299059_yok.png: 224x224 yok 1.00, var 0.00, 9.4ms
# Speed: 5.3ms preprocess, 9.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\299907_yok.png: 224x224 yok 0.99, var 0.01, 8.6ms
# Speed: 5.2ms preprocess, 8.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\1\final_testset\..\trainingDatav3\val\yok\299907_yok.png: 224x224 yok 0.99, var 0.01, 8.6ms
# Speed: 5.2ms preprocess, 8.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Collected 2418 predictions
#
# Testing 18 different threshold values...
# Collected 2418 predictions
#
# Testing 18 different threshold values...
#
# ==================================================
# THRESHOLD OPTIMIZATION RESULTS
# ==================================================
#
# 1. MAXIMUM ACCURACY (regardless of coverage):
#    Threshold: 0.95
#    Accuracy: 0.9295 (92.95%)
#    Coverage: 0.8805 (88.05%)
#    Correct/Accepted: 1979.0/2129.0
#
# 2. BEST ACCURACY-COVERAGE TRADE-OFF:
#    Threshold: 0.10
#    Accuracy: 0.8883 (88.83%)
#    Coverage: 1.0000 (100.00%)
#    Score (Acc×Cov): 0.8883
#    Correct/Accepted: 2148.0/2418.0
#
# 3. BEST ACCURACY WITH ≥80% COVERAGE:
#    Threshold: 0.95
#    Accuracy: 0.9295 (92.95%)
#    Coverage: 0.8805 (88.05%)
#    Correct/Accepted: 1979.0/2129.0
#
# ORIGINAL ACCURACY (no threshold): 0.8883 (88.83%)
#
# Confidence score statistics:
# Mean confidence: 0.9721
# Std confidence: 0.0831
# Min confidence: 0.5011
# Max confidence: 1.0000
#
# ==================================================
# THRESHOLD OPTIMIZATION RESULTS
# ==================================================
#
# 1. MAXIMUM ACCURACY (regardless of coverage):
#    Threshold: 0.95
#    Accuracy: 0.9295 (92.95%)
#    Coverage: 0.8805 (88.05%)
#    Correct/Accepted: 1979.0/2129.0
#
# 2. BEST ACCURACY-COVERAGE TRADE-OFF:
#    Threshold: 0.10
#    Accuracy: 0.8883 (88.83%)
#    Coverage: 1.0000 (100.00%)
#    Score (Acc×Cov): 0.8883
#    Correct/Accepted: 2148.0/2418.0
#
# 3. BEST ACCURACY WITH ≥80% COVERAGE:
#    Threshold: 0.95
#    Accuracy: 0.9295 (92.95%)
#    Coverage: 0.8805 (88.05%)
#    Correct/Accepted: 1979.0/2129.0
#
# ORIGINAL ACCURACY (no threshold): 0.8883 (88.83%)
#
# Confidence score statistics:
# Mean confidence: 0.9721
# Std confidence: 0.0831
# Min confidence: 0.5011
# Max confidence: 1.0000

# %%
# ===== VISUALIZATION OF THRESHOLD ANALYSIS =====
import matplotlib.pyplot as plt
# Create visualization plots
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 12))

# Plot 1: Accuracy vs Threshold
ax1.plot(results_df['threshold'], results_df['accuracy'], 'b-', linewidth=2, marker='o', markersize=4)
ax1.axvline(best_accuracy_threshold['threshold'], color='red', linestyle='--', alpha=0.7, 
            label=f'Max Accuracy: {best_accuracy_threshold["threshold"]:.2f}')
ax1.axvline(best_tradeoff_threshold['threshold'], color='green', linestyle='--', alpha=0.7,
            label=f'Best Trade-off: {best_tradeoff_threshold["threshold"]:.2f}')
ax1.set_xlabel('Confidence Threshold')
ax1.set_ylabel('Accuracy')
ax1.set_title('Accuracy vs Confidence Threshold\n(Low confidence → "yok" predictions)')
ax1.grid(True, alpha=0.3)
ax1.legend()

# Plot 2: Yok Assignment Ratio vs Threshold
ax2.plot(results_df['threshold'], results_df['yok_ratio']*100, 'r-', linewidth=2, marker='s', markersize=4)
ax2.axhline(20, color='orange', linestyle='--', alpha=0.7, label='20% Yok Assignment')
ax2.set_xlabel('Confidence Threshold')
ax2.set_ylabel('% Predictions Assigned to "yok"')
ax2.set_title('Yok Assignment Ratio vs Confidence Threshold')
ax2.grid(True, alpha=0.3)
ax2.legend()

# Plot 3: Accuracy vs Yok Assignment Ratio (Trade-off)
ax3.scatter(results_df['yok_ratio']*100, results_df['accuracy'], c=results_df['threshold'], 
           cmap='viridis', s=50, alpha=0.7)
ax3.scatter(best_tradeoff_threshold['yok_ratio']*100, best_tradeoff_threshold['accuracy'], 
           color='red', s=100, marker='*', label='Best Trade-off', zorder=5)
ax3.set_xlabel('% Predictions Assigned to "yok"')
ax3.set_ylabel('Accuracy')
ax3.set_title('Accuracy vs Yok Assignment Trade-off')
ax3.grid(True, alpha=0.3)
ax3.legend()
cbar = plt.colorbar(ax3.collections[0], ax=ax3)
cbar.set_label('Threshold')

# Plot 4: Confidence Score Distribution with threshold lines
ax4.hist(confidence_scores, bins=30, alpha=0.7, color='skyblue', edgecolor='black')
ax4.axvline(best_accuracy_threshold['threshold'], color='red', linestyle='--', 
            label=f'Max Acc Threshold: {best_accuracy_threshold["threshold"]:.2f}')
ax4.axvline(best_tradeoff_threshold['threshold'], color='green', linestyle='--',
            label=f'Trade-off Threshold: {best_tradeoff_threshold["threshold"]:.2f}')
ax4.axvline(np.mean(confidence_scores), color='orange', linestyle='-', 
            label=f'Mean: {np.mean(confidence_scores):.2f}')
ax4.set_xlabel('Confidence Score')
ax4.set_ylabel('Frequency')
ax4.set_title('Distribution of Confidence Scores\n(Below threshold → "yok" predictions)')
ax4.grid(True, alpha=0.3)
ax4.legend()

plt.tight_layout()
plt.savefig('threshold_optimization_yok_analysis.png', dpi=300, bbox_inches='tight')
plt.show()

print("Threshold optimization plots saved to 'threshold_optimization_yok_analysis.png'")
# Out:
# Threshold optimization plots saved to 'threshold_optimization_analysis.png'

# %%
# ===== APPLY OPTIMAL THRESHOLD FOR FINAL PREDICTIONS =====

# Choose your preferred threshold strategy
STRATEGY = "tradeoff"  # Options: "max_accuracy", "tradeoff", "low_yok"

if STRATEGY == "max_accuracy":
    optimal_threshold = best_accuracy_threshold['threshold']
    print(f"Using maximum accuracy strategy with threshold: {optimal_threshold:.2f}")
elif STRATEGY == "tradeoff":
    optimal_threshold = best_tradeoff_threshold['threshold']
    print(f"Using accuracy with minimal 'yok' assignments strategy with threshold: {optimal_threshold:.2f}")
elif STRATEGY == "low_yok" and best_low_yok_threshold is not None:
    optimal_threshold = best_low_yok_threshold['threshold']
    print(f"Using low 'yok' assignment strategy with threshold: {optimal_threshold:.2f}")
else:
    optimal_threshold = best_tradeoff_threshold['threshold']
    print(f"Defaulting to trade-off strategy with threshold: {optimal_threshold:.2f}")

# Re-run predictions with optimal threshold and "yok" assignment
print(f"\nRe-evaluating with optimal threshold: {optimal_threshold:.2f}")
print("(Low confidence predictions assigned to 'yok' class)")
print("="*60)

T_optimal = 0
F_optimal = 0
yok_assigned_count = 0
all_true_labels_optimal = []
all_pred_labels_optimal = []

for data in prediction_data:
    true_label = data['true_label']
    
    if data['top1_conf'] >= optimal_threshold:
        # Use original prediction if confidence >= threshold
        pred_label = data['top1_label']
        print(f"✓ True: {true_label}, Pred: {pred_label}, Conf: {data['top1_conf']:.3f}")
    else:
        # Assign to "yok" class if confidence < threshold
        pred_label = "yok"
        yok_assigned_count += 1
        print(f"⚠ True: {true_label}, Pred: {pred_label} (assigned due to low conf: {data['top1_conf']:.3f})")
    
    all_true_labels_optimal.append(true_label)
    all_pred_labels_optimal.append(pred_label)
    
    if pred_label.lower() == true_label.lower():
        T_optimal += 1
    else:
        F_optimal += 1

total_samples = len(prediction_data)
original_predictions = total_samples - yok_assigned_count

print(f"\n" + "="*60)
print("OPTIMAL THRESHOLD RESULTS WITH 'YOK' ASSIGNMENT")
print("="*60)
print(f"Threshold used: {optimal_threshold:.2f}")
print(f"Total samples: {total_samples}")
print(f"Original model predictions: {original_predictions}")
print(f"Assigned to 'yok' class: {yok_assigned_count}")
print(f"Yok assignment ratio: {yok_assigned_count/total_samples*100:.2f}%")
print(f"Overall accuracy: {T_optimal/total_samples*100:.2f}%")
print(f"Correct predictions: {T_optimal}")
print(f"Incorrect predictions: {F_optimal}")

# Generate confusion matrix for optimal threshold predictions with "yok" assignments
all_labels_optimal = sorted(list(set(all_true_labels_optimal + all_pred_labels_optimal)))
cm_optimal = confusion_matrix(all_true_labels_optimal, all_pred_labels_optimal, labels=all_labels_optimal)

plt.figure(figsize=(12, 10))
sns.heatmap(cm_optimal, annot=True, fmt="d", cmap='Blues',
            xticklabels=all_labels_optimal, yticklabels=all_labels_optimal)
plt.title(f'Confusion Matrix with Threshold {optimal_threshold:.2f}\n(Low confidence → "yok" predictions)')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.savefig(f'confusion_matrix_yok_threshold_{optimal_threshold:.2f}.png', dpi=300)
plt.show()
print(f"\nOptimal threshold confusion matrix saved to 'confusion_matrix_yok_threshold_{optimal_threshold:.2f}.png'")

# Calculate class-wise statistics
print(f"\n" + "="*50)
print("CLASS-WISE PERFORMANCE ANALYSIS")
print("="*50)

from sklearn.metrics import classification_report
report = classification_report(all_true_labels_optimal, all_pred_labels_optimal, 
                             labels=all_labels_optimal, output_dict=True)

for class_name in all_labels_optimal:
    if class_name in report:
        print(f"\nClass '{class_name}':")
        print(f"  Precision: {report[class_name]['precision']:.3f}")
        print(f"  Recall: {report[class_name]['recall']:.3f}")
        print(f"  F1-score: {report[class_name]['f1-score']:.3f}")
        print(f"  Support: {report[class_name]['support']}")

# Save optimal threshold to file for future use
threshold_info = {
    'optimal_threshold': optimal_threshold,
    'strategy': STRATEGY,
    'overall_accuracy': T_optimal/total_samples,
    'total_samples': total_samples,
    'original_predictions': original_predictions,
    'yok_assigned': yok_assigned_count,
    'yok_assignment_ratio': yok_assigned_count/total_samples,
    'correct_predictions': T_optimal,
    'incorrect_predictions': F_optimal
}

import json
with open('optimal_threshold_yok_info.json', 'w') as f:
    json.dump(threshold_info, f, indent=2)

print(f"\nOptimal threshold information saved to 'optimal_threshold_yok_info.json'")
# Out:
# Using accuracy-coverage trade-off strategy with threshold: 0.10
#
# Re-evaluating with optimal threshold: 0.10
# ==================================================
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.972
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.988
# ✓ True: var, Pred: var, Conf: 0.990
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.932
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.997
# ✓ True: var, Pred: yok, Conf: 0.996
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.763
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.994
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.766
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.937
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.998
# ✓ True: var, Pred: var, Conf: 0.947
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.638
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.995
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.742
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.807
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.998
# ✓ True: var, Pred: yok, Conf: 0.824
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.998
# ✓ True: var, Pred: var, Conf: 0.994
# ✓ True: var, Pred: var, Conf: 0.995
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.979
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.823
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.979
# ✓ True: var, Pred: var, Conf: 0.979
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 0.995
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.851
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.953
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 0.731
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.793
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.994
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.998
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.909
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.997
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.882
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.905
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.998
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.879
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.923
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.993
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.997
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.967
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.957
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.915
# ✓ True: var, Pred: yok, Conf: 0.962
# ✓ True: var, Pred: var, Conf: 0.997
# ✓ True: var, Pred: var, Conf: 0.997
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.998
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.938
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.744
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.758
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.996
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.843
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.993
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.959
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.921
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.855
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.665
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.997
# ✓ True: var, Pred: var, Conf: 0.991
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.869
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.998
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.998
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.675
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.719
# ✓ True: var, Pred: var, Conf: 0.995
# ✓ True: var, Pred: var, Conf: 0.974
# ✓ True: var, Pred: var, Conf: 0.802
# ✓ True: var, Pred: yok, Conf: 0.977
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.988
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 0.666
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.946
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.798
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.983
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.768
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 0.867
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.959
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.998
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.993
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.986
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.585
# ✓ True: var, Pred: yok, Conf: 0.508
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.828
# ✓ True: var, Pred: var, Conf: 0.934
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.913
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.998
# ✓ True: var, Pred: var, Conf: 0.926
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.882
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.931
# ✓ True: var, Pred: yok, Conf: 0.687
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 0.916
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.997
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.599
# ✓ True: var, Pred: var, Conf: 0.890
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.901
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.990
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.997
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.990
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.996
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.981
# ✓ True: var, Pred: var, Conf: 0.980
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.991
# ✓ True: var, Pred: var, Conf: 0.995
# ✓ True: var, Pred: var, Conf: 0.881
# ✓ True: var, Pred: var, Conf: 0.777
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.953
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.631
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.989
# ✓ True: var, Pred: yok, Conf: 0.897
# ✓ True: var, Pred: yok, Conf: 0.711
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.877
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.994
# ✓ True: var, Pred: var, Conf: 0.990
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.986
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.981
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.880
# ✓ True: var, Pred: var, Conf: 0.994
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.998
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.994
# ✓ True: var, Pred: yok, Conf: 0.896
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.983
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.825
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.997
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.833
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.991
# ✓ True: var, Pred: var, Conf: 0.997
# ✓ True: var, Pred: var, Conf: 0.997
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.996
# ✓ True: var, Pred: yok, Conf: 0.988
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.894
# ✓ True: var, Pred: var, Conf: 0.829
# ✓ True: var, Pred: var, Conf: 0.507
# ✓ True: var, Pred: yok, Conf: 0.613
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: yok, Conf: 0.874
# ✓ True: var, Pred: var, Conf: 0.988
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.985
# ✓ True: var, Pred: var, Conf: 0.989
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.982
# ✓ True: var, Pred: var, Conf: 0.982
# ✓ True: var, Pred: var, Conf: 0.981
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.977
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.943
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.992
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.503
# ✓ True: var, Pred: var, Conf: 0.970
# ✓ True: var, Pred: var, Conf: 0.890
# ✓ True: var, Pred: var, Conf: 0.991
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.992
# ✓ True: var, Pred: var, Conf: 0.939
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.954
# ✓ True: var, Pred: yok, Conf: 0.993
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.997
# ✓ True: var, Pred: var, Conf: 0.997
# ✓ True: var, Pred: var, Conf: 0.951
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.974
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.532
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.865
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.998
# ✓ True: var, Pred: var, Conf: 0.912
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.923
# ✓ True: var, Pred: yok, Conf: 0.996
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.821
# ✓ True: var, Pred: var, Conf: 0.988
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.949
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.627
# ✓ True: var, Pred: var, Conf: 0.771
# ✓ True: var, Pred: yok, Conf: 0.851
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.758
# ✓ True: var, Pred: yok, Conf: 0.644
# ✓ True: var, Pred: var, Conf: 0.990
# ✓ True: var, Pred: yok, Conf: 0.999
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.836
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.998
# ✓ True: var, Pred: yok, Conf: 0.966
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.811
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.547
# ✓ True: var, Pred: var, Conf: 0.956
# ✓ True: var, Pred: var, Conf: 0.944
# ✓ True: var, Pred: var, Conf: 0.878
# ✓ True: var, Pred: yok, Conf: 0.823
# ✓ True: var, Pred: var, Conf: 0.982
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 0.681
# ✓ True: var, Pred: yok, Conf: 0.995
# ✓ True: var, Pred: var, Conf: 0.982
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.983
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: yok, Conf: 0.995
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.997
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.999
# ✓ True: var, Pred: yok, Conf: 0.957
# ✓ True: var, Pred: var, Conf: 0.974
# ✓ True: var, Pred: yok, Conf: 0.920
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.909
# ✓ True: var, Pred: var, Conf: 0.992
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.965
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.954
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.956
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: yok, Conf: 0.979
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.943
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: yok, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.980
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.606
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.997
# ✓ True: var, Pred: var, Conf: 0.972
# ✓ True: var, Pred: yok, Conf: 0.985
# ✓ True: var, Pred: var, Conf: 0.977
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.896
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.972
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.991
# ✓ True: var, Pred: var, Conf: 0.658
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.998
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.944
# ✓ True: var, Pred: var, Conf: 0.989
# ✓ True: var, Pred: yok, Conf: 0.582
# ✓ True: var, Pred: yok, Conf: 0.779
# ✓ True: var, Pred: var, Conf: 0.998
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.949
# ✓ True: var, Pred: yok, Conf: 0.683
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.972
# ✓ True: var, Pred: var, Conf: 0.995
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 0.578
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 0.993
# ✓ True: var, Pred: yok, Conf: 0.990
# ✓ True: var, Pred: yok, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 0.994
# ✓ True: var, Pred: var, Conf: 0.960
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.994
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.804
# ✓ True: var, Pred: var, Conf: 0.975
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.906
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.623
# ✓ True: var, Pred: yok, Conf: 0.993
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.794
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 0.996
# ✓ True: var, Pred: var, Conf: 0.991
# ✓ True: var, Pred: yok, Conf: 0.913
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.988
# ✓ True: var, Pred: var, Conf: 0.550
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.995
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: yok, Conf: 0.999
# ✓ True: var, Pred: yok, Conf: 0.982
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.998
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.968
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.823
# ✓ True: var, Pred: yok, Conf: 0.949
# ✓ True: var, Pred: yok, Conf: 0.544
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.914
# ✓ True: var, Pred: var, Conf: 0.761
# ✓ True: var, Pred: var, Conf: 0.997
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.903
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.998
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.990
# ✓ True: var, Pred: var, Conf: 0.997
# ✓ True: var, Pred: yok, Conf: 0.846
# ✓ True: var, Pred: var, Conf: 0.964
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.881
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.993
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 0.996
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.607
# ✓ True: var, Pred: yok, Conf: 0.533
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.931
# ✓ True: var, Pred: yok, Conf: 0.974
# ✓ True: var, Pred: var, Conf: 0.986
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.947
# ✓ True: var, Pred: var, Conf: 0.998
# ✓ True: var, Pred: var, Conf: 0.973
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: yok, Conf: 0.997
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.995
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 0.965
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.772
# ✓ True: var, Pred: yok, Conf: 0.920
# ✓ True: var, Pred: var, Conf: 0.995
# ✓ True: var, Pred: yok, Conf: 0.988
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.992
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.647
# ✓ True: var, Pred: var, Conf: 0.968
# ✓ True: var, Pred: yok, Conf: 0.988
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.959
# ✓ True: var, Pred: var, Conf: 0.963
# ✓ True: var, Pred: yok, Conf: 0.996
# ✓ True: var, Pred: var, Conf: 0.974
# ✓ True: var, Pred: yok, Conf: 0.966
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 0.860
# ✓ True: var, Pred: yok, Conf: 0.854
# ✓ True: var, Pred: yok, Conf: 0.847
# ✓ True: var, Pred: var, Conf: 0.998
# ✓ True: var, Pred: yok, Conf: 0.847
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.959
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.883
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.970
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.985
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.655
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.949
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.998
# ✓ True: var, Pred: yok, Conf: 0.808
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.979
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.998
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.972
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.987
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: yok, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.978
# ✓ True: var, Pred: var, Conf: 0.994
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.974
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.992
# ✓ True: var, Pred: var, Conf: 0.997
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.993
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.968
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.954
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.950
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.996
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: yok, Conf: 0.529
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.928
# ✓ True: var, Pred: var, Conf: 0.999
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.913
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.994
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.521
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.947
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.998
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 0.950
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: var, Pred: var, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.951
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.997
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.995
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.996
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.994
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.971
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.798
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.988
# ✓ True: yok, Pred: yok, Conf: 0.916
# ✓ True: yok, Pred: yok, Conf: 0.998
# ✓ True: yok, Pred: yok, Conf: 0.962
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.998
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.931
# ✓ True: yok, Pred: yok, Conf: 0.743
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.653
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.993
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.552
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.993
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 0.897
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 0.629
# ✓ True: yok, Pred: yok, Conf: 0.646
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.589
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.981
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.757
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.569
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.685
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.926
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.571
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.995
# ✓ True: yok, Pred: var, Conf: 0.632
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.987
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.810
# ✓ True: yok, Pred: yok, Conf: 0.952
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.735
# ✓ True: yok, Pred: var, Conf: 0.838
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.806
# ✓ True: yok, Pred: yok, Conf: 0.989
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.993
# ✓ True: yok, Pred: yok, Conf: 0.668
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.502
# ✓ True: yok, Pred: yok, Conf: 0.993
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.513
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.713
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.991
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.994
# ✓ True: yok, Pred: yok, Conf: 1.000
# ...
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.694
# ✓ True: yok, Pred: yok, Conf: 0.984
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.953
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.964
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.531
# ✓ True: yok, Pred: yok, Conf: 0.982
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.908
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.986
# ✓ True: yok, Pred: yok, Conf: 0.985
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.962
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.871
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.738
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 0.960
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.595
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.905
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.984
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.801
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.953
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.604
# ✓ True: yok, Pred: var, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.992
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.975
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.998
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 0.967
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.991
# ✓ True: yok, Pred: yok, Conf: 0.985
# ✓ True: yok, Pred: var, Conf: 0.985
# ✓ True: yok, Pred: yok, Conf: 0.997
# ✓ True: yok, Pred: yok, Conf: 0.995
# ✓ True: yok, Pred: yok, Conf: 0.968
# ✓ True: yok, Pred: var, Conf: 0.606
# ✓ True: yok, Pred: yok, Conf: 0.868
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.985
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.968
# ✓ True: yok, Pred: yok, Conf: 0.554
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.972
# ✓ True: yok, Pred: yok, Conf: 0.997
# ✓ True: yok, Pred: var, Conf: 0.703
# ✓ True: yok, Pred: yok, Conf: 0.537
# ✓ True: yok, Pred: var, Conf: 0.932
# ✓ True: yok, Pred: var, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.701
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.985
# ✓ True: yok, Pred: yok, Conf: 0.888
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.514
# ✓ True: yok, Pred: yok, Conf: 0.989
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.603
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.656
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.957
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.954
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.910
# ✓ True: yok, Pred: yok, Conf: 0.986
# ✓ True: yok, Pred: yok, Conf: 0.844
# ✓ True: yok, Pred: yok, Conf: 0.998
# ✓ True: yok, Pred: yok, Conf: 0.845
# ✓ True: yok, Pred: yok, Conf: 0.969
# ✓ True: yok, Pred: var, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.926
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.991
# ✓ True: yok, Pred: var, Conf: 0.988
# ✓ True: yok, Pred: var, Conf: 0.813
# ✓ True: yok, Pred: var, Conf: 0.822
# ✓ True: yok, Pred: yok, Conf: 0.998
# ✓ True: yok, Pred: yok, Conf: 0.997
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.764
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: var, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.833
# ✓ True: yok, Pred: yok, Conf: 0.997
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.920
# ✓ True: yok, Pred: yok, Conf: 0.998
# ✓ True: yok, Pred: yok, Conf: 0.740
# ✓ True: yok, Pred: yok, Conf: 0.988
# ✓ True: yok, Pred: yok, Conf: 0.991
# ✓ True: yok, Pred: var, Conf: 0.898
# ✓ True: yok, Pred: var, Conf: 0.978
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.941
# ✓ True: yok, Pred: var, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.622
# ✓ True: yok, Pred: var, Conf: 0.607
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.946
# ✓ True: yok, Pred: var, Conf: 0.984
# ✓ True: yok, Pred: var, Conf: 0.915
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.994
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.975
# ✓ True: yok, Pred: var, Conf: 0.760
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.993
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.988
# ✓ True: yok, Pred: yok, Conf: 0.994
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.983
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 0.549
# ✓ True: yok, Pred: var, Conf: 0.659
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: var, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.756
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.998
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 0.848
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 0.950
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.990
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 0.998
# ✓ True: yok, Pred: yok, Conf: 0.971
# ✓ True: yok, Pred: var, Conf: 0.784
# ✓ True: yok, Pred: yok, Conf: 0.977
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.812
# ✓ True: yok, Pred: yok, Conf: 0.997
# ✓ True: yok, Pred: var, Conf: 0.963
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.998
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.936
# ✓ True: yok, Pred: yok, Conf: 0.974
# ✓ True: yok, Pred: var, Conf: 0.811
# ✓ True: yok, Pred: var, Conf: 0.965
# ✓ True: yok, Pred: var, Conf: 0.979
# ✓ True: yok, Pred: yok, Conf: 0.996
# ✓ True: yok, Pred: yok, Conf: 0.535
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.996
# ✓ True: yok, Pred: var, Conf: 0.889
# ✓ True: yok, Pred: yok, Conf: 0.998
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.989
# ✓ True: yok, Pred: var, Conf: 0.651
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.702
# ✓ True: yok, Pred: var, Conf: 0.651
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.964
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.529
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.594
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.844
# ✓ True: yok, Pred: yok, Conf: 0.996
# ✓ True: yok, Pred: yok, Conf: 0.899
# ✓ True: yok, Pred: var, Conf: 0.997
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.877
# ✓ True: yok, Pred: var, Conf: 0.790
# ✓ True: yok, Pred: var, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.997
# ✓ True: yok, Pred: yok, Conf: 0.960
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.993
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.998
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 0.678
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.994
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.798
# ✓ True: yok, Pred: var, Conf: 0.994
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 0.998
# ✓ True: yok, Pred: yok, Conf: 0.993
# ✓ True: yok, Pred: yok, Conf: 0.948
# ✓ True: yok, Pred: yok, Conf: 0.996
# ✓ True: yok, Pred: yok, Conf: 0.969
# ✓ True: yok, Pred: var, Conf: 0.987
# ✓ True: yok, Pred: yok, Conf: 0.991
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.992
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.940
# ✓ True: yok, Pred: yok, Conf: 0.997
# ✓ True: yok, Pred: var, Conf: 0.540
# ✓ True: yok, Pred: yok, Conf: 0.917
# ✓ True: yok, Pred: yok, Conf: 0.519
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.997
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 0.998
# ✓ True: yok, Pred: yok, Conf: 0.957
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.926
# ✓ True: yok, Pred: yok, Conf: 0.997
# ✓ True: yok, Pred: yok, Conf: 0.907
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.997
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.994
# ✓ True: yok, Pred: yok, Conf: 0.980
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.995
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.965
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.983
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: var, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.960
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.996
# ✓ True: yok, Pred: yok, Conf: 0.992
# ✓ True: yok, Pred: yok, Conf: 0.998
# ✓ True: yok, Pred: var, Conf: 0.937
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.506
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.993
# ✓ True: yok, Pred: var, Conf: 0.929
# ✓ True: yok, Pred: yok, Conf: 0.845
# ✓ True: yok, Pred: var, Conf: 0.982
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.997
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 0.984
# ✓ True: yok, Pred: var, Conf: 0.986
# ✓ True: yok, Pred: yok, Conf: 0.997
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: var, Conf: 0.673
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 0.989
# ✓ True: yok, Pred: yok, Conf: 0.927
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.757
# ✓ True: yok, Pred: yok, Conf: 0.924
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.760
# ✓ True: yok, Pred: yok, Conf: 0.998
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.998
# ✓ True: yok, Pred: yok, Conf: 0.962
# ✓ True: yok, Pred: var, Conf: 0.989
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: var, Conf: 0.897
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.996
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 0.915
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 1.000
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 0.957
# ✓ True: yok, Pred: var, Conf: 0.985
# ✓ True: yok, Pred: yok, Conf: 0.999
# ✓ True: yok, Pred: yok, Conf: 0.987
#
# ==================================================
# OPTIMAL THRESHOLD RESULTS
# ==================================================
# Threshold used: 0.10
# Total samples: 2418
# Accepted predictions: 2418
# Rejected predictions: 0
# Coverage: 100.00%
# Accuracy on accepted: 88.83%
# Correct predictions: 2148
# Incorrect predictions: 270
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 70
#      68 if len(all_true_labels_optimal) > 0:
#      69     all_labels_optimal = sorted(list(set(all_true_labels_optimal + all_pred_labels_optimal)))
# ---> 70     cm_optimal = confusion_matrix(all_true_labels_optimal, all_pred_labels_optimal, labels=all_labels_optimal)
#      72     plt.figure(figsize=(12, 10))
#      73     sns.heatmap(cm_optimal, annot=True, fmt="d", cmap='Blues',
#      74                 xticklabels=all_labels_optimal, yticklabels=all_labels_optimal)
#
# NameError: name 'confusion_matrix' is not defined
