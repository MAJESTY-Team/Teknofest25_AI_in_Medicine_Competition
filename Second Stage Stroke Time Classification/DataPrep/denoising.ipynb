# %%
import cv2
import matplotlib.pyplot as plt


from pathlib import Path
path=Path("C:\\Users\\alt_user\\Desktop\\Teknofest25Veri\\Pipeline\\val_results\\F\\Vaka_359786_50451936.2.4_Subakut.png")
# Load as grayscale
img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)


def show_image_and_histogram(img):
    # Show image
    plt.figure(figsize=(6, 6))
    plt.imshow(img, cmap="gray")
    plt.title("Original MR Slice")
    plt.axis("off")

    # Plot histogram
    plt.figure(figsize=(6, 3))
    plt.hist(img.ravel()[img.ravel()!=0], bins=256, color="black")
    plt.title("Intensity Histogram")
    plt.xlabel("Pixel value")
    plt.ylabel("Count")
    plt.show()


show_image_and_histogram(img)

# %%
denoised = cv2.medianBlur(img, ksize=3) 
show_image_and_histogram(denoised)

# %%
IMAGE_EXTENSIONS = {'.png'}

def read_images(root_dir):
    root = Path(root_dir)
    for path in root.rglob('*'):
        if path.suffix.lower() in IMAGE_EXTENSIONS:
            yield path

# %%
import os

for image_path in read_images("noise"):
    img = cv2.imread(str(image_path), cv2.IMREAD_GRAYSCALE)
    denoised = cv2.medianBlur(img, ksize=5)
    label=image_path.stem.split('_')[-1]  # Assuming label is the first part of the filename
    denoised_path = os.path.join(f"denoised/{label}", f"{image_path.name}")
    os.makedirs(os.path.dirname(denoised_path), exist_ok=True)
    cv2.imwrite(str(denoised_path), denoised)
    print(f"Denoised image saved at: {denoised_path}")
# Out:
# Denoised image saved at: denoised/HiperakutAkut\aug.1.Vaka_356786_50226994.3.4_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\aug.1.Vaka_357997_50464072.0.11_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\aug.1.Vaka_364070_50059319.3.16_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\aug.1.Vaka_387129_50480598.3.24_HiperakutAkut.png
# Denoised image saved at: denoised/NormalKronik\aug.1.Vaka_394828_50057670.2.6_NormalKronik.png
# Denoised image saved at: denoised/HiperakutAkut\aug.2.Vaka_330369_50255429.2.3_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\aug.2.Vaka_356786_50226994.3.4_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\aug.2.Vaka_364070_50059319.3.16_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\aug.2.Vaka_387129_50480598.3.24_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\aug.3.Vaka_330369_50255429.2.3_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\aug.3.Vaka_356786_50226994.3.4_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\aug.3.Vaka_364070_50059319.3.16_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\aug.3.Vaka_387129_50480598.3.24_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_302330_50080557.1.23_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_302330_50080557.1.53_HiperakutAkut.png
# Denoised image saved at: denoised/Subakut\Vaka_302667_50342134.3.21_Subakut.png
# Denoised image saved at: denoised/Subakut\Vaka_302667_50342134.3.22_Subakut.png
# Denoised image saved at: denoised/Subakut\Vaka_302667_50342134.3.23_Subakut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_305905_50521425.2.0_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_305905_50521425.2.12_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_305905_50521425.2.16_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_305905_50521425.2.6_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_305932_50000275.0.18_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_305932_50000275.0.19_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_305932_50000275.0.20_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_313875_50209600.2.1_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_315536_50047497.0.11_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_315536_50047497.0.19_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_315536_50047497.0.2_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_315536_50047497.0.31_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_315536_50047497.0.9_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_317529_50454308.2.4_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_318363_50157660.0.10_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_318363_50157660.0.11_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_323310_50415913.1.0_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_323310_50415913.1.2_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_323310_50415913.1.5_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_330362_50126698.1.19_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_330362_50126698.1.7_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_330369_50255429.2.3_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_337763_50554088.1.4_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_337763_50554088.1.5_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_347849_50066970.7.7_HiperakutAkut.png
# Denoised image saved at: denoised/NormalKronik\Vaka_350385_50567819.3.13_NormalKronik.png
# Denoised image saved at: denoised/NormalKronik\Vaka_350385_50567819.3.23_NormalKronik.png
# Denoised image saved at: denoised/NormalKronik\Vaka_350385_50567819.3.3_NormalKronik.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_351152_50125752.1.10_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_351152_50125752.1.8_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_351152_50125752.1.9_HiperakutAkut.png
# Denoised image saved at: denoised/NormalKronik\Vaka_355697_50075232.2.12_NormalKronik.png
# Denoised image saved at: denoised/NormalKronik\Vaka_355697_50075232.2.3_NormalKronik.png
# Denoised image saved at: denoised/NormalKronik\Vaka_355697_50075232.2.5_NormalKronik.png
# Denoised image saved at: denoised/NormalKronik\Vaka_355697_50075232.2.9_NormalKronik.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_357848_50033967.3.6_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_360963_50251162.3.11_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_360963_50251162.3.13_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_360963_50251162.3.14_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_360963_50251162.3.7_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_360963_50251162.3.9_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_361878_50454187.2.24_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_361878_50454187.2.5_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_361878_50454187.2.6_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_364963_50533952.2.21_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_364963_50533952.3.18_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_364963_50533952.3.20_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_364963_50533952.3.21_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_365785_50482761.2.13_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_365785_50482761.2.14_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_365785_50482761.2.15_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_366284_50179676.4.16_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_366284_50179676.4.21_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_370140_50244203.1.24_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_370140_50244203.1.26_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_370140_50244203.1.27_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_376109_50401250.8.14_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_376109_50401250.8.15_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_397972_50254786.2.14_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_397972_50254786.2.15_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_397972_50254786.2.5_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_397972_50254786.2.6_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_398659_50170627.2.15_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_398659_50170627.2.16_HiperakutAkut.png
# Denoised image saved at: denoised/HiperakutAkut\Vaka_398659_50170627.2.18_HiperakutAkut.png
