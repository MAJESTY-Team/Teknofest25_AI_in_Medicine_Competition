# %%
from ultralytics import YOLO
model = YOLO("../TrainingCodes/runs/classify/yolo11m-cls_datasetv2/weights/best.pt") 

read_dir="../Yolo/Topluv2/train"
output_dir="./Assistance_required_data"

# %%
import shutil
from pathlib import Path
import os
IMAGE_EXTENSIONS = {'.png'}

def read_images(root_dir):
    root = Path(root_dir)
    for path in root.rglob('*'):
        if path.suffix.lower() in IMAGE_EXTENSIONS:
            yield path

# Usage
for path in read_images(read_dir):
    if(str(path).find("CT")!=-1):
        continue

    label=path.stem.split("_")[-1]
    # name=f"{caseNum}_"+path.name
    result=model.predict(source=path, save=False)
    result=result[0]
    pred=result.probs.top1
    if result.names[pred].lower() == label.lower():
        continue
    dst=os.path.join(output_dir, label, result.names[pred])
    os.makedirs(dst, exist_ok=True)
    name=path.name
    shutil.copyfile(path, os.path.join(dst, name))
    print(f"True label: {label}, Predicted: {result.names[pred]}")
    print(f"Image saved to {os.path.join(dst, name)}")
# Out:
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_301367_50353613.5.8_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.3ms
# Speed: 1.7ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_302861_50479238.3.5_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 8.7ms
# Speed: 3.7ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_309924_50419553.1.7_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 4.2ms
# Speed: 1.9ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_310946_50189128.1.14_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.4ms
# Speed: 1.3ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_310946_50189128.1.15_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.3ms
# Speed: 1.4ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_313358_50372352.3.5_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 4.4ms
# Speed: 1.6ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_313849_50385612.2.38_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.3ms
# Speed: 1.3ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_316890_50044252.5.13_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 9.2ms
# Speed: 1.8ms preprocess, 9.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_317258_50302750.0.64_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.4ms
# Speed: 1.4ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_319251_50343483.2.17_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 9.6ms
# Speed: 2.5ms preprocess, 9.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_322742_50434227.3.16_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 6.5ms
# Speed: 2.3ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_330369_50255429.2.3_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.8ms
# Speed: 2.7ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_338283_50310659.0.19_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 8.9ms
# Speed: 1.9ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_338283_50310659.2.13_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.4ms
# Speed: 1.5ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_342165_50106927.2.42_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.5ms
# Speed: 1.6ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_350305_50083595.0.19_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.6ms
# Speed: 1.7ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_352325_50280951.7.16_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.5ms
# Speed: 1.6ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_353517_50065258.3.16_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.7ms
# Speed: 1.4ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_353517_50065258.3.39_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.4ms
# Speed: 1.4ms preprocess, 4.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_356786_50226994.3.4_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 4.5ms
# Speed: 1.4ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_357848_50033967.2.54_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 8.5ms
# Speed: 1.7ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_357997_50464072.0.11_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.0ms
# Speed: 1.3ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_357997_50464072.1.14_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.0ms
# Speed: 1.8ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_359336_50168941.0.12_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.4ms
# Speed: 1.9ms preprocess, 4.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_359785_50049493.1.31_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.0ms
# Speed: 2.7ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_360833_50081709.3.14_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.5ms
# Speed: 1.6ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_361353_50546273.3.20_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.5ms
# Speed: 1.6ms preprocess, 4.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_363012_50409818.2.37_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.5ms
# Speed: 1.5ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_364070_50059319.3.16_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.2ms
# Speed: 1.5ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_366094_50208299.8.7_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.8ms
# Speed: 1.7ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_370115_50417921.4.13_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.3ms
# Speed: 1.7ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_370357_50417666.1.7_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 6.7ms
# Speed: 1.4ms preprocess, 6.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_372307_50233196.0.33_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_372492_50367310.1.7_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.4ms
# Speed: 1.4ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_376219_50133652.2.14_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.8ms
# Speed: 1.3ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_378382_50307811.3.12_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.3ms
# Speed: 2.0ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_380090_50156866.1.15_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 7.7ms
# Speed: 2.2ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_382189_50188317.2.36_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.4ms
# Speed: 2.2ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_383852_50543711.1.11_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.9ms
# Speed: 1.4ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_387129_50480598.3.24_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.7ms
# Speed: 1.5ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_387497_50052458.3.9_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 8.9ms
# Speed: 1.5ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_389128_50173324.2.8_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 4.3ms
# Speed: 1.3ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_390252_50002184.0.31_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.6ms
# Speed: 1.2ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_392143_50150204.4.14_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.2ms
# Speed: 1.6ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_393467_50467565.1.18_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 4.5ms
# Speed: 0.9ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_394192_50430154.0.42_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.4ms
# Speed: 1.4ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_395584_50218149.14.20_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 6.1ms
# Speed: 1.6ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_397182_50064017.2.27_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 6.0ms
# Speed: 1.3ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.1.Vaka_397939_50194682.3.40_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.6ms
# Speed: 1.7ms preprocess, 4.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_301367_50353613.5.8_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.5ms
# Speed: 1.5ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_302861_50479238.3.5_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.6ms
# Speed: 2.2ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_309924_50419553.1.7_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 4.2ms
# Speed: 1.4ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_310946_50189128.1.14_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.4ms
# Speed: 1.3ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_310946_50189128.1.15_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.1ms
# Speed: 1.3ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_313358_50372352.3.5_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 4.2ms
# Speed: 1.7ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_313849_50385612.2.38_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.2ms
# Speed: 1.3ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_316890_50044252.5.13_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.3ms
# Speed: 1.8ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_317258_50302750.0.64_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.5ms
# Speed: 1.3ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_319251_50343483.2.17_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.4ms
# Speed: 2.4ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_322742_50434227.3.16_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.3ms
# Speed: 1.3ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_330369_50255429.2.3_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.7ms
# Speed: 1.7ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_338283_50310659.0.19_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.0ms
# Speed: 1.4ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_338283_50310659.2.13_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.5ms
# Speed: 1.2ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_342165_50106927.2.42_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 7.5ms
# Speed: 3.4ms preprocess, 7.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_350305_50083595.0.19_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 5.4ms
# Speed: 1.6ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_352325_50280951.7.16_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.9ms
# Speed: 2.0ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_353517_50065258.3.16_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.6ms
# Speed: 1.3ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_353517_50065258.3.39_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.4ms
# Speed: 1.5ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_356786_50226994.3.4_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 9.1ms
# Speed: 1.5ms preprocess, 9.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_357848_50033967.2.54_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.2ms
# Speed: 1.4ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_357997_50464072.0.11_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.2ms
# Speed: 1.3ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_357997_50464072.1.14_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.5ms
# Speed: 1.7ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_359336_50168941.0.12_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.5ms
# Speed: 1.7ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_359785_50049493.1.31_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.4ms
# Speed: 1.8ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_360833_50081709.3.14_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, Subakut 0.00, NormalKronik 0.00, 4.8ms
# Speed: 1.6ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_361353_50546273.3.20_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.1ms
# Speed: 1.7ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_363012_50409818.2.37_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.5ms
# Speed: 1.8ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_364070_50059319.3.16_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.4ms
# Speed: 1.7ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_366094_50208299.8.7_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.7ms
# Speed: 1.7ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_370115_50417921.4.13_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.4ms
# Speed: 1.6ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_370357_50417666.1.7_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.9ms
# Speed: 1.4ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_372307_50233196.0.33_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 4.9ms
# Speed: 1.5ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka_372492_50367310.1.7_HiperakutAkut.png: 224x224 HiperakutAkut 1.00, NormalKronik 0.00, Subakut 0.00, 5.1ms
# Speed: 1.6ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 c:\Users\alt_user\Documents\GitHub\Teknofest25_AI_in_Medicine_Competition\2\Pipeline\..\Yolo\Topluv2\train\HiperakutAkut\aug.2.Vaka
4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)

# %%
import os
from PIL import Image, ImageEnhance, ImageOps
import random

# 1) Configuration: point these to your folders
input_dir = 'Assistance_required_data'    # Folder containing original images
output_dir = '../Yolo/Toplu/train'  # Folder to save augmented images
aug_per_image = 3            # How many augmented copies per original

# Ensure output folder exists
os.makedirs(output_dir, exist_ok=True)

def random_flip(img):
    """Random horizontal and/or vertical flip."""
    if random.choice([True, False]):
        img = ImageOps.mirror(img)
    if random.choice([True, False]):
        img = ImageOps.flip(img)
    return img

def random_rotation(img):
    """Rotate by a random angle between -30 and +30 degrees."""
    angle = random.uniform(-40, 40)
    return img.rotate(angle, expand=True)

def random_color_jitter(img):
    """Adjust brightness, contrast, and color randomly."""
    # Brightness
    enhancer = ImageEnhance.Brightness(img)
    img = enhancer.enhance(random.uniform(0.7, 1.3))

    # Contrast
    enhancer = ImageEnhance.Contrast(img)
    img = enhancer.enhance(random.uniform(0.7, 1.3))

    # # Color/Saturation
    # enhancer = ImageEnhance.Color(img)
    # img = enhancer.enhance(random.uniform(0.8, 1.2))

    return img

# def random_crop(img):
#     """
#     Randomly crop 80–100% of the original, then resize back to original size.
#     This simulates a zoom-and-translate effect.
#     """
#     width, height = img.size
#     scale = random.uniform(0.8, 1.0)
#     new_w = int(width * scale)
#     new_h = int(height * scale)
#     left = random.randint(0, width - new_w)
#     top = random.randint(0, height - new_h)
#     cropped = img.crop((left, top, left + new_w, top + new_h))
#     return cropped.resize((width, height), Image.ANTIALIAS)

def augment_image(image_path, output_base, count):
    """
    Apply a sequence of random augmentations and save the results.
    Each run picks a random combination of flip, rotate, color jitter, crop.
    """
    img = Image.open(image_path).convert('RGB')
    base_name = os.path.splitext(os.path.basename(image_path))[0]
    label=base_name.split("_")[-1]
    output_base = os.path.join(output_base, label)
    for i in range(count):
        aug = img.copy()

        # Chain a few random transforms:
        aug = random_flip(aug)
        aug = random_rotation(aug)
        aug = random_color_jitter(aug)

        # Save out as JPEG (you can switch format/quality if desired)
        save_name = f"aug.{i+1}.{base_name}.png"
        aug.save(os.path.join(output_base, save_name), quality=100)

# Loop through each image and produce augmented variants
for image_file in read_images(input_dir):
    image_path = image_file
    augment_image(image_path, output_dir, aug_per_image)
    print(f"Processed {image_path}")

# print(f"Processed {len(image_files)} images, each with {aug_per_image} variants.")
# Out:
# Processed Assistance_required_data\HiperakutAkut\NormalKronik\aug.2.Vaka_338283_50310659.2.13_HiperakutAkut.png
# Processed Assistance_required_data\HiperakutAkut\NormalKronik\aug.3.Vaka_395584_50218149.14.20_HiperakutAkut.png
# Processed Assistance_required_data\HiperakutAkut\NormalKronik\Vaka_317258_50302750.0.26_HiperakutAkut.png
# Processed Assistance_required_data\HiperakutAkut\NormalKronik\Vaka_322742_50434227.3.34_HiperakutAkut.png
# Processed Assistance_required_data\HiperakutAkut\NormalKronik\Vaka_323985_50119318.1.7_HiperakutAkut.png
# Processed Assistance_required_data\HiperakutAkut\NormalKronik\Vaka_337094_50164879.2.14_HiperakutAkut.png
# Processed Assistance_required_data\HiperakutAkut\NormalKronik\Vaka_365841_50181008.1.8_HiperakutAkut.png
# Processed Assistance_required_data\HiperakutAkut\NormalKronik\Vaka_367103_50357972.1.54_HiperakutAkut.png
# Processed Assistance_required_data\HiperakutAkut\NormalKronik\Vaka_367103_50357972.2.15_HiperakutAkut.png
# Processed Assistance_required_data\HiperakutAkut\NormalKronik\Vaka_370652_50026710.5.32_HiperakutAkut.png
# Processed Assistance_required_data\HiperakutAkut\NormalKronik\Vaka_389406_50352493.2.5_HiperakutAkut.png
# Processed Assistance_required_data\HiperakutAkut\NormalKronik\Vaka_390197_50576225.1.40_HiperakutAkut.png
# Processed Assistance_required_data\HiperakutAkut\NormalKronik\Vaka_391608_50380830.3.19_HiperakutAkut.png
# Processed Assistance_required_data\HiperakutAkut\NormalKronik\Vaka_394459_50514443.5.15_HiperakutAkut.png
# Processed Assistance_required_data\HiperakutAkut\Subakut\Vaka_323088_50162728.1.8_HiperakutAkut.png
# Processed Assistance_required_data\HiperakutAkut\Subakut\Vaka_393853_50092208.3.9_HiperakutAkut.png
# Processed Assistance_required_data\NormalKronik\HiperakutAkut\Vaka_328125_50054899.1.16_NormalKronik.png
# Processed Assistance_required_data\NormalKronik\HiperakutAkut\Vaka_331929_50451401.1.10_NormalKronik.png
# Processed Assistance_required_data\NormalKronik\HiperakutAkut\Vaka_333957_50360549.4.38_NormalKronik.png
# Processed Assistance_required_data\NormalKronik\HiperakutAkut\Vaka_340816_50519015.6.15_NormalKronik.png
# Processed Assistance_required_data\NormalKronik\HiperakutAkut\Vaka_349730_50100831.2.13_NormalKronik.png
# Processed Assistance_required_data\NormalKronik\HiperakutAkut\Vaka_355697_50075232.0.36_NormalKronik.png
# Processed Assistance_required_data\NormalKronik\HiperakutAkut\Vaka_357554_50417960.3.12_NormalKronik.png
# Processed Assistance_required_data\NormalKronik\HiperakutAkut\Vaka_361445_50435359.2.9_NormalKronik.png
# Processed Assistance_required_data\NormalKronik\HiperakutAkut\Vaka_373884_50124346.2.54_NormalKronik.png
# Processed Assistance_required_data\NormalKronik\HiperakutAkut\Vaka_376792_50332442.2.8_NormalKronik.png
# Processed Assistance_required_data\NormalKronik\HiperakutAkut\Vaka_391302_50336546.0.4_NormalKronik.png
# Processed Assistance_required_data\NormalKronik\Subakut\aug.3.Vaka_350695_50451897.0.4_NormalKronik.png
# Processed Assistance_required_data\NormalKronik\Subakut\Vaka_327703_50057434.1.32_NormalKronik.png
# Processed Assistance_required_data\Subakut\HiperakutAkut\Vaka_317529_50454308.2.29_Subakut.png
# Processed Assistance_required_data\Subakut\HiperakutAkut\Vaka_326765_50184294.2.37_Subakut.png
